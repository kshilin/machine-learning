# %% [markdown]
# # Finance clustering
#
# ## Yahoo Finance

# %%
import sys

import warnings
warnings.filterwarnings("ignore")

import pandas as pd
import numpy as np
import time
from tqdm.autonotebook import tqdm

import seaborn as sns
import matplotlib.pyplot as plt

from tslearn.clustering import TimeSeriesKMeans
from sklearn.metrics import silhouette_score
from sklearn.cluster import KMeans
from sklearn.preprocessing import StandardScaler, MinMaxScaler

import yfinance as yf

# %%
def get_info(ticker_obj):
    info_keys = ['shortName', 'sector', 'industry', 'country', 'market']
    info_values = []
    for key in info_keys:
        info_values.append(ticker_obj.info.get(key, None))
    return dict(zip(info_keys, info_values))

# %%
msft = yf.Ticker("MSFT")
display(msft.history())
get_info(msft)
# Out:
#                   Open        High         Low       Close    Volume  \
# Date
# 2021-11-16  335.066992  340.047900  334.897319  338.890015  20886800
# 2021-11-17  338.940002  342.190002  338.000000  339.119995  19053400
# 2021-11-18  338.179993  342.450012  337.119995  341.269989  22463500
# 2021-11-19  342.640015  345.100006  342.200012  343.109985  21963400
# 2021-11-22  344.619995  349.670013  339.549988  339.829987  31031100
# 2021-11-23  337.049988  339.450012  333.559998  337.679993  30427600
# 2021-11-24  336.279999  338.160004  333.910004  337.910004  21661300
# 2021-11-26  334.350006  337.929993  328.119995  329.679993  24217200
# 2021-11-29  334.940002  339.029999  334.739990  336.630005  28563500
# 2021-11-30  335.320007  337.779999  328.989990  330.589996  42885600
# 2021-12-01  335.130005  339.279999  329.390015  330.079987  33337600
# 2021-12-02  330.299988  333.489990  327.799988  329.489990  30766000
# 2021-12-03  331.989990  332.700012  318.029999  323.010010  41755900
# 2021-12-06  323.950012  327.450012  319.230011  326.190002  30032600
# 2021-12-07  331.640015  335.799988  330.100006  334.920013  31021900
# 2021-12-08  335.309998  335.500000  330.799988  334.970001  24761000
# 2021-12-09  334.410004  336.489990  332.119995  333.100006  22214200
# 2021-12-10  334.980011  343.000000  334.790009  342.540009  38077300
# 2021-12-13  340.679993  343.790009  339.079987  339.399994  28899400
# 2021-12-14  333.220001  334.640015  324.109985  328.339996  44438700
# 2021-12-15  328.609985  335.190002  324.500000  334.649994  35316000
#
#             Dividends  Stock Splits
# Date
# 2021-11-16       0.00             0
# 2021-11-17       0.62             0
# 2021-11-18       0.00             0
# 2021-11-19       0.00             0
# 2021-11-22       0.00             0
# 2021-11-23       0.00             0
# 2021-11-24       0.00             0
# 2021-11-26       0.00             0
# 2021-11-29       0.00             0
# 2021-11-30       0.00             0
# 2021-12-01       0.00             0
# 2021-12-02       0.00             0
# 2021-12-03       0.00             0
# 2021-12-06       0.00             0
# 2021-12-07       0.00             0
# 2021-12-08       0.00             0
# 2021-12-09       0.00             0
# 2021-12-10       0.00             0
# 2021-12-13       0.00             0
# 2021-12-14       0.00             0
# 2021-12-15       0.00             0
# {'shortName': 'Microsoft Corporation',
#  'sector': 'Technology',
#  'industry': 'Software—Infrastructure',
#  'country': 'United States',
#  'market': 'us_market'}

# %% [markdown]
# ## In case you need all tickers

# %%
all_tickers = pd.read_csv(
    'https://raw.githubusercontent.com/shilewenuw/get_all_tickers/master/get_all_tickers/tickers.csv', 
    header=None,
    error_bad_lines=False
)

all_tickers = all_tickers.values.reshape(-1)
print(len(all_tickers))
print(all_tickers[:4])
# Out:
# 2762
# ['DDD' 'MMM' 'WBAI' 'WUBA']

# %% [markdown]
# ## Loading interesting tickers

# %%
get_info(msft)
# Out:
# {'shortName': 'Microsoft Corporation',
#  'sector': 'Technology',
#  'industry': 'Software—Infrastructure',
#  'country': 'United States',
#  'market': 'us_market'}

# %%
import requests


url_link = 'https://finance.yahoo.com/trending-tickers'
r = requests.get(url_link,headers ={'User-Agent':'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/91.0.4472.124 Safari/537.36'})
trending = pd.read_html(r.text)[0]
display(trending.head(5))

url_link = 'https://finance.yahoo.com/screener/predefined/most_actives'
r = requests.get(url_link,headers ={'User-Agent':'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/91.0.4472.124 Safari/537.36'})
most_active = pd.read_html(r.text)[0]
display(most_active.head(5))

url_link = 'https://finance.yahoo.com/gainers'
r = requests.get(url_link,headers ={'User-Agent':'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/91.0.4472.124 Safari/537.36'})
gainers = pd.read_html(r.text)[0]
display(gainers.head(5))

url_link = 'https://finance.yahoo.com/losers'
r = requests.get(url_link,headers ={'User-Agent':'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/91.0.4472.124 Safari/537.36'})
losers = pd.read_html(r.text)[0]
display(losers.head(5))
# Out:
#   Symbol                          Name  Last Price Market Time  Change  \
# 0    AMD  Advanced Micro Devices, Inc.      146.50  4:00PM EST   10.90
# 1   RBLX            Roblox Corporation       97.95  4:01PM EST   -9.72
# 2   AAPL                    Apple Inc.      179.30  4:00PM EST    4.97
# 3   ROKU                    Roku, Inc.      203.94  4:00PM EST  -17.61
# 4   NVDA            NVIDIA Corporation      304.59  4:00PM EST   21.22
#
#   % Change    Volume Market Cap  Intraday High/Low  52 Week Range  Day Chart
# 0   +8.04%   71.982M   176.915B                NaN            NaN        NaN
# 1   -9.03%   42.649M    56.697B                NaN            NaN        NaN
# 2   +2.85%  127.001M     2.942T                NaN            NaN        NaN
# 3   -7.95%   20.475M    27.402B                NaN            NaN        NaN
# 4   +7.49%   69.401M   759.038B                NaN            NaN        NaN
#   Symbol                          Name  Price (Intraday)  Change % Change  \
# 0   AAPL                    Apple Inc.            179.30    4.97   +2.85%
# 1      F            Ford Motor Company             20.19    0.14   +0.70%
# 2    NIO                      NIO Inc.             30.79   -1.51   -4.67%
# 3      T                     AT&T Inc.             22.17   -0.12   -0.54%
# 4    AMD  Advanced Micro Devices, Inc.            146.50   10.90   +8.04%
#
#      Volume Avg Vol (3 month) Market Cap  PE Ratio (TTM)  52 Week Range
# 0  127.001M           87.704M     2.942T           31.96            NaN
# 1   76.081M            92.96M    80.684B           28.32            NaN
# 2     78.8M           41.411M    48.974B             NaN            NaN
# 3   67.296M           48.692M   158.316B          171.86            NaN
# 4   71.982M           53.431M   176.915B           45.19            NaN
#   Symbol                            Name  Price (Intraday)   Change % Change  \
# 0   CCMP             CMC Materials, Inc.           195.500  49.5300  +33.93%
# 1  BMCLF  BAIC Motor Corporation Limited             0.485   0.1018  +26.57%
# 2   BRDS               Bird Global, Inc.             8.970   1.2200  +15.74%
# 3    DNA  Ginkgo Bioworks Holdings, Inc.            10.850   1.3500  +14.21%
# 4     AI                     C3.ai, Inc.            35.010   3.8300  +12.28%
#
#     Volume Avg Vol (3 month) Market Cap  PE Ratio (TTM)  52 Week Range
# 0   5.176M            265490     5.557B             NaN            NaN
# 1   246270             26661     3.955B            8.66            NaN
# 2   1.073M            1.004M     2.461B             NaN            NaN
# 3  12.876M            8.335M    16.131B             NaN            NaN
# 4   9.492M            3.462M     3.677B             NaN            NaN
#   Symbol                          Name  Price (Intraday)  Change % Change  \
# 0  WXXWY  WuXi Biologics (Cayman) Inc.             19.83 -5.2300  -20.85%
# 1  WUXAY         WuXi AppTec Co., Ltd.             17.30 -4.1500  -19.35%
# 2   LEGN    Legend Biotech Corporation             41.14 -7.4000  -15.25%
# 3   ZLAB               Zai Lab Limited             54.90 -7.7900  -12.43%
# 4  EGRNF        China Evergrande Group              0.19 -0.0246  -11.46%
#
#    Volume Avg Vol (3 month) Market Cap  PE Ratio (TTM)  52 Week Range
# 0  444302            165621    42.111B           98.17            NaN
# 1  118972             16155    56.496B           78.28            NaN
# 2  2.576M            594400     5.954B             NaN            NaN
# 3  2.701M            630861     5.895B             NaN            NaN
# 4  174487            935495     2.623B            1.01            NaN

# %%
interesting_tickers = set()

for df in [trending, most_active, gainers, losers]:
    interesting_tickers = interesting_tickers.union(set(df['Symbol']))
    
interesting_tickers = list(interesting_tickers)
interesting_tickers[:4]
# Out:
# ['DNA', 'EDF.PA', 'AUPH', 'FMCKJ']

# %%
len(interesting_tickers)
# Out:
# 92

# %%
full_ticker_data = []

ticker_obj = yf.Ticker('BGNE')
close_price = ticker_obj.history(period='3mo')['Close'].to_dict()
info = get_info(ticker_obj)
info.update(close_price)
full_ticker_data.append(info)
pd.DataFrame(full_ticker_data)

ticker_obj = yf.Ticker('NUE')
close_price = ticker_obj.history(period='3mo')['Close'].to_dict()
info = get_info(ticker_obj)
info.update(close_price)
full_ticker_data.append(info)
pd.DataFrame(full_ticker_data)
# Out:
#            shortName           sector       industry         country  \
# 0      BeiGene, Ltd.       Healthcare  Biotechnology  Cayman Islands
# 1  Nucor Corporation  Basic Materials          Steel   United States
#
#       market  2021-09-16 00:00:00  2021-09-17 00:00:00  2021-09-20 00:00:00  \
# 0  us_market           385.239990           403.140015           398.500000
# 1  us_market           109.387848           104.477249            96.498764
#
#    2021-09-21 00:00:00  2021-09-22 00:00:00  ...  2021-12-02 00:00:00  \
# 0           388.510010           388.179993  ...           345.869995
# 1            95.831406            96.797585  ...           107.559998
#
#    2021-12-03 00:00:00  2021-12-06 00:00:00  2021-12-07 00:00:00  \
# 0           314.140015           299.209991           317.250000
# 1           110.500000           110.239998           114.010002
#
#    2021-12-08 00:00:00  2021-12-09 00:00:00  2021-12-10 00:00:00  \
# 0           315.029999           305.600006           298.429993
# 1           112.809998           112.889999           113.209999
#
#    2021-12-13 00:00:00  2021-12-14 00:00:00  2021-12-15 00:00:00
# 0           282.950012           278.429993           248.559998
# 1           115.550003           118.419998           108.220001
#
# [2 rows x 69 columns]

# %%
full_ticker_data = []

for ticker in tqdm(interesting_tickers):
    try:
        ticker_obj = yf.Ticker(ticker)
        close_price = ticker_obj.history(start="2020-01-01", period='3mo')['Close'].to_dict()
        info = get_info(ticker_obj)
        info.update(close_price)
        full_ticker_data.append(info)
    except:
        continue
        
full_ticker_df = pd.DataFrame(full_ticker_data)
# Out:
#   0%|          | 0/92 [00:00<?, ?it/s]

# %%
df_tic = full_ticker_df.dropna(axis=0, thresh = int(0.8*df.shape[0]))
df_tic = pd.concat([df_tic.iloc[:,:5],df_tic.iloc[:,5:].dropna(axis='columns' )],axis=1)
df_tic.head()
# Out:
#                          shortName              sector               industry  \
# 0   Ginkgo Bioworks Holdings, Inc.          Healthcare          Biotechnology
# 1                              EDF           Utilities  Utilities—Diversified
# 2      Aurinia Pharmaceuticals Inc          Healthcare          Biotechnology
# 3  FEDERAL HOME LOAN MORTGAGE CORP  Financial Services       Mortgage Finance
# 4         Barrick Gold Corporation     Basic Materials                   Gold
#
#          country     market  2021-11-03 00:00:00  2021-11-04 00:00:00  \
# 0  United States  us_market            14.190000            14.410000
# 1         France  fr_market            12.331509            12.448719
# 2         Canada  us_market            30.389999            31.900000
# 3  United States  us_market             3.270000             3.280000
# 4         Canada  us_market            18.399021            18.527477
#
#    2021-11-05 00:00:00  2021-11-08 00:00:00  2021-11-09 00:00:00  ...  \
# 0            13.950000            14.920000            14.920000  ...
# 1            12.531743            12.639186            12.609883  ...
# 2            31.980000            31.320000            30.059999  ...
# 3             3.300000             3.310000             3.300000  ...
# 4            19.367390            19.248814            19.387154  ...
#
#    2021-11-30 00:00:00  2021-12-01 00:00:00  2021-12-02 00:00:00  \
# 0                11.87            11.390000            10.220000
# 1                12.39            12.575000            12.430000
# 2                18.84            17.780001            20.139999
# 3                 3.67             3.900000             3.720000
# 4                18.99            18.389999            18.180000
#
#    2021-12-03 00:00:00  2021-12-06 00:00:00  2021-12-07 00:00:00  \
# 0             8.650000                 9.74             9.980000
# 1            12.550000                12.74            12.945000
# 2            18.670000                19.15            20.209999
# 3             3.260000                 3.41             3.430000
# 4            18.219999                18.49            18.559999
#
#    2021-12-08 00:00:00  2021-12-09 00:00:00  2021-12-10 00:00:00  \
# 0               10.160             9.890000            10.070000
# 1               12.795            12.540000            12.390000
# 2               20.830            20.969999            20.129999
# 3                3.600             3.700000             3.720000
# 4               18.600            18.170000            17.950001
#
#    2021-12-15 00:00:00
# 0            10.850000
# 1            11.870000
# 2            19.870001
# 3             3.010000
# 4            17.650000
#
# [5 rows x 33 columns]

# %% [markdown]
# ## Scaling everything

# %%
scaler = StandardScaler()
tickers_scaled = scaler.fit_transform(df_tic.iloc[:, 5:].T).T

# %%
plt.plot(tickers_scaled.T);

# %% [markdown]
# # Basic KMeans

# %%
distortions = []
silhouette = []
K = range(1, 10)
for k in tqdm(K):
    kmeanModel = TimeSeriesKMeans(n_clusters=k, metric="euclidean", n_jobs=6, max_iter=10)
    kmeanModel.fit(tickers_scaled)
    distortions.append(kmeanModel.inertia_)
    if k > 1:
        silhouette.append(silhouette_score(tickers_scaled, kmeanModel.labels_))

plt.figure(figsize=(10,4))
plt.plot(K, distortions, 'bx-')
plt.xlabel('k')
plt.ylabel('Distortion')
plt.title('Elbow Method')
plt.show()

plt.figure(figsize=(10,4))
plt.plot(K[1:], silhouette, 'bx-')
plt.xlabel('k')
plt.ylabel('Silhouette score')
plt.title('Silhouette')
plt.show()
# Out:
#   0%|          | 0/9 [00:00<?, ?it/s]

# %%
n_clusters = 6
ts_kmeans = TimeSeriesKMeans(n_clusters=n_clusters, metric="euclidean", n_jobs=3, max_iter=10)
ts_kmeans.fit(tickers_scaled)
# Out:
# TimeSeriesKMeans(max_iter=10, n_clusters=6, n_jobs=3)

# %%
for cluster_number in range(n_clusters):
    plt.plot(ts_kmeans.cluster_centers_[cluster_number, :, 0].T, label=cluster_number)
plt.title("Cluster centroids")
plt.legend()
plt.show()

# %%
df_tic['cluster'] = ts_kmeans.predict(tickers_scaled)
pd.DataFrame(df_tic.groupby('cluster')['sector'].value_counts())
# Out:
#                                 sector
# cluster sector
# 0       Technology                  10
#         Financial Services           6
#         Healthcare                   4
#         Communication Services       3
#         Consumer Cyclical            3
#                                      1
#         Basic Materials              1
#         Industrials                  1
# 1       Healthcare                   5
#         Technology                   3
#         Communication Services       1
#         Consumer Cyclical            1
#         Industrials                  1
#         Utilities                    1
# 2       Financial Services           7
#         Technology                   3
#         Consumer Cyclical            2
#         Healthcare                   2
# 3       Healthcare                   7
#         Financial Services           2
#         Consumer Cyclical            1
#         Consumer Defensive           1
#         Technology                   1
# 4       Technology                   4
#         Energy                       1
#         Financial Services           1
#         Healthcare                   1
#         Industrials                  1
# 5       Technology                   4
#         Basic Materials              2
#         Consumer Defensive           2
#         Industrials                  2
#         Communication Services       1
#         Financial Services           1
#         Healthcare                   1
#         Real Estate                  1

# %%
def plot_cluster_tickers(current_cluster):
    fig, ax = plt.subplots(
        int(np.ceil(current_cluster.shape[0]/4)),
        4,
        figsize=(15, 3*int(np.ceil(current_cluster.shape[0]/4)))
    )
    fig.autofmt_xdate(rotation=45)
    ax = ax.reshape(-1)

    for index, (_, row) in enumerate(current_cluster.iterrows()):
        ax[index].plot(row.iloc[5:-1])
        ax[index].set_title(f"{row.shortName}\n{row.sector}")
        plt.xticks(rotation=45)

    plt.tight_layout()
    plt.show()

# %%
for cluster in range(n_clusters):
    print("=================================================================================")
    print(f"                          Cluster number: {cluster}")
    print("=================================================================================")
    plot_cluster_tickers(df_tic[df_tic.cluster==cluster])
# Out:
# =================================================================================
#                           Cluster number: 0
# =================================================================================
# =================================================================================
#                           Cluster number: 1
# =================================================================================
# =================================================================================
#                           Cluster number: 2
# =================================================================================
# =================================================================================
#                           Cluster number: 3
# =================================================================================
# =================================================================================
#                           Cluster number: 4
# =================================================================================
# =================================================================================
#                           Cluster number: 5
# =================================================================================

# %% [markdown]
# # DTW

# %%
distortions = []
silhouette = []
K = range(1, 10)
for k in tqdm(K):
    kmeanModel = TimeSeriesKMeans(n_clusters=k, metric="dtw", n_jobs=6, max_iter=10)
    kmeanModel.fit(tickers_scaled)
    distortions.append(kmeanModel.inertia_)
    if k > 1:
        silhouette.append(silhouette_score(tickers_scaled, kmeanModel.labels_))

plt.figure(figsize=(10,4))
plt.plot(K, distortions, 'bx-')
plt.xlabel('k')
plt.ylabel('Distortion')
plt.title('Elbow Method')
plt.show()

plt.figure(figsize=(10,4))
plt.plot(K[1:], silhouette, 'bx-')
plt.xlabel('k')
plt.ylabel('Silhouette score')
plt.title('Silhouette')
plt.show()
# Out:
#   0%|          | 0/9 [00:00<?, ?it/s]

# %%
n_clusters = 7
ts_kmeans_dtw = TimeSeriesKMeans(n_clusters=n_clusters, metric="dtw", n_jobs=6, max_iter=10)
ts_kmeans_dtw.fit(tickers_scaled)
# Out:
# TimeSeriesKMeans(max_iter=10, metric='dtw', n_clusters=7, n_jobs=6)

# %%
for cluster_number in range(n_clusters):
    plt.plot(ts_kmeans_dtw.cluster_centers_[cluster_number, :, 0].T, label=cluster_number)
plt.title("Cluster centroids")
plt.legend()
plt.show()

# %%
df_tic['cluster'] = ts_kmeans_dtw.predict(tickers_scaled)
pd.DataFrame(df_tic.groupby('cluster')['sector'].value_counts())
# Out:
#                                 sector
# cluster sector
# 0       Technology                  11
#         Healthcare                  10
#         Financial Services           9
#         Consumer Cyclical            4
#         Communication Services       3
#         Basic Materials              1
#         Consumer Defensive           1
#         Industrials                  1
# 1       Healthcare                   2
#         Technology                   2
#         Basic Materials              1
#         Communication Services       1
#         Energy                       1
#         Financial Services           1
#         Industrials                  1
#         Utilities                    1
# 2       Healthcare                   3
#         Technology                   2
#         Communication Services       1
#         Consumer Defensive           1
#         Financial Services           1
#         Industrials                  1
# 3       Technology                   5
#         Healthcare                   2
#         Industrials                  2
#                                      1
#         Basic Materials              1
#         Consumer Cyclical            1
#         Consumer Defensive           1
#         Real Estate                  1
# 4       Technology                   4
#         Financial Services           1
#         Healthcare                   1
# 5       Consumer Cyclical            2
#         Healthcare                   1
#         Technology                   1
# 6       Financial Services           5
#         Healthcare                   1

# %%
for cluster in range(n_clusters):
    print("=================================================================================")
    print(f"                          Cluster number: {cluster}")
    print("=================================================================================")
    plot_cluster_tickers(df_tic[df_tic.cluster==cluster])
# Out:
# =================================================================================
#                           Cluster number: 0
# =================================================================================
# =================================================================================
#                           Cluster number: 1
# =================================================================================
# =================================================================================
#                           Cluster number: 2
# =================================================================================
# =================================================================================
#                           Cluster number: 3
# =================================================================================
# =================================================================================
#                           Cluster number: 4
# =================================================================================
# =================================================================================
#                           Cluster number: 5
# =================================================================================
# =================================================================================
#                           Cluster number: 6
# =================================================================================
