# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from IPython.display import display

# %%
import sklearn
sklearn.__version__
# Out:
# '1.7.2'

# %% [markdown]
# ## Датасет -  стоимость брильянтов, [лучшие друзья ...](https://youtu.be/hEyWqVfY4vo?si=u6HHD2zL4L8ad71K)

# %%
df = pd.read_csv("Diamants/dim_train.csv")
display(df.head())
# Out:
#    carat        cut color clarity  depth  table  price     x     y     z
# 0   1.52      Ideal     J     SI1   61.9   57.0   7491  7.37  7.33  4.55
# 1   0.31  Very Good     F     SI2   63.0   58.0    408  4.34  4.36  2.74
# 2   1.00    Premium     F     SI1   60.7   60.0   5292  6.40  6.36  3.87
# 3   1.01  Very Good     E    VVS2   63.3   58.0   8912  6.39  6.31  4.02
# 4   0.40    Premium     I     SI2   62.9   59.0    585  4.68  4.63  2.93

# %%
df = pd.read_csv("Diamants/dim_train.csv")
display(df.head())
# Out:
#    carat        cut color clarity  depth  table  price     x     y     z
# 0   1.52      Ideal     J     SI1   61.9   57.0   7491  7.37  7.33  4.55
# 1   0.31  Very Good     F     SI2   63.0   58.0    408  4.34  4.36  2.74
# 2   1.00    Premium     F     SI1   60.7   60.0   5292  6.40  6.36  3.87
# 3   1.01  Very Good     E    VVS2   63.3   58.0   8912  6.39  6.31  4.02
# 4   0.40    Premium     I     SI2   62.9   59.0    585  4.68  4.63  2.93

# %% [markdown]
# ## 1 проблема датасета - нереальные данные

# %%
df.describe()
# Out:
#               carat         depth         table         price             x  \
# count  37758.000000  37758.000000  37758.000000  37758.000000  37758.000000
# mean       0.798777     61.755085     57.460784   3932.113300      5.732871
# std        0.474574      1.440063      2.230229   3980.261121      1.122451
# min        0.200000     43.000000     43.000000    326.000000      0.000000
# 25%        0.400000     61.000000     56.000000    953.000000      4.720000
# 50%        0.700000     61.800000     57.000000   2404.000000      5.700000
# 75%        1.040000     62.500000     59.000000   5345.000000      6.540000
# max        5.010000     79.000000     95.000000  18823.000000     10.740000
#
#                   y             z
# count  37758.000000  37758.000000
# mean       5.736693      3.539717
# std        1.154608      0.695749
# min        0.000000      0.000000
# 25%        4.720000      2.910000
# 50%        5.710000      3.530000
# 75%        6.540000      4.040000
# max       58.900000      8.060000

# %% [markdown]
# ## 2 проблема датасета - "каратная цикличность"

# %%
sns.scatterplot(data = df, x = 'carat', y = 'price', alpha=0.05);
plt.xlim(0,3)
# Out:
# (0.0, 3.0)

# %%
sns.histplot(data=df, x="carat", bins=200);
plt.xlim(0,3);

# %% [markdown]
# ## 3 проблема датасета - нелинейность роста цены

# %%
sns.relplot(data = df, x = 'carat', y = 'price', col = 'cut', kind = 'scatter');

# %%
sns.relplot(data = df, x = 'carat', y = 'price', col = 'color', kind = 'scatter');

# %%
sns.relplot(data = df, x = 'carat', y = 'price', col = 'clarity', kind = 'scatter');

# %% [markdown]
# ## 4 проблема - целевая переменная

# %%
sns.histplot(data=df, x="price", bins=100, stat='percent');

# %% [markdown]
# ## 5 проблема датасета ???

# %%
sns.relplot(data = df, x = 'depth', y = 'price', col = 'cut', kind = 'scatter', alpha=1);

# %%
sns.relplot(data = df, x = df['x']*df['y'], y = 'price', col = 'cut', kind = 'scatter', alpha=0.5);

# %%
sns.relplot(data = df, x = df['x']*df['y']*df['z'], y = 'price', col = 'cut', kind = 'scatter', alpha=0.5);
