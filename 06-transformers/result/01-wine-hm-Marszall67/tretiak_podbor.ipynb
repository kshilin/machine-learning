# %%
# Внимание!!! Важно, что бы файлы с данными и исполняемый файл находились в одной папке, 
# тогда пути к тестовым и тренировочным наборам будут содержать только имена файлов.
# 
# В пути к тренировочным и тестовым данным запрежается использовать абсалютную адресацию, 
# то есть адресацию, в которой присутствуют имена папок. Путь должен содержать только имя файла.
#
# Напоминание: под моделью машинного обучения понимаются все действия с исходными данными, 
# которые необходимо произвести, что бы сопоставить признаки целевому значению.

# %% [markdown]
# ### Область работы 1 (библиотеки)

# %%
# Данный блок в области 1 НЕ выполняется преподавателем
# 
# данный блок предназначен только для подключения необходимых библиотек
# запрещается подключать библиотеки в других блоках
# запрещается скрывать предупреждения системы
# установка дополнительных библиотек размещается прямо здесь (обязательно закоментированы)
# pip install

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from scipy.stats import iqr


import plotly.express as px
import plotly.graph_objects as go
# %matplotlib inline
sns.set_style('whitegrid')

from sklearn.model_selection import train_test_split, StratifiedKFold, GridSearchCV, cross_val_score
from sklearn.neighbors import KNeighborsClassifier
from sklearn.model_selection import validation_curve
from sklearn.pipeline import Pipeline, make_pipeline
from sklearn.preprocessing import MinMaxScaler, RobustScaler, StandardScaler, Normalizer
from sklearn.metrics import roc_auc_score, precision_score, recall_score, accuracy_score, fbeta_score, classification_report
from sklearn.linear_model import LogisticRegression

# %% [markdown]
# ### Область работы 2 (поиск  модели .... )

# %%
# Данный блок(и) НЕ выполняются преподавателем в области 2
# блок(и) предназначены для поиска лучшей модели 
# должен быть понятен и очевиден отбор параметров модели
# оставляйте свои комментарии и разъяснения
# 
# Запрещается размещать данные блоки за пределами обасти 2
# Все блоки данной области должны быть выполнены
#
# ЗАПРЕЩАЕТСЯ ИСПОЛЬЗОВАТЬ ТЕСТОВЫЙ НАБОР
#
# Путь к тренировочному набору
# 

path_train = 'train.csv' # содержит только имя файла, без имен папок !!!
df = pd.read_csv(path_train)

# %% [markdown]
# # EDA

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1725 entries, 0 to 1724
# Data columns (total 12 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   fixed acidity         1725 non-null   float64
#  1   volatile acidity      1725 non-null   float64
#  2   citric acid           1725 non-null   float64
#  3   residual sugar        1725 non-null   float64
#  4   chlorides             1725 non-null   float64
#  5   free sulfur dioxide   1725 non-null   float64
#  6   total sulfur dioxide  1725 non-null   float64
#  7   density               1725 non-null   float64
#  8   pH                    1725 non-null   float64
#  9   sulphates             1725 non-null   float64
#  10  alcohol               1725 non-null   float64
#  11  quality               1725 non-null   int64
# dtypes: float64(11), int64(1)
# memory usage: 161.8 KB

# %%
df.isna().sum()
# Out:
# fixed acidity           0
# volatile acidity        0
# citric acid             0
# residual sugar          0
# chlorides               0
# free sulfur dioxide     0
# total sulfur dioxide    0
# density                 0
# pH                      0
# sulphates               0
# alcohol                 0
# quality                 0
# dtype: int64

# %%
df.describe()
# Out:
#        fixed acidity  volatile acidity  citric acid  residual sugar  \
# count    1725.000000       1725.000000  1725.000000     1725.000000
# mean        6.821797          0.283849     0.332545        5.725652
# std         0.853886          0.106090     0.122279        4.570812
# min         3.900000          0.085000     0.000000        0.600000
# 25%         6.300000          0.210000     0.270000        1.600000
# 50%         6.800000          0.270000     0.320000        4.600000
# 75%         7.300000          0.330000     0.380000        8.700000
# max        11.800000          1.100000     1.660000       20.700000
#
#          chlorides  free sulfur dioxide  total sulfur dioxide      density  \
# count  1725.000000          1725.000000           1725.000000  1725.000000
# mean      0.044460            34.615072            135.248116     0.993532
# std       0.021236            16.751535             42.848854     0.002830
# min       0.012000             3.000000             10.000000     0.987110
# 25%       0.034000            23.000000            105.000000     0.991320
# 50%       0.041000            33.000000            130.000000     0.993200
# 75%       0.049000            45.000000            164.000000     0.995500
# max       0.290000           124.000000            366.500000     1.001820
#
#                 pH    sulphates      alcohol      quality
# count  1725.000000  1725.000000  1725.000000  1725.000000
# mean      3.201449     0.492394    10.734348     6.004638
# std       0.151395     0.121452     1.272796     1.071667
# min       2.830000     0.220000     8.400000     3.000000
# 25%       3.100000     0.400000     9.600000     5.000000
# 50%       3.190000     0.480000    10.600000     6.000000
# 75%       3.300000     0.560000    11.700000     7.000000
# max       3.820000     1.080000    14.200000     9.000000

# %%
print('Пусто по дупликатам')
df[df.duplicated()]
# Out:
# Пусто по дупликатам
# Empty DataFrame
# Columns: [fixed acidity, volatile acidity, citric acid, residual sugar, chlorides, free sulfur dioxide, total sulfur dioxide, density, pH, sulphates, alcohol, quality]
# Index: []

# %%
plt.figure(figsize=(18, 18))
for i, col in enumerate(df.select_dtypes(include=['float64']).columns):
    plt.rcParams['axes.facecolor'] = 'white'
    ax = plt.subplot(4,3, i+1)
    sns.histplot(data=df, x=col, ax=ax,color='red',kde=True)
plt.suptitle('Data distribution of continuous variables')
plt.tight_layout()

# %%
df.corr().style.background_gradient(cmap = 'Greys')
# Out:
# <style type="text/css">
# #T_0e7d2_row0_col0, #T_0e7d2_row1_col1, #T_0e7d2_row2_col2, #T_0e7d2_row3_col3, #T_0e7d2_row4_col4, #T_0e7d2_row5_col5, #T_0e7d2_row6_col6, #T_0e7d2_row7_col7, #T_0e7d2_row8_col8, #T_0e7d2_row9_col9, #T_0e7d2_row10_col10, #T_0e7d2_row11_col11 {
#   background-color: #000000;
#   color: #f1f1f1;
# }
# #T_0e7d2_row0_col1, #T_0e7d2_row0_col11 {
#   background-color: #e9e9e9;
#   color: #000000;
# }
# #T_0e7d2_row0_col2, #T_0e7d2_row9_col8, #T_0e7d2_row11_col8 {
#   background-color: #afafaf;
#   color: #000000;
# }
# #T_0e7d2_row0_col3, #T_0e7d2_row6_col0 {
#   background-color: #bfbfbf;
#   color: #000000;
# }
# #T_0e7d2_row0_col4, #T_0e7d2_row5_col11 {
#   background-color: #c9c9c9;
#   color: #000000;
# }
# #T_0e7d2_row0_col5, #T_0e7d2_row8_col1 {
#   background-color: #eeeeee;
#   color: #000000;
# }
# #T_0e7d2_row0_col6, #T_0e7d2_row0_col10, #T_0e7d2_row1_col6, #T_0e7d2_row2_col4 {
#   background-color: #bebebe;
#   color: #000000;
# }
# #T_0e7d2_row0_col7, #T_0e7d2_row3_col6 {
#   background-color: #777777;
#   color: #f1f1f1;
# }
# #T_0e7d2_row0_col8, #T_0e7d2_row1_col2, #T_0e7d2_row1_col9, #T_0e7d2_row7_col10, #T_0e7d2_row7_col11, #T_0e7d2_row8_col0, #T_0e7d2_row10_col3, #T_0e7d2_row10_col4, #T_0e7d2_row10_col5, #T_0e7d2_row10_col6, #T_0e7d2_row10_col7, #T_0e7d2_row11_col1 {
#   background-color: #ffffff;
#   color: #000000;
# }
# #T_0e7d2_row0_col9, #T_0e7d2_row10_col9 {
#   background-color: #fafafa;
#   color: #000000;
# }
# #T_0e7d2_row1_col0 {
#   background-color: #d1d1d1;
#   color: #000000;
# }
# #T_0e7d2_row1_col3, #T_0e7d2_row1_col4, #T_0e7d2_row3_col4, #T_0e7d2_row4_col3 {
#   background-color: #c1c1c1;
#   color: #000000;
# }
# #T_0e7d2_row1_col5, #T_0e7d2_row11_col4 {
#   background-color: #f4f4f4;
#   color: #000000;
# }
# #T_0e7d2_row1_col7 {
#   background-color: #9f9f9f;
#   color: #f1f1f1;
# }
# #T_0e7d2_row1_col8, #T_0e7d2_row3_col1, #T_0e7d2_row4_col1, #T_0e7d2_row4_col2, #T_0e7d2_row6_col1 {
#   background-color: #d6d6d6;
#   color: #000000;
# }
# #T_0e7d2_row1_col10 {
#   background-color: #a0a0a0;
#   color: #f1f1f1;
# }
# #T_0e7d2_row1_col11, #T_0e7d2_row10_col2 {
#   background-color: #f1f1f1;
#   color: #000000;
# }
# #T_0e7d2_row2_col0, #T_0e7d2_row5_col3 {
#   background-color: #919191;
#   color: #f1f1f1;
# }
# #T_0e7d2_row2_col1 {
#   background-color: #fcfcfc;
#   color: #000000;
# }
# #T_0e7d2_row2_col3 {
#   background-color: #c3c3c3;
#   color: #000000;
# }
# #T_0e7d2_row2_col5, #T_0e7d2_row7_col2, #T_0e7d2_row9_col0 {
#   background-color: #d3d3d3;
#   color: #000000;
# }
# #T_0e7d2_row2_col6 {
#   background-color: #b8b8b8;
#   color: #000000;
# }
# #T_0e7d2_row2_col7 {
#   background-color: #909090;
#   color: #f1f1f1;
# }
# #T_0e7d2_row2_col8, #T_0e7d2_row11_col3 {
#   background-color: #e4e4e4;
#   color: #000000;
# }
# #T_0e7d2_row2_col9, #T_0e7d2_row4_col9 {
#   background-color: #f2f2f2;
#   color: #000000;
# }
# #T_0e7d2_row2_col10 {
#   background-color: #b0b0b0;
#   color: #000000;
# }
# #T_0e7d2_row2_col11 {
#   background-color: #cecece;
#   color: #000000;
# }
# #T_0e7d2_row3_col0 {
#   background-color: #bdbdbd;
#   color: #000000;
# }
# #T_0e7d2_row3_col2, #T_0e7d2_row4_col8 {
#   background-color: #dcdcdc;
#   color: #000000;
# }
# #T_0e7d2_row3_col5 {
#   background-color: #a5a5a5;
#   color: #f1f1f1;
# }
# #T_0e7d2_row3_col7 {
#   background-color: #212121;
#   color: #f1f1f1;
# }
# #T_0e7d2_row3_col8, #T_0e7d2_row11_col0 {
#   background-color: #e5e5e5;
#   color: #000000;
# }
# #T_0e7d2_row3_col9, #T_0e7d2_row8_col2 {
#   background-color: #fbfbfb;
#   color: #000000;
# }
# #T_0e7d2_row3_col10, #T_0e7d2_row4_col10, #T_0e7d2_row7_col1 {
#   background-color: #dfdfdf;
#   color: #000000;
# }
# #T_0e7d2_row3_col11, #T_0e7d2_row11_col2 {
#   background-color: #e6e6e6;
#   color: #000000;
# }
# #T_0e7d2_row4_col0 {
#   background-color: #c6c6c6;
#   color: #000000;
# }
# #T_0e7d2_row4_col5 {
#   background-color: #d4d4d4;
#   color: #000000;
# }
# #T_0e7d2_row4_col6 {
#   background-color: #a3a3a3;
#   color: #f1f1f1;
# }
# #T_0e7d2_row4_col7, #T_0e7d2_row5_col7 {
#   background-color: #767676;
#   color: #f1f1f1;
# }
# #T_0e7d2_row4_col11, #T_0e7d2_row5_col1 {
#   background-color: #f5f5f5;
#   color: #000000;
# }
# #T_0e7d2_row5_col0 {
#   background-color: #dadada;
#   color: #000000;
# }
# #T_0e7d2_row5_col2 {
#   background-color: #d8d8d8;
#   color: #000000;
# }
# #T_0e7d2_row5_col4 {
#   background-color: #c0c0c0;
#   color: #000000;
# }
# #T_0e7d2_row5_col6 {
#   background-color: #585858;
#   color: #f1f1f1;
# }
# #T_0e7d2_row5_col8, #T_0e7d2_row6_col8 {
#   background-color: #cccccc;
#   color: #000000;
# }
# #T_0e7d2_row5_col9, #T_0e7d2_row6_col11 {
#   background-color: #ececec;
#   color: #000000;
# }
# #T_0e7d2_row5_col10, #T_0e7d2_row8_col6 {
#   background-color: #cbcbcb;
#   color: #000000;
# }
# #T_0e7d2_row6_col2, #T_0e7d2_row9_col3 {
#   background-color: #d5d5d5;
#   color: #000000;
# }
# #T_0e7d2_row6_col3 {
#   background-color: #7a7a7a;
#   color: #f1f1f1;
# }
# #T_0e7d2_row6_col4 {
#   background-color: #a7a7a7;
#   color: #f1f1f1;
# }
# #T_0e7d2_row6_col5 {
#   background-color: #646464;
#   color: #f1f1f1;
# }
# #T_0e7d2_row6_col7 {
#   background-color: #505050;
#   color: #f1f1f1;
# }
# #T_0e7d2_row6_col9, #T_0e7d2_row10_col0 {
#   background-color: #e1e1e1;
#   color: #000000;
# }
# #T_0e7d2_row6_col10, #T_0e7d2_row8_col5, #T_0e7d2_row9_col2 {
#   background-color: #e2e2e2;
#   color: #000000;
# }
# #T_0e7d2_row7_col0 {
#   background-color: #939393;
#   color: #f1f1f1;
# }
# #T_0e7d2_row7_col3 {
#   background-color: #2b2b2b;
#   color: #f1f1f1;
# }
# #T_0e7d2_row7_col4 {
#   background-color: #949494;
#   color: #f1f1f1;
# }
# #T_0e7d2_row7_col5 {
#   background-color: #a9a9a9;
#   color: #f1f1f1;
# }
# #T_0e7d2_row7_col6 {
#   background-color: #606060;
#   color: #f1f1f1;
# }
# #T_0e7d2_row7_col8, #T_0e7d2_row9_col5 {
#   background-color: #d7d7d7;
#   color: #000000;
# }
# #T_0e7d2_row7_col9 {
#   background-color: #ededed;
#   color: #000000;
# }
# #T_0e7d2_row8_col3 {
#   background-color: #e8e8e8;
#   color: #000000;
# }
# #T_0e7d2_row8_col4, #T_0e7d2_row8_col9 {
#   background-color: #dedede;
#   color: #000000;
# }
# #T_0e7d2_row8_col7, #T_0e7d2_row9_col6 {
#   background-color: #b2b2b2;
#   color: #000000;
# }
# #T_0e7d2_row8_col10 {
#   background-color: #9a9a9a;
#   color: #f1f1f1;
# }
# #T_0e7d2_row8_col11 {
#   background-color: #b4b4b4;
#   color: #000000;
# }
# #T_0e7d2_row9_col1, #T_0e7d2_row11_col9 {
#   background-color: #f0f0f0;
#   color: #000000;
# }
# #T_0e7d2_row9_col4 {
#   background-color: #cacaca;
#   color: #000000;
# }
# #T_0e7d2_row9_col7 {
#   background-color: #999999;
#   color: #f1f1f1;
# }
# #T_0e7d2_row9_col10 {
#   background-color: #ababab;
#   color: #000000;
# }
# #T_0e7d2_row9_col11 {
#   background-color: #c7c7c7;
#   color: #000000;
# }
# #T_0e7d2_row10_col1 {
#   background-color: #e0e0e0;
#   color: #000000;
# }
# #T_0e7d2_row10_col8 {
#   background-color: #c2c2c2;
#   color: #000000;
# }
# #T_0e7d2_row10_col11 {
#   background-color: #6d6d6d;
#   color: #f1f1f1;
# }
# #T_0e7d2_row11_col5 {
#   background-color: #dbdbdb;
#   color: #000000;
# }
# #T_0e7d2_row11_col6 {
#   background-color: #e7e7e7;
#   color: #000000;
# }
# #T_0e7d2_row11_col7 {
#   background-color: #dddddd;
#   color: #000000;
# }
# #T_0e7d2_row11_col10 {
#   background-color: #575757;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_0e7d2">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_0e7d2_level0_col0" class="col_heading level0 col0" >fixed acidity</th>
#       <th id="T_0e7d2_level0_col1" class="col_heading level0 col1" >volatile acidity</th>
#       <th id="T_0e7d2_level0_col2" class="col_heading level0 col2" >citric acid</th>
#       <th id="T_0e7d2_level0_col3" class="col_heading level0 col3" >residual sugar</th>
#       <th id="T_0e7d2_level0_col4" class="col_heading level0 col4" >chlorides</th>
#       <th id="T_0e7d2_level0_col5" class="col_heading level0 col5" >free sulfur dioxide</th>
#       <th id="T_0e7d2_level0_col6" class="col_heading level0 col6" >total sulfur dioxide</th>
#       <th id="T_0e7d2_level0_col7" class="col_heading level0 col7" >density</th>
#       <th id="T_0e7d2_level0_col8" class="col_heading level0 col8" >pH</th>
#       <th id="T_0e7d2_level0_col9" class="col_heading level0 col9" >sulphates</th>
#       <th id="T_0e7d2_level0_col10" class="col_heading level0 col10" >alcohol</th>
#       <th id="T_0e7d2_level0_col11" class="col_heading level0 col11" >quality</th>
#     </tr>
#   </thead>
#   <tbody

# %% [markdown]
# С данными ок.

# %% [markdown]
# Разметим классы.

# %%
df.quality = np.where(df.quality < 7, 0, 1)

# %% [markdown]
# #### Общие соображения
#
# "Цель: научиться приобретать вино качеством от 7 и более (7, 8 и т.д.)...ведет по пути дата-сатаниста" K.Ю. Шилин
# Чего мы не хотим: покупать плохое вино (баллом ниже 7, те "нули"), значит минимизоровав
# $$
# Precision = \min\nolimits_{FP}\frac{TP}{TP+FP}
# $$
# добьемся желаемого.

# %% [markdown]
# # K-neighbours classifier

# %% [markdown]
#  Корреляция между содержанием сахара и плотностью не удивляет. Выкинем `density`, тк она коррелирует и с другими признаками. Стоит выкидывать высоко коррелированные признаки, т.к. kNN работает на расстояних между объектами.

# %%
df = df.drop(columns = 'density')
df.head()
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            6.4              0.17         0.34             1.5      0.091
# 1            8.0              0.42         0.36             5.0      0.037
# 2            6.7              0.27         0.25             8.0      0.053
# 3            5.2              0.21         0.31             1.7      0.048
# 4            7.6              0.48         0.37             1.2      0.034
#
#    free sulfur dioxide  total sulfur dioxide    pH  sulphates  alcohol  \
# 0                 42.0                 135.0  3.25       0.49      9.6
# 1                 34.0                 101.0  3.13       0.57     12.3
# 2                 54.0                 202.0  3.22       0.43      9.3
# 3                 17.0                  61.0  3.24       0.37     12.0
# 4                  5.0                  57.0  3.05       0.54     10.4
#
#    quality
# 0        1
# 1        1
# 2        0
# 3        1
# 4        0

# %%
X_train, X_test, y_train, y_test = train_test_split(df.drop(columns = ['quality']), df.quality, test_size=0.3,
                                                    stratify=df.quality)

# %% [markdown]
# Сделаем сначала $Grid Search$ с большим шагом по количеству соседей

# %%
knk = KNeighborsClassifier()

n_range = np.arange(1, 401, 10)

train_scores, test_scores = validation_curve(
    knk, X_train, y_train,
    param_name="n_neighbors", 
    param_range=n_range,
    cv=StratifiedKFold(shuffle=True), 
    scoring="roc_auc")


train_scores_mean = np.mean(train_scores, axis=1)
train_scores_std = np.std(train_scores, axis=1)
test_scores_mean = np.mean(test_scores, axis=1)
test_scores_std = np.std(test_scores, axis=1)

plt.figure(figsize=(15,10))

plt.title("Validation Curve with kNN")
plt.xlabel("$n-соседей$")
plt.ylabel("Score")
plt.ylim(0.5, 1.05)

plt.plot(n_range, train_scores_mean, label="Training score", color="darkorange")
plt.fill_between(n_range, train_scores_mean - train_scores_std,
                 train_scores_mean + train_scores_std, alpha=0.2,
                 color="darkorange")
plt.plot(n_range, test_scores_mean, label="Cross-validation score",
             color="navy")
plt.fill_between(n_range, test_scores_mean - test_scores_std,
                 test_scores_mean + test_scores_std, alpha=0.2,
                 color="navy")
plt.xticks(n_range)
plt.legend(loc="best")
plt.show()

# %% [markdown]
# Сделаем подробный $Grid Search$ от 80 до 140 по ROC AUC с подбором препроцессинга и др. гиперпараметров

# %%
pipe = Pipeline([('preprocessing', MinMaxScaler()), 
                 ('classifier',    KNeighborsClassifier())])

# определим кросс-валидацию
kfold = StratifiedKFold(n_splits=15, shuffle=True)

# Определим параметры для перебора по решетке

p = np.arange(1,5)
weights = ['uniform','distance']
n_neighbors = np.arange(80,140)
scaling = [ MinMaxScaler(), StandardScaler(),RobustScaler() ]


# параметры решетки
param_grid =[
    {'preprocessing': scaling, 
     'classifier': [KNeighborsClassifier()],
         'classifier__n_neighbors': n_neighbors,
         'classifier__p': p,
         'classifier__weights': weights
     }]

grid = GridSearchCV(pipe, param_grid, cv=kfold, scoring = 'roc_auc')
grid.fit(X_train,y_train)
grid
# Out:
# GridSearchCV(cv=StratifiedKFold(n_splits=15, random_state=None, shuffle=True),
#              estimator=Pipeline(steps=[('preprocessing', MinMaxScaler()),
#                                        ('classifier', KNeighborsClassifier())]),
#              param_grid=[{'classifier': [KNeighborsClassifier(n_neighbors=116,
#                                                               p=1,
#                                                               weights='distance')],
#                           'classifier__n_neighbors': array([ 80,  81,  82,  83,  84,  85,  86,  87,  88,  89,  90,  91,  92,
#         93,  94,  95,  96,  97,  98,  99, 100, 101, 102, 103, 104, 105,
#        106, 107, 108, 109, 110, 111, 112, 113, 114, 115, 116, 117, 118,
#        119, 120, 121, 122, 123, 124, 125, 126, 127, 128, 129, 130, 131,
#        132, 133, 134, 135, 136, 137, 138, 139]),
#                           'classifier__p': array([1, 2, 3, 4]),
#                           'classifier__weights': ['uniform', 'distance'],
#                           'preprocessing': [MinMaxScaler(), StandardScaler(),
#                                             RobustScaler()]}],
#              scoring='roc_auc')

# %%
grid_result = pd.DataFrame(grid.cv_results_).sort_values(["rank_test_score",'std_test_score']).T
grid_result
# Out:
#                                                                             868   \
# mean_fit_time                                                           0.003556
# std_fit_time                                                            0.000513
# mean_score_time                                                         0.004855
# std_score_time                                                          0.000359
# param_classifier               KNeighborsClassifier(n_neighbors=116, p=1, wei...
# param_classifier__n_neighbors                                                116
# param_classifier__p                                                            1
# param_classifier__weights                                               distance
# param_preprocessing                                             StandardScaler()
# params                         {'classifier': KNeighborsClassifier(n_neighbor...
# split0_test_score                                                       0.793103
# split1_test_score                                                       0.900531
# split2_test_score                                                       0.743369
# split3_test_score                                                       0.840186
# split4_test_score                                                       0.861406
# split5_test_score                                                       0.804377
# split6_test_score                                                       0.824934
# split7_test_score                                                       0.843137
# split8_test_score                                                       0.876944
# split9_test_score                                                       0.783638
# split10_test_score                                                      0.787018
# split11_test_score                                                      0.848546
# split12_test_score                                                       0.85783
# split13_test_score                                                      0.857143
# split14_test_score                                                      0.789148
# mean_test_score                                                         0.827421
# std_test_score                                                          0.041159
# rank_test_score                                                                1
#
#                                                                             100   \
# mean_fit_time                                                             0.0036
# std_fit_time                                                             0.00049
# mean_score_time                                                         0.004335
# std_score_time                                                          0.000472
# param_classifier               KNeighborsClassifier(n_neighbors=116, p=1, wei...
# param_classifier__n_neighbors                                                 84
# param_classifier__p                                                            1
# param_classifier__weights                                               distance
# param_preprocessing                                             StandardScaler()
# params                         {'classifier': KNeighborsClassifier(n_neighbor...
# split0_test_score                                                       0.796419
# split1_test_score                                                        0.90252
# split2_test_score                                                       0.748674
# split3_test_score                                                       0.841512
# split4_test_score                                                       0.860743
# split5_test_score                                                       0.811671
# split6_test_score                                                        0.81565
# split7_test_score                                                       0.848546
# split8_test_score                                                        0.86883
# split9_test_score                                                        0.78499
# split10_test_score                                                      0.788371
# split11_test_score                                                      0.852603
# split12_test_score                                                      0.851648
# split13_test_score                                                      0.853709
# split14_test_score                                                       0.78022
# mean_test_score                                                         0.827074
# std_test_score                                                          0.040102
# rank_test_score                                                                2
#
#                                                                             892   \
# mean_fit_time                                                           0.003637
# std_fit_time                                                             0.00053
# mean_score_time                                                         0.004862
# std_score_time                                                          0.000299
# param_classifier               KNeighborsClassifier(n_neighbors=116, p=1, wei...
# param_classifier__n_neighbors                                                117
# param_classifier__p                                                            1
# param_classifier__weights                                               distance
# param_preprocessing                                             StandardScaler()
# params                         {'classifier': KNeighborsClassifier(n_neighbor...
# split0_test_score                                                        0.79244
# split1_test_score                                                       0.899867
# split2_test_score                                                       0.742042
# split3_test_score                                                       0.840849
# split4_test_score                                                       0.861406
# split5_test_score                                                       0.804377
# split6_test_score                                                       0.822944
# split7_test_score                                                       0.843813
# split8_test_score                                                       0.874915
# split9_test_score                                                        0.78499
# split10_test_score                                                      0.787694
# split11_test_score                                                      0.848546
# split12_test_score                                                      0.857143
# split13_test_score                                                      0.855082
# split14_test_score                                                      0.788462
# mean_test_score                                                         0.826971
# std_test_score                                                          0.040956
# rank_test_score                                                                3
#
#                                                                             52    \
# mean_fit_time                                                           0.003702
# std_fit_time                                                            0.000439
# mean_score_time                                                         0.004069
# std_score_time                                                          0.000298
# param_classifier               KNeighborsClassifier(n_neighbors=116, p=1, wei...
# param_classifier__n_neighbors                                                 82
# param_classifier__p                                                            1
# param_classifier__weights                                               distance
# param_preprocessing                                             StandardScaler()
# params                         {'classifier': KNeighborsClassifier(n_neighbor...
# split0_test_score                                                        0.79443
# split1_test_score                                                       0.905172
# split2_test_score                                                       0.750663
# split3_test_score                                                       0.841512
# split4_test_score                                                       0.861406
# split5_test_score                                                       0.811671
# split6_test_score                                                       0.812997
# split7_test_score                                                       0.845842
# split8_test_score                                                       0.866802
# split9_test_score                                                       0.787018
# split10_test_score                                                      0.789047
# split11_test_score                                                      0.854632
# split12_test_score                                                      0.855769
# split13_test_score                                                      0.848901
# split14_test_score                                                      0.778159
# mean_test_score                                                         0.826935
# std_test_score                                                          0.040215
# rank_test_score                                                                4
#
#                                                                             76    \
# mean_fit_time                                                             0.0036
# std_fit_time                                                            0.000611
# mean_score_time                                                         0.004401
# std_score_time                                                           0.00049
# param_classifier               KNeighborsClassifier(n_neighbors=116, p=1, wei...
# param_classifier__n_neighbors                                                 83
# param_classifier__p                                                            1
# param_classifier__weights                                               distance
# param_preprocessing                                             StandardScaler()
# params                         {'classifier': KNeighborsClassifier(n_neighbor...
# split0_test_score                                                       0.795756
# split1_test_score                                                       0.901857
# split2_test_score                                                       0.750663
# split3_test_score                                                       0.842175
# split4_test_score                                                       0.861406
# split5_test_score                                                       0.808355
# split6_test_score                                                        0.81366
# split7_test_score                                                        0.84787
# split8_test_score                                                       0.867478
# split9_test_score                                                       0.784314
# split10_test_score                                                      0.791751
# split11_test_score                                                      0.855308
# split12_test_score                                                      0.854396
# split13_test_score                                                      0.850962
# split14_test_score                                                      0.776099
# mean_test_score                                                         0.826803
# std_test_score                                                          0.040168
# rank_test_score                                                                5
#
#                                                                             172   \
# mean_fit_time                                                           0.003604
# std_fit_time                                                            0.000491
# mean_score_time                                                         0.004481
# std_score_time                                                           0.00049
# param_classifier               KNeighborsClassifier(n_neighbors=116, p=1, wei...
# param_classifier__n_neighbors                                                 87
# param_classifier__p                                                            1
# param_classifier__weights                                               distance
# param_preprocessing                                             StandardScaler()
# params                         {'classifier': KNeighborsClassifier(n_neighbor...
# split0_test_score                                                       0.795093
# split1_test_score                                                       0.905172
# split2_test_score                                                       0.750663
# split3_test_score                                                       0.840186
# split4_test_score                                                       0.857427
# split5_test_score                                                       0.809019
# split6_test_score                                                       0.817639
# split7_test_score                                                       0.845166
# split8_test_score                                                       0.870859
# split9_test_score                                                       0.784314
# split10_test_score                                                      0.787018
# split11_test_score                                                      0.849899
# split12_test_score                                                      0.853022
# split13_test_score                                                      0.853709
# split14_test_score                                                      0.780907
# mean_test_score                                                         0.826673
# std_test_score                                                          0.040149
# rank_test_score                                                                6
#
#                                                                             772   \
# mean_fit_time                                                           0.003608
# std_fit_time                                                            0.000456
# mean_score_time                                                         0.004638
# std_score_time                                                            0.0005
# param_classifier               KNeighborsClassifier(n_neighbors=116, p=1, wei...
# param_classifier__n_neighbors                                                112
# param_classifier__p                                                            1
# param_classifier__weights                                               distance
# param_preprocessing                                             StandardScaler()
# params                         {'classifier': KNeighborsClassifier(n_neighbor...
# split0_test_score                                                       0.787798
# split1_test_score                                                       0.900531
# split2_test_score                                                       0.742706
# split3_test_score                                                       0.840849
# split4_test_score                                                       0.862732
# split5_test_score                                                       0.806366
# split6_test_score                                                       0.825597
# split7_test_score                                                       0.837728
# split8_test_score                                                       0.878296
# split9_test_score                                                       0.780933
# split10_test_score                                                      0.786342
# split11_test_score                                                      0.851251
# split12_test_score                                                      0.856456
# split13_test_score                                                      0.851648
# split14_test_score                                                      0.789835
# mean_test_score                                                         0.826605
# std_test_score                                                          0.041561
# rank_test_score                                                                7
#
#                                                                             4     \
# mean_fit_time                                                           0.003673
# std_fit_time                                                            0.000432
# mean_score_time                                                          0.00404
# std_score_time                                                          0.000282
# param_classifier               KNeighborsClassifier(n_neighbors=116, p=1, wei...
# param_classifier__n_neighbors                                                 80
# param_classifier__p                                                            1
# param_classifier__weights                                               distance
# param_preprocessing                                             StandardScaler()
# params                         {'classifier': KNeighborsClassifier(n_neighbor...
# split0_test_score                                                       0.791114
# split1_test_score                                                       0.905836
# split2_test_score                                                           0.75
# split3_test_score                                                       0.839523
# split4_test_score                                                        0.85809
# split5_test_score                                                       0.809682
# split6_test_score                                                       0.818966
# split7_test_score                                                       0.845842
# split8_test_score                                                       0.863421
# split9_test_score                                                        0.79378
# split10_test_score                                                      0.791751
# split11_test_score                                                      0.853279
# split12_test_score                                                      0.851648
# split13_test_score                                                      0.846154
# split14_test_score                                                      0.778846
# mean_test_score                                                         0.826529
# std_test_score                                                          0.039096
# rank_test_score                                                                8
#
#                                                                             916   \
# mean_fit_time                                                           0.003667
# std_fit_time                                                            0.000471
# mean_score_time                                                         0.004801
# std_score_time                                                            0.0004
# param_classifier               KNeighborsClassifier(n_neighbors=116, p=1, wei...
# param_classifier__n_neighbors                                                118
# param_classifier__p                                                            1
# param_classifier__weights                                               distance
# param_preprocessing                                             StandardScaler()
# params                         {'classifier': KNeighborsClassifier(n_neighbor...
# split0_test_score                                                       0.793103
# split1_test_score                                                       0.899867
# split2_test_score                                                       0.740053
# split3_test_score                                                       0.842175
# split4_test_score                                                        0.86008
# split5_test_score                                                       0.801061
# split6_test_score                                                       0.821618
# split7_test_score                                                       0.845166
# split8_test_score                                                       0.873563
# split9_test_score                                                        0.78499
# split10_test_score                                                      0.788371
# split11_test_score                                                      0.847194
# split12_test_score                                                      0.857143
# split13_test_score                                                      0.855082
# split14_test_score                                                      0.786401
# mean_test_score                                                         0.826391
# std_test_score                                                           0.04127
# rank_test_score                                                                9
#
#                                                                             844   \
# mean_fit_time                                                             0.0035
# std_fit_time                                                            0.000447
# mean_score_time                                                         0.004777
# std_score_time                                                          0.000499
# param_classifier               KNeighborsClassifier(n_neighbors=116, p=1, wei...
# param_classifier__n_neighbors                                                115
# param_classifier__p                                                            1
# param_classifier__weights                                               distance
# param_preprocessing                                             StandardScaler()
# params                         {'classifier': KNeighborsClassifier(n_neighbor...
# split0_test_score                                                       0.791114
# split1_test_score                                                       0.900531
# split2_test_score                                                       0.740053
# split3_test_score                                                       0.840186
# split4_test_score                                                       0.858753
# split5_test_score                                                       0.801724
# split6_test_score                                                       0.822944
# split7_test_score                                                       0.842461
# split8_test_score                                                        0.87762
# split9_test_score                                                       0.782961
# split10_test_score                                                      0.787694
# split11_test_score                                                      0.849222
# split12_test_score                                                      0.858516
# split13_test_score                                                      0.853709
# split14_test_score                                                      0.787088
# mean_test_score                                                         0.826305
# std_test_score                                                          0.041764
# rank_test_score                                                               10
#
#                                ...  \
# mean_fit_time                  ...
# std_fit_time                   ...
# mean_score_time                ...
# std_score_time                 ...
# param_classifier               ...
# param_classifier__n_neighbors  ...
# param_classifier__p            ...
# param_classifier__weights      ...
# param_preprocessing            ...
# params                         ...
# split0_test_score              ...
# split1_test_score              ...
# split2_test_score              ...
# split3_test_score              ...
# split4_test_score              ...
# split5_test_score              ...
# split6_test_score              ...
# split7_test_score              ...
# split8_test_score              ...
# split9_test_score              ...
# split10_test_score             ...
# split11_test_score             ...
# split12_test_score             ...
# split13_test_score             ...
# split14_test_score             ...
# mean_test_score                ...
# std_test_score                 ...
# rank_test_score                ...
#
#                                                                             1196  \
# mean_fit_time                                                           0.004975
# std_fit_time                                                            0.000107
# mean_score_time                                                         0.019072
# std_score_time                                                          0.000254
# param_classifier               KNeighborsClassifier(n_neighbors=116, p=1, wei...
# param_classifier__n_neighbors                                                129
# param_classifier__p                                                            4
# param_classifier__weights                                                uniform
# param_preprocessing                                               RobustScaler()
# params                         {'classifier': KNeighborsClassifier(n_neighbor...
# split0_test_score                                                       0.835544
# split1_test_score                                                       0.860411
# split2_test_score                                                       0.702255
# split3_test_score                                                       0.798408
# split4_test_score                                                       0.826592
# split5_test_score                                                       0.757294
# split6_test_score                                                       0.780836
# split7_test_score                                                       0.838404
# split8_test_score                                                        0.84449
# split9_test_score                                                       0.743408
# split10_test_score                                                      0.767748
# split11_test_score                                                      0.788709
# split12_test_score                                                       0.79842
# split13_test_score                                                      0.799794
# split14_test_score                                                      0.724245
# mean_test_score                                                         0.791104
# std_test_score                                                          0.044532
# rank_test_score                                                             1431
#
#                                                                             1172  \
# mean_fit_time                                                            0.00515
# std_fit_time                                                            0.000382
# mean_score_time                                                          0.01897
# std_score_time                                                          0.000523
# param_classifier               KNeighborsClassifier(n_neighbors=116, p=1, wei...
# param_classifier__n_neighbors                                                128
# param_classifier__p                                                            4
# param_classifier__weights                                                uniform
# param_preprocessing                                               RobustScaler()
# params                         {'classifier': KNeighborsClassifier(n_neighbor...
# split0_test_score                                                       0.833223
# split1_test_score                                                       0.861737
# split2_test_score                                                       0.703581
# split3_test_score                                                        0.79443
# split4_test_score                                                       0.826592
# split5_test_score                                                       0.760942
# split6_test_score                                                       0.779841
# split7_test_score                                                       0.840095
# split8_test_score                                                       0.841109
# split9_test_score                                                       0.743408
# split10_test_score                                                      0.769101
# split11_test_score                                                      0.787356
# split12_test_score                                                      0.797734
# split13_test_score                                                       0.79842
# split14_test_score                                                      0.722871
# mean_test_score                                                         0.790696
# std_test_score                                                          0.044087
# rank_test_score                                                             1432
#
#                                                                             1244  \
# mean_fit_time                                                           0.004961
# std_fit_time                                                            0.000147
# mean_score_time                                                          0.01884
# std_score_time                                                          0.000487
# param_classifier               KNeighborsClassifier(n_neighbors=116, p=1, wei...
# param_classifier__n_neighbors                                                131
# param_classifier__p                                                            4
# param_classifier__weights                                                uniform
# param_preprocessing                                               RobustScaler()
# params                         {'classifier': KNeighborsClassifier(n_neighbor...
# split0_test_score                                                        0.83256
# split1_test_score                                                       0.861406
# split2_test_score                                                       0.699602
# split3_test_score                                                       0.796751
# split4_test_score                                                       0.824271
# split5_test_score                                                        0.76061
# split6_test_score                                                       0.785146
# split7_test_score                                                       0.840433
# split8_test_score                                                       0.843813
# split9_test_score                                                       0.740703
# split10_test_score                                                      0.769777
# split11_test_score                                                      0.783976
# split12_test_score                                                      0.796016
# split13_test_score                                                      0.803228
# split14_test_score                                                       0.72081
# mean_test_score                                                         0.790607
# std_test_score                                                           0.04509
# rank_test_score                                                             1433
#
#                                                                             1388  \
# mean_fit_time                                                           0.005001
# std_fit_time                                                                 0.0
# mean_score_time                                                         0.018738
# std_score_time                                                          0.000442
# param_classifier               KNeighborsClassifier(n_neighbors=116, p=1, wei...
# param_classifier__n_neighbors                                                137
# param_classifier__p                                                            4
# param_classifier__weights                                                uniform
# param_preprocessing                                               RobustScaler()
# params                         {'classifier': KNeighborsClassifier(n_neighbor...
# split0_test_score                                                       0.831565
# split1_test_score                                                        0.86008
# split2_test_score                                                       0.708886
# split3_test_score                                                       0.794761
# split4_test_score                                                        0.82195
# split5_test_score                                                        0.76061
# split6_test_score                                                       0.785809
# split7_test_score                                                       0.832319
# split8_test_score                                                       0.845166
# split9_test_score                                                        0.74476
# split10_test_score                                                      0.769439
# split11_test_score                                                      0.784314
# split12_test_score                                                      0.789835
# split13_test_score                                                      0.810096
# split14_test_score                                                      0.718407
# mean_test_score                                                         0.790533
# std_test_score                                                          0.043208
# rank_test_score                                                             1434
#
#                                                                             1220  \
# mean_fit_time                                                            0.00506
# std_fit_time                                                            0.000257
# mean_score_time                                                         0.018913
# std_score_time                                                          0.000432
# param_classifier               KNeighborsClassifier(n_neighbors=116, p=1, wei...
# param_classifier__n_neighbors                                                130
# param_classifier__p                                                            4
# param_classifier__weights                                                uniform
# param_preprocessing                                               RobustScaler()
# params                         {'classifier': KNeighborsClassifier(n_neighbor...
# split0_test_score                                                       0.836207
# split1_test_score                                                       0.861074
# split2_test_score                                                       0.695623
# split3_test_score                                                       0.797082
# split4_test_score                                                       0.825928
# split5_test_score                                                       0.760279
# split6_test_score                                                       0.782493
# split7_test_score                                                       0.840095
# split8_test_score                                                       0.843813
# split9_test_score                                                       0.743408
# split10_test_score                                                      0.768087
# split11_test_score                                                       0.78668
# split12_test_score                                                      0.795673
# split13_test_score                                                      0.801168
# split14_test_score                                                       0.71978
# mean_test_score                                                         0.790493
# std_test_score                                                          0.045845
# rank_test_score                                                             1435
#
#                                                                             1268  \
# mean_fit_time                                                           0.005098
# std_fit_time                                                            0.000207
# mean_score_time                                                         0.018946
# std_score_time                                                          0.000481
# param_classifier               KNeighborsClassifier(n_neighbors=116, p=1, wei...
# param_classifier__n_neighbors                                                132
# param_classifier__p                                                            4
# param_classifier__weights                                                uniform
# param_preprocessing                                               RobustScaler()
# params                         {'classifier': KNeighborsClassifier(n_neighbor...
# split0_test_score                                                       0.830239
# split1_test_score                                                       0.862401
# split2_test_score                                                       0.701592
# split3_test_score                                                       0.792772
# split4_test_score                                                       0.824271
# split5_test_score                                                       0.763594
# split6_test_score                                                       0.784483
# split7_test_score                                                       0.840095
# split8_test_score                                                       0.843475
# split9_test_score                                                       0.739689
# split10_test_score                                                      0.769439
# split11_test_score                                                      0.783976
# split12_test_score                                                      0.796016
# split13_test_score                                                      0.804602
# split14_test_score                                                       0.71875
# mean_test_score                                                         0.790359
# std_test_score                                                          0.044922
# rank_test_score                                                             1436
#
#                                                                             1364  \
# mean_fit_time                                                           0.004993
# std_fit_time                                                            0.000264
# mean_score_time                                                         0.019006
# std_score_time                                                          0.000449
# param_classifier               KNeighborsClassifier(n_neighbors=116, p=1, wei...
# param_classifier__n_neighbors                                                136
# param_classifier__p                                                            4
# param_classifier__weights                                                uniform
# param_preprocessing                                               RobustScaler()
# params                         {'classifier': KNeighborsClassifier(n_neighbor...
# split0_test_score                                                       0.829244
# split1_test_score                                                       0.859748
# split2_test_score                                                        0.70557
# split3_test_score                                                       0.793103
# split4_test_score                                                       0.823276
# split5_test_score                                                       0.762931
# split6_test_score                                                        0.78183
# split7_test_score                                                       0.835024
# split8_test_score                                                       0.845504
# split9_test_score                                                        0.74476
# split10_test_score                                                      0.771129
# split11_test_score                                                      0.780595
# split12_test_score                                                      0.790522
# split13_test_score                                                      0.808036
# split14_test_score                                                      0.720467
# mean_test_score                                                         0.790116
# std_test_score                                                          0.043366
# rank_test_score                                                             1437
#
#                                                                             1292  \
# mean_fit_time                                                            0.00491
# std_fit_time                                                            0.000259
# mean_score_time                                                         0.018863
# std_score_time                                                          0.000424
# param_classifier               KNeighborsClassifier(n_neighbors=116, p=1, wei...
# param_classifier__n_neighbors                                                133
# param_classifier__p                                                            4
# param_classifier__weights                                                uniform
# param_preprocessing                                               RobustScaler()
# params                         {'classifier': KNeighborsClassifier(n_neighbor...
# split0_test_score                                                       0.831565
# split1_test_score                                                       0.859748
# split2_test_score                                                       0.701592
# split3_test_score                                                       0.789788
# split4_test_score                                                       0.822944
# split5_test_score                                                       0.763594
# split6_test_score                                                       0.781499
# split7_test_score                                                       0.836038
# split8_test_score                                                       0.843137
# split9_test_score                                                       0.742055
# split10_test_score                                                      0.769439
# split11_test_score                                                      0.783638
# split12_test_score                                                      0.794299
# split13_test_score                                                      0.804945
# split14_test_score                                                      0.722184
# mean_test_score                                                         0.789764
# std_test_score                                                          0.043824
# rank_test_score                                                             1438
#
#                                                                             1340  \
# mean_fit_time                                                           0.005134
# std_fit_time                                                             0.00034
# mean_score_time                                                         0.018804
# std_score_time                                                          0.000542
# param_classifier               KNeighborsClassifier(n_neighbors=116, p=1, wei...
# param_classifier__n_neighbors                                                135
# param_classifier__p                                                            4
# param_classifier__weights                                                uniform
# param_preprocessing                                               RobustScaler()
# params                         {'classifier': KNeighborsClassifier(n_neighbor...
# split0_test_score                                                       0.826923
# split1_test_score                                                       0.861074
# split2_test_score                                                       0.704244
# split3_test_score                                                       0.793103
# split4_test_score                                                       0.822281
# split5_test_score                                                       0.760942
# split6_test_score                                                       0.783488
# split7_test_score                                                       0.836376
# split8_test_score                                                       0.845166
# split9_test_score                                                        0.74476
# split10_test_score                                                      0.769101
# split11_test_score                                                      0.782285
# split12_test_score                                                      0.794643
# split13_test_score                                                      0.803571
# split14_test_score                                                      0.718407
# mean_test_score                                                         0.789758
# std_test_score                                                          0.043799
# rank_test_score                                                             1439
#
#                                                                             1316
# mean_fit_time                                                           0.005101
# std_fit_time                                                            0.000271
# mean_score_time                                                         0.018338
# std_score_time                                                          0.000471
# param_classifier               KNeighborsClassifier(n_neighbors=116, p=1, wei...
# param_classifier__n_neighbors                                                134
# param_classifier__p                                                            4
# param_classifier__weights                                                uniform
# param_preprocessing                                               RobustScaler()
# params                         {'classifier': KNeighborsClassifier(n_neighbor...
# split0_test_score                                                       0.829907
# split1_test_score                                                       0.860411
# split2_test_score                                                       0.704244
# split3_test_score                                                       0.790782
# split4_test_score                                                       0.822613
# split5_test_score                                                       0.761936
# split6_test_score                                                       0.784151
# split7_test_score                                                       0.832995
# split8_test_score                                                       0.843475
# split9_test_score                                                       0.743746
# split10_test_score                                                      0.767748
# split11_test_score                                                      0.783976
# split12_test_score                                                      0.794299
# split13_test_score                                                      0.802885
# split14_test_score                                                      0.719437
# mean_test_score                                                         0.789507
# std_test_score                                                          0.043458
# rank_test_score                                                             1440
#
# [28 rows x 1440 columns]

# %%
mask = grid_result.index[grid_result.index.str.endswith("_test_score")][:-3]
tabl = grid_result.loc[mask].iloc[:,:10]
sns.boxplot(data=tabl);

# %%
pipe_knn = Pipeline([('preprocessing', StandardScaler()), 
                    ('classifier',    KNeighborsClassifier(n_neighbors=84, p = 1, weights='distance'))])
pipe_knn.fit(X_train, y_train)
# Out:
# Pipeline(steps=[('preprocessing', StandardScaler()),
#                 ('classifier',
#                  KNeighborsClassifier(n_neighbors=84, p=1,
#                                       weights='distance'))])

# %% [markdown]
# Подёргаем treshhold

# %%
thresholds = np.unique(pipe_knn.predict_proba(X_test)[:,1])

max_precision, max_threshold = 0, 0
y_pred_proba = pipe_knn.predict_proba(X_test)[:,1]

for threshold in thresholds:
        # Применение порога к вероятностям классов
        y_pred_raw = y_pred_proba > threshold
        # Преобразование булевых значений в целочисленные
        y_pred = y_pred_raw.astype(int)
        # Вычисление precision
        pre = fbeta_score(y_test, y_pred, beta = 0.2)
        if pre > max_precision:
            max_precision, max_threshold = pre, threshold
print(f'Treshold: {max_threshold} fbeta {max_precision}')
# Out:
# Treshold: 0.6865884799878101 fbeta 0.9902213072568193

# %%
y_pred = (pipe_knn.predict_proba(X_test)[:,1] > max_threshold).astype(int)

print('precision', precision_score(y_test, y_pred))
print('recall', recall_score(y_test, y_pred))
print('fbeta', fbeta_score(y_test, y_pred, beta = 0.2))
print('ROC AUC', roc_auc_score(y_test, y_pred))
# Out:
# precision 0.8275862068965517
# recall 0.3870967741935484
# fbeta 0.7928843710292248
# ROC AUC 0.670958025650991

# %%
pr, rec = [], []

for i in range(1000):
    X_train, X_test, y_train, y_test = train_test_split(df.drop(columns = ['quality']), df.quality, test_size=0.3,
                                                    stratify=df.quality)
    
    pipe_knn = Pipeline([('preprocessing', StandardScaler()), 
                    ('classifier',    KNeighborsClassifier(n_neighbors=80, p = 1, weights='distance'))])
    pipe_knn.fit(X_train, y_train)
    
    y_pred = (pipe_knn.predict_proba(X_test)[:,1] > max_threshold).astype(int)
    
    pr.append(precision_score(y_test, y_pred))
    rec.append(recall_score(y_test, y_pred))

# %%
print('mean precision', np.array(pr).mean())
print('std precision', np.array(pr).std())
print('mean recall', np.array(rec).mean())
print('std recall', np.array(fbeta).std())
#проверка на устойчивость
# Out:
# mean precision 0.8209796565706535
# std precision 0.048326047666338655
# mean recall 0.26482795698924727
# std recall 0.033428327069327066

# %% [markdown]
# ## Logistic Regression

# %% [markdown]
# #### Общие соображения
#
# Понадеясь на регуляризацию, не будем выкидывать высоко коррелированные признаки или будем....

# %%
path_train = 'train.csv' 
df = pd.read_csv(path_train)
df.quality = np.where(df.quality < 7, 0, 1)
df = df.drop(columns = 'density') #будем всё таки

# %%
X_train, X_test, y_train, y_test = train_test_split(df.drop(columns = ['quality']), df.quality, test_size=0.3)

# %%
pipe = Pipeline([('preprocessing', MinMaxScaler()),
                 ('classifier', LogisticRegression())])

kfold = StratifiedKFold(n_splits=10, shuffle=True)
scaling = [ MinMaxScaler(), StandardScaler(),RobustScaler(), Normalizer()]

param_grid =[
    {'preprocessing': scaling,'classifier__penalty': ['l2'], 
         'classifier__solver': ['newton-cg' ,'lbfgs', 'liblinear', 'sag', 'saga'],
         'classifier__tol' : [1e-1, 1e-2, 1e-3, 1e-4],
         'classifier__class_weight' : ['balanced', None]},
    {'preprocessing': scaling,'classifier__penalty': ['l1'], 
         'classifier__solver': ['liblinear', 'saga'],
         'classifier__tol' : [1e-1, 1e-2, 1e-3, 1e-4],
         'classifier__class_weight' : ['balanced', None]},
    {'preprocessing': scaling,'classifier__penalty': [None], 
         'classifier__solver': ['newton-cg' ,'lbfgs', 'newton-cholesky', 'sag', 'saga'],
         'classifier__tol' : [1e-1, 1e-2, 1e-3, 1e-4],
         'classifier__class_weight' : ['balanced', None]}
    ]

grid = GridSearchCV(pipe, param_grid, cv = kfold, scoring='roc_auc')
grid.fit(X_train, y_train)
grid
# Out:
# C:\ProgramData\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\ProgramData\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\ProgramData\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\ProgramData\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\ProgramData\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\ProgramData\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\ProgramData\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\ProgramData\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\ProgramData\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\ProgramData\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\ProgramData\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\ProgramData\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\ProgramData\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\ProgramData\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\ProgramData\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\ProgramData\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\ProgramData\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\ProgramData\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\ProgramData\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\ProgramData\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\ProgramData\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\ProgramData\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\ProgramData\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\ProgramData\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\ProgramData\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\ProgramData\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\ProgramData\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\ProgramData\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\ProgramData\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\ProgramData\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\ProgramData\anaconda3\lib\site-packages\sklearn\linear_model\_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# C:\ProgramData\anaconda3\lib\site-packages\sklearn\linear_model\_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# C:\ProgramData\anaconda3\lib\site-packages\sklearn\linear_model\_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# C:\ProgramData\anaconda3\lib\site-packages\sklearn\linear_model\_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# C:\ProgramData\anaconda3\lib\site-packages\sklearn\linear_model\_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# C:\ProgramData\anaconda3\lib\site-packages\sklearn\linear_model\_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# C:\ProgramData\anaconda3\lib\site-packages\sklearn\linear_model\_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# C:\ProgramData\anaconda3\lib\site-packages\sklearn\linear_model\_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# C:\ProgramData\anaconda3\lib\site-packages\sklearn\linear_model\_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# C:\ProgramData\anaconda3\lib\site-packages\sklearn\linear_model\_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# C:\ProgramData\anaconda3\lib\site-packages\sklearn\linear_model\_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# C:\ProgramData\anaconda3\lib\site-packages\sklearn\linear_model\_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# C:\ProgramData\anaconda3\lib\site-packages\sklearn\linear_model\_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# C:\ProgramData\anaconda3\lib\site-packages\sklearn\linear_model\_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# C:\ProgramData\anaconda3\lib\site-packages\sklearn\linear_model\_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# C:\ProgramData\anaconda3\lib\site-packages\sklearn\linear_model\_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# C:\ProgramData\anaconda3\lib\site-packages\sklearn\linear_model\_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# C:\ProgramData\anaconda3\lib\site-packages\sklearn\linear_model\_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# C:\ProgramData\anaconda3\lib\site-packages\sklearn\linear_model\_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# C:\ProgramData\anaconda3\lib\site-packages\sklearn\linear_model\_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# C:\ProgramData\anaconda3\lib\site-packages\sklearn\linear_model\_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# C:\ProgramData\anaconda3\lib\site-packages\sklearn\linear_model\_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# C:\ProgramData\anaconda3\lib\site-packages\sklearn\linear_model\_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# C:\ProgramData\anaconda3\lib\site-packages\sklearn\linear_model\_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# C:\ProgramData\anaconda3\lib\site-packages\sklearn\linear_model\_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# C:\ProgramData\anaconda3\lib\site-packages\sklearn\linear_model\_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# C:\ProgramData\anaconda3\lib\site-packages\sklearn\linear_model\_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# C:\ProgramData\anaconda3\lib\site-packages\sklearn\linear_model\_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# C:\ProgramData\anaconda3\lib\site-packages\sklearn\linear_model\_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# C:\ProgramData\anaconda3\lib\site-packages\sklearn\linear_model\_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# C:\ProgramData\anaconda3\lib\site-packages\sklearn\linear_model\_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# C:\ProgramData\anaconda3\lib\site-packages\sklearn\linear_model\_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# C:\ProgramData\anaconda3\lib\site-packages\sklearn\linear_model\_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# C:\ProgramData\anaconda3\lib\site-packages\sklearn\linear_model\_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# C:\ProgramData\anaconda3\lib\site-packages\sklearn\linear_model\_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# C:\ProgramData\anaconda3\lib\site-packages\sklearn\linear_model\_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# C:\ProgramData\anaconda3\lib\site-packages\sklearn\linear_model\_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# C:\ProgramData\anaconda3\lib\site-packages\sklearn\linear_model\_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# C:\ProgramData\anaconda3\lib\site-packages\sklearn\linear_model\_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# C:\ProgramData\anaconda3\lib\site-packages\sklearn\linear_model\_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# C:\ProgramData\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\ProgramData\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\ProgramData\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\ProgramData\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\ProgramData\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\ProgramData\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\ProgramData\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\ProgramData\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\ProgramData\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\ProgramData\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\ProgramData\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\ProgramData\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\ProgramData\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\ProgramData\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\ProgramData\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\ProgramData\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\ProgramData\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\ProgramData\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\ProgramData\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\ProgramData\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\ProgramData\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\ProgramData\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\ProgramData\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\ProgramData\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\ProgramData\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\ProgramData\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\ProgramData\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\ProgramData\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\ProgramData\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\ProgramData\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\ProgramData\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\ProgramData\anaconda3\lib\site-packages\sklearn\linear_model\_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# C:\ProgramData\anaconda3\lib\site-packages\sklearn\linear_model\_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# C:\ProgramData\anaconda3\lib\site-packages\sklearn\linear_model\_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# C:\ProgramData\anaconda3\lib\site-packages\sklearn\linear_model\_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# C:\ProgramData\anaconda3\lib\site-packages\sklearn\linear_model\_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# C:\ProgramData\anaconda3\lib\site-packages\sklearn\linear_model\_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# C:\ProgramData\anaconda3\lib\site-packages\sklearn\linear_model\_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# C:\ProgramData\anaconda3\lib\site-packages\sklearn\linear_model\_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# C:\ProgramData\anaconda3\lib\site-packages\sklearn\linear_model\_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# C:\ProgramData\anaconda3\lib\site-packages\sklearn\linear_model\_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# C:\ProgramData\anaconda3\lib\site-packages\sklearn\linear_model\_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# C:\ProgramData\anaconda3\lib\site-packages\sklearn\linear_model\_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# C:\ProgramData\anaconda3\lib\site-packages\sklearn\linear_model\_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# C:\ProgramData\anaconda3\lib\site-packages\sklearn\linear_model\_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# C:\ProgramData\anaconda3\lib\site-packages\sklearn\linear_model\_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# C:\ProgramData\anaconda3\lib\site-packages\sklearn\linear_model\_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# C:\ProgramData\anaconda3\lib\site-packages\sklearn\linear_model\_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# C:\ProgramData\anaconda3\lib\site-packages\sklearn\linear_model\_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# C:\ProgramData\anaconda3\lib\site-packages\sklearn\linear_model\_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# C:\ProgramData\anaconda3\lib\site-packages\sklearn\linear_model\_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# C:\ProgramData\anaconda3\lib\site-packages\sklearn\linear_model\_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# C:\ProgramData\anaconda3\lib\site-packages\sklearn\linear_model\_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# C:\ProgramData\anaconda3\lib\site-packages\sklearn\linear_model\_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# C:\ProgramData\anaconda3\lib\site-packages\sklearn\linear_model\_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# C:\ProgramData\anaconda3\lib\site-packages\sklearn\linear_model\_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# C:\ProgramData\anaconda3\lib\site-packages\sklearn\linear_model\_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# C:\ProgramData\anaconda3\lib\site-packages\sklearn\linear_model\_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# C:\ProgramData\anaconda3\lib\site-packages\sklearn\linear_model\_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# C:\ProgramData\anaconda3\lib\site-packages\sklearn\linear_model\_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# C:\ProgramData\anaconda3\lib\site-packages\sklearn\linear_model\_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# C:\ProgramData\anaconda3\lib\site-packages\sklearn\linear_model\_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# C:\ProgramData\anaconda3\lib\site-packages\sklearn\linear_model\_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# C:\ProgramData\anaconda3\lib\site-packages\sklearn\linear_model\_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# C:\ProgramData\anaconda3\lib\site-packages\sklearn\linear_model\_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# C:\ProgramData\anaconda3\lib\site-packages\sklearn\linear_model\_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# C:\ProgramData\anaconda3\lib\site-packages\sklearn\linear_model\_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# C:\ProgramData\anaconda3\lib\site-packages\sklearn\linear_model\_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# C:\ProgramData\anaconda3\lib\site-packages\sklearn\linear_model\_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# C:\ProgramData\anaconda3\lib\site-packages\sklearn\linear_model\_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# C:\ProgramData\anaconda3\lib\site-packages\sklearn\linear_model\_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# GridSearchCV(cv=StratifiedKFold(n_splits=10, random_state=None, shuffle=True),
#              estimator=Pipeline(steps=[('preprocessing', MinMaxScaler()),
#                                        ('classifier', LogisticRegression())]),
#              param_grid=[{'classifier__class_weight': ['balanced', None],
#                           'classifier__penalty': ['l2'],
#                           'classifier__solver': ['newton-cg', 'lbfgs',
#                                                  'liblinear', 'sag', 'saga'],
#                           'classifier__tol': [0.1...
#                           'preprocessing': [MinMaxScaler(), StandardScaler(),
#                                             RobustScaler(), Normalizer()]},
#                          {'classifier__class_weight': ['balanced', None],
#                           'classifier__penalty': [None],
#                           'classifier__solver': ['newton-cg', 'lbfgs',
#                                                  'newton-cholesky', 'sag',
#                                                  'saga'],
#                           'classifier__tol': [0.1, 0.01, 0.001, 0.0001],
#                           'preprocessing': [MinMaxScaler(), StandardScaler(),
#                                             RobustScaler(), Normalizer()]}],
#              scoring='roc_auc')

# %%
grid_result = pd.DataFrame(grid.cv_results_).sort_values(["rank_test_score",'std_test_score']).T
grid_result
# Out:
#                                                                               145  \
# mean_fit_time                                                            0.003722
# std_fit_time                                                             0.002393
# mean_score_time                                                          0.001543
# std_score_time                                                           0.000748
# param_classifier__class_weight                                               None
# param_classifier__penalty                                                      l2
# param_classifier__solver                                                     saga
# param_classifier__tol                                                         0.1
# param_preprocessing                                              StandardScaler()
# params                          {'classifier__class_weight': None, 'classifier...
# split0_test_score                                                        0.829457
# split1_test_score                                                        0.736732
# split2_test_score                                                        0.858676
# split3_test_score                                                        0.794872
# split4_test_score                                                        0.870602
# split5_test_score                                                        0.841499
# split6_test_score                                                        0.766234
# split7_test_score                                                        0.787073
# split8_test_score                                                         0.87013
# split9_test_score                                                         0.81939
# mean_test_score                                                          0.817467
# std_test_score                                                           0.043124
# rank_test_score                                                                 1
#
#                                                                               193  \
# mean_fit_time                                                            0.002855
# std_fit_time                                                             0.003563
# mean_score_time                                                          0.000952
# std_score_time                                                           0.002375
# param_classifier__class_weight                                               None
# param_classifier__penalty                                                      l1
# param_classifier__solver                                                liblinear
# param_classifier__tol                                                         0.1
# param_preprocessing                                              StandardScaler()
# params                          {'classifier__class_weight': None, 'classifier...
# split0_test_score                                                        0.833631
# split1_test_score                                                        0.740012
# split2_test_score                                                        0.857782
# split3_test_score                                                        0.792188
# split4_test_score                                                        0.870602
# split5_test_score                                                        0.838843
# split6_test_score                                                        0.765348
# split7_test_score                                                        0.787375
# split8_test_score                                                        0.869526
# split9_test_score                                                         0.81486
# mean_test_score                                                          0.817017
# std_test_score                                                           0.042593
# rank_test_score                                                                 2
#
#                                                                               209  \
# mean_fit_time                                                             0.00159
# std_fit_time                                                             0.002369
# mean_score_time                                                          0.003211
# std_score_time                                                           0.002403
# param_classifier__class_weight                                               None
# param_classifier__penalty                                                      l1
# param_classifier__solver                                                     saga
# param_classifier__tol                                                         0.1
# param_preprocessing                                              StandardScaler()
# params                          {'classifier__class_weight': None, 'classifier...
# split0_test_score                                                        0.829159
# split1_test_score                                                        0.743888
# split2_test_score                                                        0.859273
# split3_test_score                                                        0.793679
# split4_test_score                                                         0.86941
# split5_test_score                                                        0.842385
# split6_test_score                                                        0.755608
# split7_test_score                                                        0.786167
# split8_test_score                                                        0.871942
# split9_test_score                                                         0.81486
# mean_test_score                                                          0.816637
# std_test_score                                                           0.043539
# rank_test_score                                                                 3
#
#                                                                               369  \
# mean_fit_time                                                            0.005097
# std_fit_time                                                             0.004395
# mean_score_time                                                          0.000311
# std_score_time                                                           0.000475
# param_classifier__class_weight                                               None
# param_classifier__penalty                                                    None
# param_classifier__solver                                                     saga
# param_classifier__tol                                                         0.1
# param_preprocessing                                              StandardScaler()
# params                          {'classifier__class_weight': None, 'classifier...
# split0_test_score                                                        0.828861
# split1_test_score                                                        0.740906
# split2_test_score                                                        0.855993
# split3_test_score                                                        0.795468
# split4_test_score                                                        0.870304
# split5_test_score                                                        0.841204
# split6_test_score                                                        0.754723
# split7_test_score                                                        0.788281
# split8_test_score                                                        0.869526
# split9_test_score                                                          0.8209
# mean_test_score                                                          0.816617
# std_test_score                                                            0.04338
# rank_test_score                                                                 4
#
#                                                                               161  \
# mean_fit_time                                                            0.002943
# std_fit_time                                                             0.000246
# mean_score_time                                                          0.001296
# std_score_time                                                           0.000456
# param_classifier__class_weight                                           balanced
# param_classifier__penalty                                                      l1
# param_classifier__solver                                                liblinear
# param_classifier__tol                                                         0.1
# param_preprocessing                                              StandardScaler()
# params                          {'classifier__class_weight': 'balanced', 'clas...
# split0_test_score                                                        0.832439
# split1_test_score                                                        0.738819
# split2_test_score                                                        0.855993
# split3_test_score                                                        0.792487
# split4_test_score                                                         0.86941
# split5_test_score                                                        0.838253
# split6_test_score                                                        0.757674
# split7_test_score                                                         0.78949
# split8_test_score                                                        0.870432
# split9_test_score                                                        0.820296
# mean_test_score                                                          0.816529
# std_test_score                                                           0.043371
# rank_test_score                                                                 5
#
#                                                                               274  \
# mean_fit_time                                                            0.005615
# std_fit_time                                                             0.000683
# mean_score_time                                                          0.001867
# std_score_time                                                           0.000332
# param_classifier__class_weight                                           balanced
# param_classifier__penalty                                                    None
# param_classifier__solver                                                      sag
# param_classifier__tol                                                         0.1
# param_preprocessing                                                RobustScaler()
# params                          {'classifier__class_weight': 'balanced', 'clas...
# split0_test_score                                                        0.829457
# split1_test_score                                                        0.740608
# split2_test_score                                                        0.856291
# split3_test_score                                                        0.787418
# split4_test_score                                                        0.871497
# split5_test_score                                                        0.836482
# split6_test_score                                                         0.75974
# split7_test_score                                                        0.792812
# split8_test_score                                                        0.868318
# split9_test_score                                                          0.8209
# mean_test_score                                                          0.816352
# std_test_score                                                            0.04274
# rank_test_score                                                                 6
#
#                                                                               126  \
# mean_fit_time                                                             0.00678
# std_fit_time                                                             0.002887
# mean_score_time                                                          0.002246
# std_score_time                                                           0.000686
# param_classifier__class_weight                                               None
# param_classifier__penalty                                                      l2
# param_classifier__solver                                                liblinear
# param_classifier__tol                                                      0.0001
# param_preprocessing                                                RobustScaler()
# params                          {'classifier__class_weight': None, 'classifier...
# split0_test_score                                                        0.831843
# split1_test_score                                                        0.736434
# split2_test_score                                                        0.857185
# split3_test_score                                                        0.793083
# split4_test_score                                                        0.871199
# split5_test_score                                                        0.839138
# split6_test_score                                                        0.754132
# split7_test_score                                                        0.787677
# split8_test_score                                                        0.870432
# split9_test_score                                                        0.821806
# mean_test_score                                                          0.816293
# std_test_score                                                           0.044734
# rank_test_score                                                                 7
#
#                                                                               122  \
# mean_fit_time                                                            0.005355
# std_fit_time                                                             0.000612
# mean_score_time                                                          0.001674
# std_score_time                                                           0.000569
# param_classifier__class_weight                                               None
# param_classifier__penalty                                                      l2
# param_classifier__solver                                                liblinear
# param_classifier__tol                                                       0.001
# param_preprocessing                                                RobustScaler()
# params                          {'classifier__class_weight': None, 'classifier...
# split0_test_score                                                        0.831843
# split1_test_score                                                        0.736434
# split2_test_score                                                        0.857185
# split3_test_score                                                        0.793083
# split4_test_score                                                        0.871199
# split5_test_score                                                        0.839138
# split6_test_score                                                        0.754132
# split7_test_score                                                        0.787677
# split8_test_score                                                        0.870432
# split9_test_score                                                        0.821504
# mean_test_score                                                          0.816263
# std_test_score                                                            0.04473
# rank_test_score                                                                 8
#
#                                                                               118  \
# mean_fit_time                                                            0.004413
# std_fit_time                                                             0.001449
# mean_score_time                                                          0.001659
# std_score_time                                                           0.001474
# param_classifier__class_weight                                               None
# param_classifier__penalty                                                      l2
# param_classifier__solver                                                liblinear
# param_classifier__tol                                                        0.01
# param_preprocessing                                                RobustScaler()
# params                          {'classifier__class_weight': None, 'classifier...
# split0_test_score                                                        0.832141
# split1_test_score                                                        0.736434
# split2_test_score                                                        0.856887
# split3_test_score                                                        0.793083
# split4_test_score                                                          0.8709
# split5_test_score                                                        0.839138
# split6_test_score                                                        0.754427
# split7_test_score                                                        0.787677
# split8_test_score                                                        0.870432
# split9_test_score                                                        0.821504
# mean_test_score                                                          0.816262
# std_test_score                                                           0.044636
# rank_test_score                                                                 9
#
#                                                                               154  \
# mean_fit_time                                                            0.007659
# std_fit_time                                                             0.000642
# mean_score_time                                                          0.001402
# std_score_time                                                           0.000488
# param_classifier__class_weight                                               None
# param_classifier__penalty                                                      l2
# param_classifier__solver                                                     saga
# param_classifier__tol                                                       0.001
# param_preprocessing                                                RobustScaler()
# params                          {'classifier__class_weight': None, 'classifier...
# split0_test_score                                                        0.832141
# split1_test_score                                                        0.736434
# split2_test_score                                                        0.856589
# split3_test_score                                                        0.793381
# split4_test_score                                                        0.871199
# split5_test_score                                                        0.839138
# split6_test_score                                                        0.754427
# split7_test_score                                                        0.787375
# split8_test_score                                                         0.87013
# split9_test_score                                                        0.821504
# mean_test_score                                                          0.816232
# std_test_score                                                           0.044613
# rank_test_score                                                                10
#
#                                 ...  \
# mean_fit_time                   ...
# std_fit_time                    ...
# mean_score_time                 ...
# std_score_time                  ...
# param_classifier__class_weight  ...
# param_classifier__penalty       ...
# param_classifier__solver        ...
# param_classifier__tol           ...
# param_preprocessing             ...
# params                          ...
# split0_test_score               ...
# split1_test_score               ...
# split2_test_score               ...
# split3_test_score               ...
# split4_test_score               ...
# split5_test_score               ...
# split6_test_score               ...
# split7_test_score               ...
# split8_test_score               ...
# split9_test_score               ...
# mean_test_score                 ...
# std_test_score                  ...
# rank_test_score                 ...
#
#                                                                               111  \
# mean_fit_time                                                            0.005377
# std_fit_time                                                             0.003704
# mean_score_time                                                          0.000912
# std_score_time                                                           0.002094
# param_classifier__class_weight                                               None
# param_classifier__penalty                                                      l2
# param_classifier__solver                                                    lbfgs
# param_classifier__tol                                                      0.0001
# param_preprocessing                                                  Normalizer()
# params                          {'classifier__class_weight': None, 'classifier...
# split0_test_score                                                        0.660405
# split1_test_score                                                         0.63059
# split2_test_score                                                        0.674419
# split3_test_score                                                        0.678891
# split4_test_score                                                        0.736732
# split5_test_score                                                        0.688017
# split6_test_score                                                        0.632527
# split7_test_score                                                        0.578375
# split8_test_score                                                        0.690728
# split9_test_score                                                        0.735729
# mean_test_score                                                          0.670641
# std_test_score                                                           0.045899
# rank_test_score                                                               372
#
#                                                                               143  \
# mean_fit_time                                                             0.00433
# std_fit_time                                                             0.003015
# mean_score_time                                                          0.002473
# std_score_time                                                           0.002654
# param_classifier__class_weight                                               None
# param_classifier__penalty                                                      l2
# param_classifier__solver                                                      sag
# param_classifier__tol                                                      0.0001
# param_preprocessing                                                  Normalizer()
# params                          {'classifier__class_weight': None, 'classifier...
# split0_test_score                                                        0.660405
# split1_test_score                                                         0.63059
# split2_test_score                                                        0.674419
# split3_test_score                                                        0.678891
# split4_test_score                                                        0.736732
# split5_test_score                                                        0.688017
# split6_test_score                                                        0.632527
# split7_test_score                                                        0.578375
# split8_test_score                                                        0.690728
# split9_test_score                                                        0.735729
# mean_test_score                                                          0.670641
# std_test_score                                                           0.045899
# rank_test_score                                                               372
#
#                                                                               159  \
# mean_fit_time                                                            0.004973
# std_fit_time                                                             0.000468
# mean_score_time                                                          0.001637
# std_score_time                                                           0.000456
# param_classifier__class_weight                                               None
# param_classifier__penalty                                                      l2
# param_classifier__solver                                                     saga
# param_classifier__tol                                                      0.0001
# param_preprocessing                                                  Normalizer()
# params                          {'classifier__class_weight': None, 'classifier...
# split0_test_score                                                        0.660405
# split1_test_score                                                         0.63059
# split2_test_score                                                        0.674419
# split3_test_score                                                        0.678891
# split4_test_score                                                        0.736732
# split5_test_score                                                        0.688017
# split6_test_score                                                        0.632527
# split7_test_score                                                        0.578375
# split8_test_score                                                        0.690728
# split9_test_score                                                        0.735729
# mean_test_score                                                          0.670641
# std_test_score                                                           0.045899
# rank_test_score                                                               372
#
#                                                                               155  \
# mean_fit_time                                                            0.004256
# std_fit_time                                                             0.000389
# mean_score_time                                                           0.00149
# std_score_time                                                           0.000491
# param_classifier__class_weight                                               None
# param_classifier__penalty                                                      l2
# param_classifier__solver                                                     saga
# param_classifier__tol                                                       0.001
# param_preprocessing                                                  Normalizer()
# params                          {'classifier__class_weight': None, 'classifier...
# split0_test_score                                                        0.660405
# split1_test_score                                                         0.63059
# split2_test_score                                                        0.673822
# split3_test_score                                                        0.678593
# split4_test_score                                                        0.736732
# split5_test_score                                                        0.688017
# split6_test_score                                                        0.632527
# split7_test_score                                                        0.578375
# split8_test_score                                                        0.690728
# split9_test_score                                                        0.735729
# mean_test_score                                                          0.670552
# std_test_score                                                           0.045889
# rank_test_score                                                               378
#
#                                                                               151  \
# mean_fit_time                                                            0.003616
# std_fit_time                                                             0.001372
# mean_score_time                                                          0.002108
# std_score_time                                                             0.0016
# param_classifier__class_weight                                               None
# param_classifier__penalty                                                      l2
# param_classifier__solver                                                     saga
# param_classifier__tol                                                        0.01
# param_preprocessing                                                  Normalizer()
# params                          {'classifier__class_weight': None, 'classifier...
# split0_test_score                                                        0.660405
# split1_test_score                                                          0.6291
# split2_test_score                                                         0.67412
# split3_test_score                                                        0.678295
# split4_test_score                                                        0.736434
# split5_test_score                                                        0.688312
# split6_test_score                                                        0.632527
# split7_test_score                                                        0.579281
# split8_test_score                                                         0.69103
# split9_test_score                                                        0.735729
# mean_test_score                                                          0.670523
# std_test_score                                                           0.045819
# rank_test_score                                                               379
#
#                                                                               123  \
# mean_fit_time                                                            0.003622
# std_fit_time                                                             0.000496
# mean_score_time                                                          0.002006
# std_score_time                                                           0.000261
# param_classifier__class_weight                                               None
# param_classifier__penalty                                                      l2
# param_classifier__solver                                                liblinear
# param_classifier__tol                                                       0.001
# param_preprocessing                                                  Normalizer()
# params                          {'classifier__class_weight': None, 'classifier...
# split0_test_score                                                        0.659511
# split1_test_score                                                        0.628503
# split2_test_score                                                        0.673524
# split3_test_score                                                        0.678891
# split4_test_score                                                        0.737329
# split5_test_score                                                        0.687131
# split6_test_score                                                        0.631936
# split7_test_score                                                        0.578073
# split8_test_score                                                        0.691332
# split9_test_score                                                        0.735729
# mean_test_score                                                          0.670196
# std_test_score                                                           0.046287
# rank_test_score                                                               380
#
#                                                                               127  \
# mean_fit_time                                                            0.003641
# std_fit_time                                                             0.000779
# mean_score_time                                                          0.001798
# std_score_time                                                           0.000599
# param_classifier__class_weight                                               None
# param_classifier__penalty                                                      l2
# param_classifier__solver                                                liblinear
# param_classifier__tol                                                      0.0001
# param_preprocessing                                                  Normalizer()
# params                          {'classifier__class_weight': None, 'classifier...
# split0_test_score                                                        0.659511
# split1_test_score                                                        0.628801
# split2_test_score                                                        0.673524
# split3_test_score                                                        0.678891
# split4_test_score                                                        0.737329
# split5_test_score                                                        0.687131
# split6_test_score                                                        0.631936
# split7_test_score                                                        0.578073
# split8_test_score                                                        0.691332
# split9_test_score                                                        0.735427
# mean_test_score                                                          0.670196
# std_test_score                                                           0.046217
# rank_test_score                                                               381
#
#                                                                               131  \
# mean_fit_time                                                            0.001814
# std_fit_time                                                             0.001531
# mean_score_time                                                          0.003249
# std_score_time                                                           0.001776
# param_classifier__class_weight                                               None
# param_classifier__penalty                                                      l2
# param_classifier__solver                                                      sag
# param_classifier__tol                                                         0.1
# param_preprocessing                                                  Normalizer()
# params                          {'classifier__class_weight': None, 'classifier...
# split0_test_score                                                        0.660405
# split1_test_score                                                        0.629994
# split2_test_score                                                        0.670244
# split3_test_score                                                        0.677102
# split4_test_score                                                        0.734347
# split5_test_score                                                        0.689197
# split6_test_score                                                        0.635773
# split7_test_score                                                        0.578979
# split8_test_score                                                        0.689822
# split9_test_score                                                        0.735125
# mean_test_score                                                          0.670099
# std_test_score                                                           0.045103
# rank_test_score                                                               382
#
#                                                                               119  \
# mean_fit_time                                                            0.001258
# std_fit_time                                                             0.001445
# mean_score_time                                                          0.003168
# std_score_time                                                           0.001374
# param_classifier__class_weight                                               None
# param_classifier__penalty                                                      l2
# param_classifier__solver                                                liblinear
# param_classifier__tol                                                        0.01
# param_preprocessing                                                  Normalizer()
# params                          {'classifier__class_weight': None, 'classifier...
# split0_test_score                                                        0.659511
# split1_test_score                                                        0.628503
# split2_test_score                                                        0.672928
# split3_test_score                                                        0.678891
# split4_test_score                                                        0.738223
# split5_test_score                                                        0.687426
# split6_test_score                                                        0.629575
# split7_test_score                                                        0.576563
# split8_test_score                                                        0.691332
# split9_test_score                                                        0.732105
# mean_test_score                                                          0.669506
# std_test_score                                                           0.046424
# rank_test_score                                                               383
#
#                                                                               115
# mean_fit_time                                                            0.002427
# std_fit_time                                                             0.000936
# mean_score_time                                                          0.001728
# std_score_time                                                           0.001118
# param_classifier__class_weight                                               None
# param_classifier__penalty                                                      l2
# param_classifier__solver                                                liblinear
# param_classifier__tol                                                         0.1
# param_preprocessing                                                  Normalizer()
# params                          {'classifier__class_weight': None, 'classifier...
# split0_test_score                                                        0.632677
# split1_test_score                                                        0.624329
# split2_test_score                                                          0.6452
# split3_test_score                                                        0.647883
# split4_test_score                                                        0.710197
# split5_test_score                                                        0.667946
# split6_test_score                                                        0.582645
# split7_test_score                                                        0.546059
# split8_test_score                                                        0.658109
# split9_test_score                                                        0.721836
# mean_test_score                                                          0.643688
# std_test_score                                                           0.050101
# rank_test_score                                                               384
#
# [23 rows x 384 columns]

# %%
mask = grid_result.index[grid_result.index.str.endswith("_test_score")][:-3]
tabl = grid_result.loc[mask].iloc[:,:10]
sns.boxplot(data=tabl); #мне №10

# %%
pipe_log = Pipeline([('preprocessing', StandardScaler()), 
                    ('classifier',    LogisticRegression(penalty='l2', solver='sag', tol = 0.1,
                                                         class_weight=None))])
pipe_log.fit(X_train, y_train)
# Out:
# Pipeline(steps=[('preprocessing', StandardScaler()),
#                 ('classifier', LogisticRegression(solver='sag', tol=0.1))])

# %%
pipe_c = make_pipeline(StandardScaler(), LogisticRegression(penalty='l2', solver='sag', tol = 0.1,
                                                         class_weight=None))

kfold = StratifiedKFold(n_splits=10, shuffle=True)

n_range = np.linspace(0.0001, 6, 500)
train_scores, test_scores = validation_curve(
    pipe_c , X_train, y_train,
    param_name = "logisticregression__C", 
    param_range = n_range,
    cv = kfold, 
    scoring="precision", 
    n_jobs=-1)

train_scores_mean = np.mean(train_scores, axis=1)
train_scores_std = np.std(train_scores, axis=1)
test_scores_mean = np.mean(test_scores, axis=1)
test_scores_std = np.std(test_scores, axis=1)

plt.figure(figsize=(15,10))

plt.title("Validation Curve")
plt.xlabel("сила регуляризации")
plt.ylabel("Score")
plt.ylim(0.5, 0.8)

plt.plot(n_range, train_scores_mean, label="Training score", color="darkorange")
plt.fill_between(n_range, train_scores_mean - train_scores_std,
                 train_scores_mean + train_scores_std, alpha=0.2,
                 color="darkorange")
plt.plot(n_range, test_scores_mean, label="Cross-validation score",
             color="navy")
plt.fill_between(n_range, test_scores_mean - test_scores_std,
                 test_scores_mean + test_scores_std, alpha=0.2,
                 color="navy")

plt.xticks(np.linspace(0, 6, 5))
plt.legend(loc="best")
plt.show() #этот std *cringe*

# %%
best_param = n_range[np.argmax(np.mean(test_scores, axis=1))]
best_param
# Out:
# 3.883802805611223

# %%
pipe_log = Pipeline([('preprocessing', StandardScaler()), 
                    ('classifier',    LogisticRegression(penalty='l2', solver='sag', tol = 0.1,
                                                         class_weight=None, C = best_param))])

pipe_log.fit(X_train, y_train)

y_pred = pipe_log.predict(X_test)
print(classification_report(y_test, y_pred))
print('ROC AUC', roc_auc_score(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.79      0.87      0.83       332
#            1       0.72      0.58      0.64       186
#
#     accuracy                           0.77       518
#    macro avg       0.75      0.73      0.74       518
# weighted avg       0.76      0.77      0.76       518
#
# ROC AUC 0.7270695685969685

# %%
thresholds = np.unique(pipe_log.predict_proba(X_test)[:,1])

max_precision, max_threshold = 0, 0
y_pred_proba = pipe_knn.predict_proba(X_test)[:,1]

for threshold in thresholds:
        # Применение порога к вероятностям классов
        y_pred_raw = y_pred_proba > threshold
        # Преобразование булевых значений в целочисленные
        y_pred = y_pred_raw.astype(int)
        # Вычисление precision
        pre = fbeta_score(y_test, y_pred, beta = 0.5)
        if pre > max_precision:
            max_precision, max_threshold = pre, threshold
print(f'Treshold: {max_threshold}: fbeta {max_precision}')
# Out:
# Treshold: 0.722118321800509: fbeta 0.9366576819407008

# %%
y_pred = (pipe_log.predict_proba(X_test)[:,1] > max_threshold).astype(int)

print('precision', precision_score(y_test, y_pred))
print('recall', recall_score(y_test, y_pred))
print('fbeta', fbeta_score(y_test, y_pred, beta = 0.5))
print('ROC AUC', roc_auc_score(y_test, y_pred))
# Out:
# precision 0.7301587301587301
# recall 0.24731182795698925
# fbeta 0.5251141552511416
# ROC AUC 0.5980535043399404

# %%
pr, rec = [], []

for i in range(1000):
    X_train, X_test, y_train, y_test = train_test_split(df.drop(columns = ['quality']), df.quality, test_size=0.3,
                                                    stratify=df.quality)
    
    pipe_log.fit(X_train, y_train)
    
    y_pred = (pipe_log.predict_proba(X_test)[:,1] > max_threshold).astype(int)
    
    pr.append(precision_score(y_test, y_pred))
    rec.append(recall_score(y_test, y_pred))

# %%
print('mean precision', np.array(pr).mean())
print('std precision', np.array(pr).std())
print('mean recall', np.array(rec).mean())
print('std recall', np.array(fbeta).std())
#проверка на устойчивость
# Out:
# mean precision 0.7418676047755511
# std precision 0.045707756822721615
# mean recall 0.26632258064516134
# std recall 0.03260804683690616
