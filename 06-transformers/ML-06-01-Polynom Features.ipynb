# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from IPython.display import display

# %%
import numpy as np
from sklearn.preprocessing import PolynomialFeatures
X = np.arange(6).reshape(3, 2)
display(X)

print('--- full ---')
poly = PolynomialFeatures(2)
X_transform = poly.fit_transform(X)
display(X_transform)

print('--- bias off ---')
poly = PolynomialFeatures(include_bias=False)
X_transform = poly.fit_transform(X)
display(X_transform)

print('--- original off ---')
poly = PolynomialFeatures(interaction_only=True)
X_transform = poly.fit_transform(X)
display(X_transform)

print('--- bias, original off ---')
poly = PolynomialFeatures(include_bias=False, interaction_only=True)
X_transform = poly.fit_transform(X)
display(X_transform)
# Out:
# array([[0, 1],
#        [2, 3],
#        [4, 5]])
# --- full ---
# array([[ 1.,  0.,  1.,  0.,  0.,  1.],
#        [ 1.,  2.,  3.,  4.,  6.,  9.],
#        [ 1.,  4.,  5., 16., 20., 25.]])
# --- bias off ---
# array([[ 0.,  1.,  0.,  0.,  1.],
#        [ 2.,  3.,  4.,  6.,  9.],
#        [ 4.,  5., 16., 20., 25.]])
# --- original off ---
# array([[ 1.,  0.,  1.,  0.],
#        [ 1.,  2.,  3.,  6.],
#        [ 1.,  4.,  5., 20.]])
# --- bias, original off ---
# array([[ 0.,  1.,  0.],
#        [ 2.,  3.,  6.],
#        [ 4.,  5., 20.]])

# %% [markdown]
# ## Полиномиальный фичинг

# %%
def make_wave(n_samples=100):
    rnd = np.random.RandomState(42)
    x = rnd.uniform(-3, 3, size=n_samples)
    y_no_noise = (np.sin(4 * x) + x)
    y = (y_no_noise + rnd.normal(size=len(x))*1) / 2
    return x.reshape(-1, 1), y

line = np.linspace(-3, 3, 1000, endpoint=False).reshape(-1, 1)

X, y = make_wave(n_samples=120)

from sklearn.preprocessing import PolynomialFeatures

# включая полиномы степени до x ** 10:
# по умолчанию "include_bias=True" есть свободный член в многочленне с данными
poly = PolynomialFeatures(degree=10, include_bias=False)
poly.fit(X)
X_poly = poly.transform(X)
print(X_poly.shape)
# Out:
# (120, 10)

# %%
np.linspace(-3, 3, 1000, endpoint=False)
# Out:
# array([-3.   , -2.994, -2.988, -2.982, -2.976, -2.97 , -2.964, -2.958,
#        -2.952, -2.946, -2.94 , -2.934, -2.928, -2.922, -2.916, -2.91 ,
#        -2.904, -2.898, -2.892, -2.886, -2.88 , -2.874, -2.868, -2.862,
#        -2.856, -2.85 , -2.844, -2.838, -2.832, -2.826, -2.82 , -2.814,
#        -2.808, -2.802, -2.796, -2.79 , -2.784, -2.778, -2.772, -2.766,
#        -2.76 , -2.754, -2.748, -2.742, -2.736, -2.73 , -2.724, -2.718,
#        -2.712, -2.706, -2.7  , -2.694, -2.688, -2.682, -2.676, -2.67 ,
#        -2.664, -2.658, -2.652, -2.646, -2.64 , -2.634, -2.628, -2.622,
#        -2.616, -2.61 , -2.604, -2.598, -2.592, -2.586, -2.58 , -2.574,
#        -2.568, -2.562, -2.556, -2.55 , -2.544, -2.538, -2.532, -2.526,
#        -2.52 , -2.514, -2.508, -2.502, -2.496, -2.49 , -2.484, -2.478,
#        -2.472, -2.466, -2.46 , -2.454, -2.448, -2.442, -2.436, -2.43 ,
#         2.28 ,  2.286,  2.292,  2.298,  2.304,  2.31 ,  2.316,  2.322,
#         2.328,  2.334,  2.34 ,  2.346,  2.352,  2.358,  2.364,  2.37 ,
#         2.376,  2.382,  2.388,  2.394,  2.4  ,  2.406,  2.412,  2.418,
#         2.424,  2.43 ,  2.436,  2.442,  2.448,  2.454,  2.46 ,  2.466,
#         2.472,  2.478,  2.484,  2.49 ,  2.496,  2.502,  2.508,  2.514,
#         2.52 ,  2.526,  2.532,  2.538,  2.544,  2.55 ,  2.556,  2.562,
#         2.568,  2.574,  2.58 ,  2.586,  2.592,  2.598,  2.604,  2.61 ,
#         2.616,  2.622,  2.628,  2.634,  2.64 ,  2.646,  2.652,  2.658,
#         2.664,  2.67 ,  2.676,  2.682,  2.688,  2.694,  2.7  ,  2.706,
#         2.712,  2.718,  2.724,  2.73 ,  2.736,  2.742,  2.748,  2.754,
#         2.76 ,  2.766,  2.772,  2.778,  2.784,  2.79 ,  2.796,  2.802,
#         2.808,  2.814,  2.82 ,  2.826,  2.832,  2.838,  2.844,  2.85 ,
#         2.856,  2.862,  2.868,  2.874,  2.88 ,  2.886,  2.892,  2.898,
#         2.904,  2.91 ,  2.916,  2.922,  2.928,  2.934,  2.94 ,  2.946,
#         2.952,  2.958,  2.964,  2.97 ,  2.976,  2.982,  2.988,  2.994])

# %%
np.linspace(-3, 3, 1000, endpoint=False).reshape(-1, 1)
# Out:
# array([[-3.   ],
#        [-2.994],
#        [-2.988],
#        [-2.982],
#        [-2.976],
#        [-2.97 ],
#        [-2.964],
#        [-2.958],
#        [-2.952],
#        [-2.946],
#        [-2.94 ],
#        [-2.934],
#        [-2.928],
#        [-2.922],
#        [-2.916],
#        [-2.91 ],
#        [-2.904],
#        [-2.898],
#        [-2.892],
#        [-2.886],
#        [-2.88 ],
#        [-2.874],
#        [-2.868],
#        [-2.862],
#        [-2.856],
#        [-2.85 ],
#        [-2.844],
#        [-2.838],
#        [-2.832],
#        [-2.826],
#        [-2.82 ],
#        [-2.814],
#        [-2.808],
#        [-2.802],
#        [-2.796],
#        [-2.79 ],
#        [-2.784],
#        [-2.778],
#        [-2.772],
#        [-2.766],
#        [-2.76 ],
#        [-2.754],
#        [-2.748],
#        [-2.742],
#        [-2.736],
#        [-2.73 ],
#        [-2.724],
#        [-2.718],
#        [-2.712],
#        [-2.706],
#        [-2.7  ],
#        [-2.694],
#        [-2.688],
#        [-2.682],
#        [-2.676],
#        [-2.67 ],
#        [-2.664],
#        [-2.658],
#        [-2.652],
#        [-2.646],
#        [-2.64 ],
#        [-2.634],
#        [-2.628],
#        [-2.622],
#        [-2.616],
#        [-2.61 ],
#        [-2.604],
#        [-2.598],
#        [-2.592],
#        [-2.586],
#        [-2.58 ],
#        [-2.574],
#        [-2.568],
#        [-2.562],
#        [-2.556],
#        [-2.55 ],
#        [-2.544],
#        [-2.538],
#        [-2.532],
#        [-2.526],
#        [-2.52 ],
#        [-2.514],
#        [-2.508],
#        [-2.502],
#        [-2.496],
#        [-2.49 ],
#        [-2.484],
#        [-2.478],
#        [-2.472],
#        [-2.466],
#        [-2.46 ],
#        [-2.454],
#        [-2.448],
#        [-2.442],
#        [-2.436],
#        [-2.43 ],
#        [-2.424],
#        [-2.418],
#        [-2.412],
#        [-2.406],
#        [-2.4  ],
#        [-2.394],
#        [-2.388],
#        [-2.382],
#        [-2.376],
#        [-2.37 ],
#        [-2.364],
#        [-2.358],
#        [-2.352],
#        [-2.346],
#        [-2.34 ],
#        [-2.334],
#        [-2.328],
#        [-2.322],
#        [-2.316],
#        [-2.31 ],
#        [-2.304],
#        [-2.298],
#        [-2.292],
#        [-2.286],
#        [-2.28 ],
#        [-2.274],
#        [-2.268],
#        [-2.262],
#        [-2.256],
#        [-2.25 ],
#        [-2.244],
#        [-2.238],
#        [-2.232],
#        [-2.226],
#        [-2.22 ],
#        [-2.214],
#        [-2.208],
#        [-2.202],
#        [-2.196],
#        [-2.19 ],
#        [-2.184],
#        [-2.178],
#        [-2.172],
#        [-2.166],
#        [-2.16 ],
#        [-2.154],
#        [-2.148],
#        [-2.142],
#        [-2.136],
#        [-2.13 ],
#        [-2.124],
#        [-2.118],
#        [-2.112],
#        [-2.106],
#        [-2.1  ],
#        [-2.094],
#        [-2.088],
#        [-2.082],
#        [-2.076],
#        [-2.07 ],
#        [-2.064],
#        [-2.058],
#        [-2.052],
#        [-2.046],
#        [-2.04 ],
#        [-2.034],
#        [-2.028],
#        [-2.022],
#        [-2.016],
#        [-2.01 ],
#        [-2.004],
#        [-1.998],
#        [-1.992],
#        [-1.986],
#        [-1.98 ],
#        [-1.974],
#        [-1.968],
#        [-1.962],
#        [-1.956],
#        [-1.95 ],
#        [-1.944],
#        [-1.938],
#        [-1.932],
#        [-1.926],
#        [-1.92 ],
#        [-1.914],
#        [-1.908],
#        [-1.902],
#        [-1.896],
#        [-1.89 ],
#        [-1.884],
#        [-1.878],
#        [-1.872],
#        [-1.866],
#        [-1.86 ],
#        [-1.854],
#        [-1.848],
#        [-1.842],
#        [-1.836],
#        [-1.83 ],
#        [-1.824],
#        [-1.818],
#        [-1.812],
#        [-1.806],
#        [-1.8  ],
#        [-1.794],
#        [-1.788],
#        [-1.782],
#        [-1.776],
#        [-1.77 ],
#        [-1.764],
#        [-1.758],
#        [-1.752],
#        [-1.746],
#        [-1.74 ],
#        [-1.734],
#        [-1.728],
#        [-1.722],
#        [-1.716],
#        [-1.71 ],
#        [-1.704],
#        [-1.698],
#        [-1.692],
#        [-1.686],
#        [-1.68 ],
#        [-1.674],
#        [-1.668],
#        [-1.662],
#        [-1.656],
#        [-1.65 ],
#        [-1.644],
#        [-1.638],
#        [-1.632],
#        [-1.626],
#        [-1.62 ],
#        [-1.614],
#        [-1.608],
#        [-1.602],
#        [-1.596],
#        [-1.59 ],
#        [-1.584],
#        [-1.578],
#        [-1.572],
#        [-1.566],
#        [-1.56 ],
#        [-1.554],
#        [-1.548],
#        [-1.542],
#        [-1.536],
#        [-1.53 ],
#        [-1.524],
#        [-1.518],
#        [-1.512],
#        [-1.506],
#        [-1.5  ],
#        [-1.494],
#        [-1.488],
#        [-1.482],
#        [-1.476],
#        [-1.47 ],
#        [-1.464],
#        [-1.458],
#        [-1.452],
#        [-1.446],
#        [-1.44 ],
#        [-1.434],
#        [-1.428],
#        [-1.422],
#        [-1.416],
#        [-1.41 ],
#        [-1.404],
#        [-1.398],
#        [-1.392],
#        [-1.386],
#        [-1.38 ],
#        [-1.374],
#        [-1.368],
#        [-1.362],
#        [-1.356],
#        [-1.35 ],
#        [-1.344],
#        [-1.338],
#        [-1.332],
#        [-1.326],
#        [-1.32 ],
#        [-1.314],
#        [-1.308],
#        [-1.302],
#        [-1.296],
#        [-1.29 ],
#        [-1.284],
#        [-1.278],
#        [-1.272],
#        [-1.266],
#        [-1.26 ],
#        [-1.254],
#        [-1.248],
#        [-1.242],
#        [-1.236],
#        [-1.23 ],
#        [-1.224],
#        [-1.218],
#        [-1.212],
#        [-1.206],
#        [-1.2  ],
#        [-1.194],
#        [-1.188],
#        [-1.182],
#        [-1.176],
#        [-1.17 ],
#        [-1.164],
#        [-1.158],
#        [-1.152],
#        [-1.146],
#        [-1.14 ],
#        [-1.134],
#        [-1.128],
#        [-1.122],
#        [-1.116],
#        [-1.11 ],
#        [-1.104],
#        [-1.098],
#        [-1.092],
#        [-1.086],
#        [-1.08 ],
#        [-1.074],
#        [-1.068],
#        [-1.062],
#        [-1.056],
#        [-1.05 ],
#        [-1.044],
#        [-1.038],
#        [-1.032],
#        [-1.026],
#        [-1.02 ],
#        [-1.014],
#        [-1.008],
#        [-1.002],
#        [-0.996],
#        [-0.99 ],
#        [-0.984],
#        [-0.978],
#        [-0.972],
#        [-0.966],
#        [-0.96 ],
#        [-0.954],
#        [-0.948],
#        [-0.942],
#        [-0.936],
#        [-0.93 ],
#        [-0.924],
#        [-0.918],
#        [-0.912],
#        [-0.906],
#        [-0.9  ],
#        [-0.894],
#        [-0.888],
#        [-0.882],
#        [-0.876],
#        [-0.87 ],
#        [-0.864],
#        [-0.858],
#        [-0.852],
#        [-0.846],
#        [-0.84 ],
#        [-0.834],
#        [-0.828],
#        [-0.822],
#        [-0.816],
#        [-0.81 ],
#        [-0.804],
#        [-0.798],
#        [-0.792],
#        [-0.786],
#        [-0.78 ],
#        [-0.774],
#        [-0.768],
#        [-0.762],
#        [-0.756],
#        [-0.75 ],
#        [-0.744],
#        [-0.738],
#        [-0.732],
#        [-0.726],
#        [-0.72 ],
#        [-0.714],
#        [-0.708],
#        [-0.702],
#        [-0.696],
#        [-0.69 ],
#        [-0.684],
#        [-0.678],
#        [-0.672],
#        [-0.666],
#        [-0.66 ],
#        [-0.654],
#        [-0.648],
#        [-0.642],
#        [-0.636],
#        [-0.63 ],
#        [-0.624],
#        [-0.618],
#        [-0.612],
#        [-0.606],
#        [-0.6  ],
#        [-0.594],
#        [-0.588],
#        [-0.582],
#        [-0.576],
#        [-0.57 ],
#        [-0.564],
#        [-0.558],
#        [-0.552],
#        [-0.546],
#        [-0.54 ],
#        [-0.534],
#        [-0.528],
#        [-0.522],
#        [-0.516],
#        [-0.51 ],
#        [-0.504],
#        [-0.498],
#        [-0.492],
#        [-0.486],
#        [-0.48 ],
#        [-0.474],
#        [-0.468],
#        [-0.462],
#        [-0.456],
#        [-0.45 ],
#        [-0.444],
#        [-0.438],
#        [-0.432],
#        [-0.426],
#        [-0.42 ],
#        [-0.414],
#        [-0.408],
#        [-0.402],
#        [-0.396],
#        [-0.39 ],
#        [-0.384],
#        [-0.378],
#        [-0.372],
#        [-0.366],
#        [-0.36 ],
#        [-0.354],
#        [-0.348],
#        [-0.342],
#        [-0.336],
#        [-0.33 ],
#        [-0.324],
#        [-0.318],
#        [-0.312],
#        [-0.306],
#        [-0.3  ],
#        [-0.294],
#        [-0.288],
#        [-0.282],
#        [-0.276],
#        [-0.27 ],
#        [-0.264],
#        [-0.258],
#        [-0.252],
#        [-0.246],
#        [-0.24 ],
#        [-0.234],
#        [-0.228],
#        [-0.222],
#        [-0.216],
#        [-0.21 ],
#        [-0.204],
#        [-0.198],
#        [-0.192],
#        [-0.186],
#        [-0.18 ],
#        [-0.174],
#        [-0.168],
#        [-0.162],
#        [-0.156],
#        [-0.15 ],
#        [-0.144],
#        [-0.138],
#        [-0.132],
#        [-0.126],
#        [-0.12 ],
#        [-0.114],
#        [-0.108],
#        [-0.102],
#        [-0.096],
#        [-0.09 ],
#        [-0.084],
#        [-0.078],
#        [-0.072],
#        [-0.066],
#        [-0.06 ],
#        [-0.054],
#        [-0.048],
#        [-0.042],
#        [-0.036],
#        [-0.03 ],
#        [-0.024],
#        [-0.018],
#        [-0.012],
#        [-0.006],
#        [ 0.   ],
#        [ 0.006],
#        [ 0.012],
#        [ 0.018],
#        [ 0.024],
#        [ 0.03 ],
#        [ 0.036],
#        [ 0.042],
#        [ 0.048],
#        [ 0.054],
#        [ 0.06 ],
#        [ 0.066],
#        [ 0.072],
#        [ 0.078],
#        [ 0.084],
#        [ 0.09 ],
#        [ 0.096],
#        [ 0.102],
#        [ 0.108],
#        [ 0.114],
#        [ 0.12 ],
#        [ 0.126],
#        [ 0.132],
#        [ 0.138],
#        [ 0.144],
#        [ 0.15 ],
#        [ 0.156],
#        [ 0.162],
#        [ 0.168],
#        [ 0.174],
#        [ 0.18 ],
#        [ 0.186],
#        [ 0.192],
#        [ 0.198],
#        [ 0.204],
#        [ 0.21 ],
#        [ 0.216],
#        [ 0.222],
#        [ 0.228],
#        [ 0.234],
#        [ 0.24 ],
#        [ 0.246],
#        [ 0.252],
#        [ 0.258],
#        [ 0.264],
#        [ 0.27 ],
#        [ 0.276],
#        [ 0.282],
#        [ 0.288],
#        [ 0.294],
#        [ 0.3  ],
#        [ 0.306],
#        [ 0.312],
#        [ 0.318],
#        [ 0.324],
#        [ 0.33 ],
#        [ 0.336],
#        [ 0.342],
#        [ 0.348],
#        [ 0.354],
#        [ 0.36 ],
#        [ 0.366],
#        [ 0.372],
#        [ 0.378],
#        [ 0.384],
#        [ 0.39 ],
#        [ 0.396],
#        [ 0.402],
#        [ 0.408],
#        [ 0.414],
#        [ 0.42 ],
#        [ 0.426],
#        [ 0.432],
#        [ 0.438],
#        [ 0.444],
#        [ 0.45 ],
#        [ 0.456],
#        [ 0.462],
#        [ 0.468],
#        [ 0.474],
#        [ 0.48 ],
#        [ 0.486],
#        [ 0.492],
#        [ 0.498],
#        [ 0.504],
#        [ 0.51 ],
#        [ 0.516],
#        [ 0.522],
#        [ 0.528],
#        [ 0.534],
#        [ 0.54 ],
#        [ 0.546],
#        [ 0.552],
#        [ 0.558],
#        [ 0.564],
#        [ 0.57 ],
#        [ 0.576],
#        [ 0.582],
#        [ 0.588],
#        [ 0.594],
#        [ 0.6  ],
#        [ 0.606],
#        [ 0.612],
#        [ 0.618],
#        [ 0.624],
#        [ 0.63 ],
#        [ 0.636],
#        [ 0.642],
#        [ 0.648],
#        [ 0.654],
#        [ 0.66 ],
#        [ 0.666],
#        [ 0.672],
#        [ 0.678],
#        [ 0.684],
#        [ 0.69 ],
#        [ 0.696],
#        [ 0.702],
#        [ 0.708],
#        [ 0.714],
#        [ 0.72 ],
#        [ 0.726],
#        [ 0.732],
#        [ 0.738],
#        [ 0.744],
#        [ 0.75 ],
#        [ 0.756],
#        [ 0.762],
#        [ 0.768],
#        [ 0.774],
#        [ 0.78 ],
#        [ 0.786],
#        [ 0.792],
#        [ 0.798],
#        [ 0.804],
#        [ 0.81 ],
#        [ 0.816],
#        [ 0.822],
#        [ 0.828],
#        [ 0.834],
#        [ 0.84 ],
#        [ 0.846],
#        [ 0.852],
#        [ 0.858],
#        [ 0.864],
#        [ 0.87 ],
#        [ 0.876],
#        [ 0.882],
#        [ 0.888],
#        [ 0.894],
#        [ 0.9  ],
#        [ 0.906],
#        [ 0.912],
#        [ 0.918],
#        [ 0.924],
#        [ 0.93 ],
#        [ 0.936],
#        [ 0.942],
#        [ 0.948],
#        [ 0.954],
#        [ 0.96 ],
#        [ 0.966],
#        [ 0.972],
#        [ 0.978],
#        [ 0.984],
#        [ 0.99 ],
#        [ 0.996],
#        [ 1.002],
#        [ 1.008],
#        [ 1.014],
#        [ 1.02 ],
#        [ 1.026],
#        [ 1.032],
#        [ 1.038],
#        [ 1.044],
#        [ 1.05 ],
#        [ 1.056],
#        [ 1.062],
#        [ 1.068],
#        [ 1.074],
#        [ 1.08 ],
#        [ 1.086],
#        [ 1.092],
#        [ 1.098],
#        [ 1.104],
#        [ 1.11 ],
#        [ 1.116],
#        [ 1.122],
#        [ 1.128],
#        [ 1.134],
#        [ 1.14 ],
#        [ 1.146],
#        [ 1.152],
#        [ 1.158],
#        [ 1.164],
#        [ 1.17 ],
#        [ 1.176],
#        [ 1.182],
#        [ 1.188],
#        [ 1.194],
#        [ 1.2  ],
#        [ 1.206],
#        [ 1.212],
#        [ 1.218],
#        [ 1.224],
#        [ 1.23 ],
#        [ 1.236],
#        [ 1.242],
#        [ 1.248],
#        [ 1.254],
#        [ 1.26 ],
#        [ 1.266],
#        [ 1.272],
#        [ 1.278],
#        [ 1.284],
#        [ 1.29 ],
#        [ 1.296],
#        [ 1.302],
#        [ 1.308],
#        [ 1.314],
#        [ 1.32 ],
#        [ 1.326],
#        [ 1.332],
#        [ 1.338],
#        [ 1.344],
#        [ 1.35 ],
#        [ 1.356],
#        [ 1.362],
#        [ 1.368],
#        [ 1.374],
#        [ 1.38 ],
#        [ 1.386],
#        [ 1.392],
#        [ 1.398],
#        [ 1.404],
#        [ 1.41 ],
#        [ 1.416],
#        [ 1.422],
#        [ 1.428],
#        [ 1.434],
#        [ 1.44 ],
#        [ 1.446],
#        [ 1.452],
#        [ 1.458],
#        [ 1.464],
#        [ 1.47 ],
#        [ 1.476],
#        [ 1.482],
#        [ 1.488],
#        [ 1.494],
#        [ 1.5  ],
#        [ 1.506],
#        [ 1.512],
#        [ 1.518],
#        [ 1.524],
#        [ 1.53 ],
#        [ 1.536],
#        [ 1.542],
#        [ 1.548],
#        [ 1.554],
#        [ 1.56 ],
#        [ 1.566],
#        [ 1.572],
#        [ 1.578],
#        [ 1.584],
#        [ 1.59 ],
#        [ 1.596],
#        [ 1.602],
#        [ 1.608],
#        [ 1.614],
#        [ 1.62 ],
#        [ 1.626],
#        [ 1.632],
#        [ 1.638],
#        [ 1.644],
#        [ 1.65 ],
#        [ 1.656],
#        [ 1.662],
#        [ 1.668],
#        [ 1.674],
#        [ 1.68 ],
#        [ 1.686],
#        [ 1.692],
#        [ 1.698],
#        [ 1.704],
#        [ 1.71 ],
#        [ 1.716],
#        [ 1.722],
#        [ 1.728],
#        [ 1.734],
#        [ 1.74 ],
#        [ 1.746],
#        [ 1.752],
#        [ 1.758],
#        [ 1.764],
#        [ 1.77 ],
#        [ 1.776],
#        [ 1.782],
#        [ 1.788],
#        [ 1.794],
#        [ 1.8  ],
#        [ 1.806],
#        [ 1.812],
#        [ 1.818],
#        [ 1.824],
#        [ 1.83 ],
#        [ 1.836],
#        [ 1.842],
#        [ 1.848],
#        [ 1.854],
#        [ 1.86 ],
#        [ 1.866],
#        [ 1.872],
#        [ 1.878],
#        [ 1.884],
#        [ 1.89 ],
#        [ 1.896],
#        [ 1.902],
#        [ 1.908],
#        [ 1.914],
#        [ 1.92 ],
#        [ 1.926],
#        [ 1.932],
#        [ 1.938],
#        [ 1.944],
#        [ 1.95 ],
#        [ 1.956],
#        [ 1.962],
#        [ 1.968],
#        [ 1.974],
#        [ 1.98 ],
#        [ 1.986],
#        [ 1.992],
#        [ 1.998],
#        [ 2.004],
#        [ 2.01 ],
#        [ 2.016],
#        [ 2.022],
#        [ 2.028],
#        [ 2.034],
#        [ 2.04 ],
#        [ 2.046],
#        [ 2.052],
#        [ 2.058],
#        [ 2.064],
#        [ 2.07 ],
#        [ 2.076],
#        [ 2.082],
#        [ 2.088],
#        [ 2.094],
#        [ 2.1  ],
#        [ 2.106],
#        [ 2.112],
#        [ 2.118],
#        [ 2.124],
#        [ 2.13 ],
#        [ 2.136],
#        [ 2.142],
#        [ 2.148],
#        [ 2.154],
#        [ 2.16 ],
#        [ 2.166],
#        [ 2.172],
#        [ 2.178],
#        [ 2.184],
#        [ 2.19 ],
#        [ 2.196],
#        [ 2.202],
#        [ 2.208],
#        [ 2.214],
#        [ 2.22 ],
#        [ 2.226],
#        [ 2.232],
#        [ 2.238],
#        [ 2.244],
#        [ 2.25 ],
#        [ 2.256],
#        [ 2.262],
#        [ 2.268],
#        [ 2.274],
#        [ 2.28 ],
#        [ 2.286],
#        [ 2.292],
#        [ 2.298],
#        [ 2.304],
#        [ 2.31 ],
#        [ 2.316],
#        [ 2.322],
#        [ 2.328],
#        [ 2.334],
#        [ 2.34 ],
#        [ 2.346],
#        [ 2.352],
#        [ 2.358],
#        [ 2.364],
#        [ 2.37 ],
#        [ 2.376],
#        [ 2.382],
#        [ 2.388],
#        [ 2.394],
#        [ 2.4  ],
#        [ 2.406],
#        [ 2.412],
#        [ 2.418],
#        [ 2.424],
#        [ 2.43 ],
#        [ 2.436],
#        [ 2.442],
#        [ 2.448],
#        [ 2.454],
#        [ 2.46 ],
#        [ 2.466],
#        [ 2.472],
#        [ 2.478],
#        [ 2.484],
#        [ 2.49 ],
#        [ 2.496],
#        [ 2.502],
#        [ 2.508],
#        [ 2.514],
#        [ 2.52 ],
#        [ 2.526],
#        [ 2.532],
#        [ 2.538],
#        [ 2.544],
#        [ 2.55 ],
#        [ 2.556],
#        [ 2.562],
#        [ 2.568],
#        [ 2.574],
#        [ 2.58 ],
#        [ 2.586],
#        [ 2.592],
#        [ 2.598],
#        [ 2.604],
#        [ 2.61 ],
#        [ 2.616],
#        [ 2.622],
#        [ 2.628],
#        [ 2.634],
#        [ 2.64 ],
#        [ 2.646],
#        [ 2.652],
#        [ 2.658],
#        [ 2.664],
#        [ 2.67 ],
#        [ 2.676],
#        [ 2.682],
#        [ 2.688],
#        [ 2.694],
#        [ 2.7  ],
#        [ 2.706],
#        [ 2.712],
#        [ 2.718],
#        [ 2.724],
#        [ 2.73 ],
#        [ 2.736],
#        [ 2.742],
#        [ 2.748],
#        [ 2.754],
#        [ 2.76 ],
#        [ 2.766],
#        [ 2.772],
#        [ 2.778],
#        [ 2.784],
#        [ 2.79 ],
#        [ 2.796],
#        [ 2.802],
#        [ 2.808],
#        [ 2.814],
#        [ 2.82 ],
#        [ 2.826],
#        [ 2.832],
#        [ 2.838],
#        [ 2.844],
#        [ 2.85 ],
#        [ 2.856],
#        [ 2.862],
#        [ 2.868],
#        [ 2.874],
#        [ 2.88 ],
#        [ 2.886],
#        [ 2.892],
#        [ 2.898],
#        [ 2.904],
#        [ 2.91 ],
#        [ 2.916],
#        [ 2.922],
#        [ 2.928],
#        [ 2.934],
#        [ 2.94 ],
#        [ 2.946],
#        [ 2.952],
#        [ 2.958],
#        [ 2.964],
#        [ 2.97 ],
#        [ 2.976],
#        [ 2.982],
#        [ 2.988],
#        [ 2.994]])

# %%
print("Entries of X:\n{}".format(X[:5]))
print("Entries of X_poly:\n{}".format(X_poly[:5]))
# Out:
# Entries of X:
# [[-0.75275929]
#  [ 2.70428584]
#  [ 1.39196365]
#  [ 0.59195091]
#  [-2.06388816]]
# Entries of X_poly:
# [[-7.52759287e-01  5.66646544e-01 -4.26548448e-01  3.21088306e-01
#   -2.41702204e-01  1.81943579e-01 -1.36959719e-01  1.03097700e-01
#   -7.76077513e-02  5.84199555e-02]
#  [ 2.70428584e+00  7.31316190e+00  1.97768801e+01  5.34823369e+01
#    1.44631526e+02  3.91124988e+02  1.05771377e+03  2.86036036e+03
#    7.73523202e+03  2.09182784e+04]
#  [ 1.39196365e+00  1.93756281e+00  2.69701700e+00  3.75414962e+00
#    5.22563982e+00  7.27390068e+00  1.01250053e+01  1.40936394e+01
#    1.96178338e+01  2.73073115e+01]
#  [ 5.91950905e-01  3.50405874e-01  2.07423074e-01  1.22784277e-01
#    7.26822637e-02  4.30243318e-02  2.54682921e-02  1.50759786e-02
#    8.92423917e-03  5.28271146e-03]
#  [-2.06388816e+00  4.25963433e+00 -8.79140884e+00  1.81444846e+01
#   -3.74481869e+01  7.72888694e+01 -1.59515582e+02  3.29222321e+02
#   -6.79478050e+02  1.40236670e+03]]

# %%
print("Polynomial feature names:\n{}".format(poly.get_feature_names_out()))
# Out:
# Polynomial feature names:
# ['x0' 'x0^2' 'x0^3' 'x0^4' 'x0^5' 'x0^6' 'x0^7' 'x0^8' 'x0^9' 'x0^10']

# %%
def make_wave(n_samples=100):
    rnd = np.random.RandomState(42)
    x = rnd.uniform(-3, 3, size=n_samples)
    y_no_noise = (np.sin(4 * x) + x)
    y = (y_no_noise + 0.1*rnd.normal(size=len(x))*1) / 2
    return x.reshape(-1, 1), y

line = np.linspace(-3, 3, 1000, endpoint=False).reshape(-1, 1)

X, y = make_wave(n_samples=120)

from sklearn.preprocessing import PolynomialFeatures

# включая полиномы степени до x ** 10:
# по умолчанию "include_bias=True" есть свободный член в многочленне с данными
poly = PolynomialFeatures(degree=12, include_bias=False)
poly.fit(X)
X_poly = poly.transform(X)
print(X_poly.shape)

from sklearn.linear_model import LinearRegression
reg = LinearRegression().fit(X_poly, y)

line_poly = poly.transform(line)

plt.plot(line, reg.predict(line_poly), label='polynomial linear regression')
plt.plot(line, (np.sin(4*line)+line)/2, label='original function')
plt.plot(X[:, 0], y, 'o', c='k')
plt.ylabel("Regression output")
plt.xlabel("Input feature")
plt.legend(loc="best");
# Out:
# (120, 12)
