# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data_url = "http://lib.stat.cmu.edu/datasets/boston"
column_names = ['CRIM', 'ZN', 'INDUS', 'CHAS', 'NOX', 'RM', 'AGE', 'DIS', 'RAD', 'TAX', 'PTRATIO', 'B', 'LSTAT', 'MEDV']

raw_df = pd.read_csv(data_url, sep="\s+", skiprows=22, header=None)
raw_df = np.hstack([raw_df.values[::2, :], raw_df.values[1::2, :3]])
df = pd.DataFrame(raw_df, columns=column_names)
df.head(3)
# Out:
#       CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD    TAX  \
# 0  0.00632  18.0   2.31   0.0  0.538  6.575  65.2  4.0900  1.0  296.0
# 1  0.02731   0.0   7.07   0.0  0.469  6.421  78.9  4.9671  2.0  242.0
# 2  0.02729   0.0   7.07   0.0  0.469  7.185  61.1  4.9671  2.0  242.0
#
#    PTRATIO       B  LSTAT  MEDV
# 0     15.3  396.90   4.98  24.0
# 1     17.8  396.90   9.14  21.6
# 2     17.8  392.83   4.03  34.7

# %%
boston_data = df.drop(['MEDV'],axis=1)
boston_target = df['MEDV']

# %% [markdown]
# ## Шаг 1. Строим самую простую модель

# %%
from sklearn.model_selection import train_test_split 
from sklearn.neighbors import KNeighborsRegressor 

X_train, X_test, y_train, y_test = train_test_split(boston_data, boston_target, random_state=1)

knn = KNeighborsRegressor(n_neighbors=4)
knn.fit(X_train, y_train)

sc_train = knn.score(X_train , y_train)
sc_test = knn.score(X_test , y_test)


print("тренировочный: {:.3f}".format(sc_train))
print("тестовый: {:.3f}".format(sc_test))
# Out:
# тренировочный: 0.716
# тестовый: 0.585

# %% [markdown]
# ## Шаг 2. Проводим препроцессинг (пересмасштабирование) данных

# %%
from sklearn.model_selection import train_test_split 
from sklearn.neighbors import KNeighborsRegressor 
from sklearn.preprocessing import MinMaxScaler

X_train, X_test, y_train, y_test = train_test_split(boston_data, boston_target, random_state=1)

scaler = MinMaxScaler() 
# находим функцию масштабирования
scaler.fit(X_train) # Перемасштабирование ТОЛЬКО на ТРЕНИРОВОЧНОМ наборе,  


X_train_scaled = scaler.transform(X_train) # перемасштабировали тренировочный набор
X_test_scaled = scaler.transform(X_test)   # перемасштабировали тестовый набор


knn = KNeighborsRegressor(n_neighbors=4)
knn.fit(X_train_scaled, y_train)

sc_train = knn.score(X_train_scaled , y_train)
sc_test =  knn.score(X_test_scaled ,  y_test)

print("тренировочный: {:.3f}".format(sc_train))
print("тестовый: {:.3f}".format(sc_test))
# Out:
# тренировочный: 0.841
# тестовый: 0.781

# %% [markdown]
# ## Шаг 2.5 Посмотрим метрики результатов
# https://scikit-learn.org/stable/modules/classes.html#module-sklearn.metrics

# %%
from sklearn.model_selection import train_test_split 
from sklearn.preprocessing import MinMaxScaler
from sklearn.neighbors import KNeighborsRegressor 
from sklearn.metrics import r2_score
from sklearn.metrics import mean_squared_error

X_train, X_test, y_train, y_test = train_test_split(boston_data, boston_target, random_state=1)

scaler = MinMaxScaler() 
# находим функцию масштабирования
scaler.fit(X_train) # Перемасштабирование ТОЛЬКО на ТРЕНИРОВОЦНОМ наборе,  


X_train_scaled = scaler.transform(X_train) # перемасштабировали тренировочный набор
X_test_scaled = scaler.transform(X_test)   # перемасштабировали тестовый набор

knn = KNeighborsRegressor(n_neighbors=4)
knn.fit(X_train_scaled, y_train)

# предскажем значение тренировочный и тестовых y
y_pred_train=knn.predict(X_train_scaled)
y_pred=knn.predict(X_test_scaled)

# Проверим тренировочный набор (не всегда нужно делать)
print('тренировочный R^2: {:.3f}'.format( r2_score(y_train,y_pred_train) ) )
# MSE само по себе мало значит, но важно при сравнении дрс другими результатами 
print('тренировочный MSE: {:.3f}'.format( mean_squared_error(y_train,y_pred_train) ) ) 

# Проверим тренировочный набор (не всегда нужно делать)
print('тестовый R^2: {:.3f}'.format( r2_score(y_test,y_pred) ) )
# MSE само по себе мало значит, но важно при сравнении дрс другими результатами 
print('тестовый MSE: {:.3f}'.format( mean_squared_error(y_test,y_pred) ) )
# Out:
# тренировочный R^2: 0.841
# тренировочный MSE: 12.637
# тестовый R^2: 0.781
# тестовый MSE: 21.691

# %% [markdown]
# ## Шаг 3. Добавим поиск оптимального параметра

# %%
from sklearn.model_selection import train_test_split 
from sklearn.preprocessing import MinMaxScaler
from sklearn.neighbors import KNeighborsRegressor 
from sklearn.metrics import mean_squared_error

X_train, X_test, y_train, y_test = train_test_split(boston_data, boston_target, random_state=12) # 1, 12, 100

from sklearn.preprocessing import MinMaxScaler

scaler = MinMaxScaler() 
scaler.fit(X_train)

X_train_scaled = scaler.transform(X_train) 
X_test_scaled = scaler.transform(X_test) 

sc_train=[]
sc_test=[]
sc_train_mse=[]
sc_test_mse=[]

ran=range(1,10)

for r in ran:
    knn = KNeighborsRegressor(n_neighbors=r)
    knn.fit(X_train_scaled, y_train)
    sc_train=np.append(sc_train,knn.score(X_train_scaled ,y_train))
    sc_test=np.append(sc_test, knn.score(X_test_scaled ,y_test)) 
    y_pred=knn.predict(X_test_scaled)
    sc_test_mse=np.append(sc_test_mse,  mean_squared_error (y_test, y_pred)   )
    
np.set_printoptions(precision=3)
print(sc_train)
print(sc_test)
print(sc_test_mse)

fig, ax1 = plt.subplots(figsize=(15,5))
ax1.plot(ran,sc_train, label= 'R^2 тренировочный')
ax1.plot(ran,sc_test, label= 'R^2 тестовый')
ax1.set_xlabel('кол. соседей')
ax1.set_ylabel('R^2')
ax2 = ax1.twinx()
ax2.plot(ran,sc_test_mse,'-g', label= 'MSE тестовый')
ax2.set_ylabel('MSE') #  СКО - среднеквадрат ошибка  или MSE - mean squared error
fig.legend(loc="upper right", bbox_to_anchor=(1,1), bbox_transform=ax1.transAxes, framealpha=0.7)
plt.show()
# Out:
# [1.    0.93  0.879 0.848 0.804 0.785 0.774 0.75  0.727]
# [0.705 0.784 0.735 0.716 0.685 0.699 0.725 0.732 0.723]
# [25.938 19.004 23.263 24.94  27.718 26.5   24.146 23.608 24.38 ]

# %% [markdown]
# ## Итоговый шаг. Строим коннтейнеры

# %%
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import MinMaxScaler, StandardScaler, RobustScaler
from sklearn.model_selection import train_test_split, cross_val_score, GridSearchCV, KFold 
from sklearn.neighbors import KNeighborsRegressor 
from sklearn.metrics import mean_squared_error


X_train, X_test, y_train, y_test = train_test_split(boston_data, boston_target, random_state=12, test_size=0.2)

kfold = KFold(n_splits=10, shuffle=True, random_state=1)

pipe = Pipeline([('preprocessing', MinMaxScaler()), 
                 ('classifier', KNeighborsRegressor())])

n_neighbors=[1, 2, 3, 4, 5]
p=[1, 2, 3, 4, 6, 8, 10]
weights=['uniform','distance']

param_grid =[
    {'preprocessing': [MinMaxScaler(), StandardScaler(),RobustScaler(),None], 
     'classifier': [KNeighborsRegressor()],
     'classifier__n_neighbors': n_neighbors,
     'classifier__p': p,
     'classifier__weights': weights
     }
]

grid = GridSearchCV(pipe, param_grid, cv=kfold, return_train_score=True, n_jobs=-1)
grid.fit(X_train,y_train)

print("----------------- Обучили и тестировали -------------------")
print("Наилучшие параметры:\n{}\n".format(grid.best_params_))
print("Средняя правильность для наилучшей модели кроссвалидации на \
                валидационных тестовых наборах: {:.6f}\n".format(grid.best_score_)) 
print("Правильность для наилучшей модели на тестовом наборе: {:.6f}\n".format(grid.score(X_test, y_test)))
gridresults = pd.DataFrame(grid.cv_results_)
display(gridresults.sort_values(["rank_test_score"]).T)
# Out:
# ----------------- Обучили и тестировали -------------------
# Наилучшие параметры:
# {'classifier': KNeighborsRegressor(), 'classifier__n_neighbors': 4, 'classifier__p': 1, 'classifier__weights': 'distance', 'preprocessing': RobustScaler()}
#
# Средняя правильность для наилучшей модели кроссвалидации на                 валидационных тестовых наборах: 0.784593
#
# Правильность для наилучшей модели на тестовом наборе: 0.848867
#                                                                              174  \
# mean_fit_time                                                           0.002323
# std_fit_time                                                             0.00106
# mean_score_time                                                         0.001047
# std_score_time                                                           0.00043
# param_classifier                                           KNeighborsRegressor()
# param_classifier__n_neighbors                                                  4
# param_classifier__p                                                            1
# param_classifier__weights                                               distance
# param_preprocessing                                               RobustScaler()
# params                         {'classifier': KNeighborsRegressor(), 'classif...
# split0_test_score                                                       0.707961
# split1_test_score                                                       0.691508
# split2_test_score                                                       0.738795
# split3_test_score                                                       0.868012
# split4_test_score                                                        0.87633
# split5_test_score                                                       0.685483
# split6_test_score                                                       0.828674
# split7_test_score                                                       0.791723
# split8_test_score                                                       0.893982
# split9_test_score                                                       0.763464
# mean_test_score                                                         0.784593
# std_test_score                                                          0.074992
# rank_test_score                                                                1
# split0_train_score                                                           1.0
# split1_train_score                                                           1.0
# split2_train_score                                                           1.0
# split3_train_score                                                           1.0
# split4_train_score                                                           1.0
# split5_train_score                                                           1.0
# split6_train_score                                                           1.0
# split7_train_score                                                           1.0
# split8_train_score                                                           1.0
# split9_train_score                                                           1.0
# mean_train_score                                                             1.0
# std_train_score                                                              0.0
#
#                                                                              230  \
# mean_fit_time                                                           0.002232
# std_fit_time                                                            0.001458
# mean_score_time                                                         0.000902
# std_score_time                                                          0.000402
# param_classifier                                           KNeighborsRegressor()
# param_classifier__n_neighbors                                                  5
# param_classifier__p                                                            1
# param_classifier__weights                                               distance
# param_preprocessing                                               RobustScaler()
# params                         {'classifier': KNeighborsRegressor(), 'classif...
# split0_test_score                                                       0.698803
# split1_test_score                                                       0.702907
# split2_test_score                                                       0.729261
# split3_test_score                                                       0.867397
# split4_test_score                                                          0.901
# split5_test_score                                                       0.675869
# split6_test_score                                                       0.791934
# split7_test_score                                                       0.757133
# split8_test_score                                                        0.88512
# split9_test_score                                                       0.781788
# mean_test_score                                                         0.779121
# std_test_score                                                          0.077424
# rank_test_score                                                                2
# split0_train_score                                                           1.0
# split1_train_score                                                           1.0
# split2_train_score                                                           1.0
# split3_train_score                                                           1.0
# split4_train_score                                                           1.0
# split5_train_score                                                           1.0
# split6_train_score                                                           1.0
# split7_train_score                                                           1.0
# split8_train_score                                                           1.0
# split9_train_score                                                           1.0
# mean_train_score                                                             1.0
# std_train_score                                                              0.0
#
#                                                                              117  \
# mean_fit_time                                                           0.001804
# std_fit_time                                                            0.001427
# mean_score_time                                                         0.000984
# std_score_time                                                           0.00054
# param_classifier                                           KNeighborsRegressor()
# param_classifier__n_neighbors                                                  3
# param_classifier__p                                                            1
# param_classifier__weights                                               distance
# param_preprocessing                                             StandardScaler()
# params                         {'classifier': KNeighborsRegressor(), 'classif...
# split0_test_score                                                        0.64813
# split1_test_score                                                       0.722274
# split2_test_score                                                       0.768316
# split3_test_score                                                       0.846542
# split4_test_score                                                       0.906994
# split5_test_score                                                       0.685926
# split6_test_score                                                       0.799401
# split7_test_score                                                       0.780725
# split8_test_score                                                       0.916392
# split9_test_score                                                       0.681811
# mean_test_score                                                         0.775651
# std_test_score                                                           0.08871
# rank_test_score                                                                3
# split0_train_score                                                           1.0
# split1_train_score                                                           1.0
# split2_train_score                                                           1.0
# split3_train_score                                                           1.0
# split4_train_score                                                           1.0
# split5_train_score                                                           1.0
# split6_train_score                                                           1.0
# split7_train_score                                                           1.0
# split8_train_score                                                           1.0
# split9_train_score                                                           1.0
# mean_train_score                                                             1.0
# std_train_score                                                              0.0
#
#                                                                              173  \
# mean_fit_time                                                           0.001289
# std_fit_time                                                            0.000618
# mean_score_time                                                         0.001197
# std_score_time                                                          0.000939
# param_classifier                                           KNeighborsRegressor()
# param_classifier__n_neighbors                                                  4
# param_classifier__p                                                            1
# param_classifier__weights                                               distance
# param_preprocessing                                             StandardScaler()
# params                         {'classifier': KNeighborsRegressor(), 'classif...
# split0_test_score                                                       0.603117
# split1_test_score                                                       0.703371
# split2_test_score                                                       0.730753
# split3_test_score                                                       0.855281
# split4_test_score                                                       0.905676
# split5_test_score                                                       0.790295
# split6_test_score                                                       0.809119
# split7_test_score                                                        0.71365
# split8_test_score                                                        0.91309
# split9_test_score                                                       0.723246
# mean_test_score                                                          0.77476
# std_test_score                                                          0.093307
# rank_test_score                                                                4
# split0_train_score                                                           1.0
# split1_train_score                                                           1.0
# split2_train_score                                                           1.0
# split3_train_score                                                           1.0
# split4_train_score                                                           1.0
# split5_train_score                                                           1.0
# split6_train_score                                                           1.0
# split7_train_score                                                           1.0
# split8_train_score                                                           1.0
# split9_train_score                                                           1.0
# mean_train_score                                                             1.0
# std_train_score                                                              0.0
#
#                                                                              229  \
# mean_fit_time                                                            0.00144
# std_fit_time                                                            0.000828
# mean_score_time                                                          0.00089
# std_score_time                                                          0.000389
# param_classifier                                           KNeighborsRegressor()
# param_classifier__n_neighbors                                                  5
# param_classifier__p                                                            1
# param_classifier__weights                                               distance
# param_preprocessing                                             StandardScaler()
# params                         {'classifier': KNeighborsRegressor(), 'classif...
# split0_test_score                                                       0.619984
# split1_test_score                                                       0.676802
# split2_test_score                                                        0.70556
# split3_test_score                                                       0.841544
# split4_test_score                                                       0.912511
# split5_test_score                                                       0.807665
# split6_test_score                                                       0.817187
# split7_test_score                                                        0.68785
# split8_test_score                                                       0.904314
# split9_test_score                                                       0.735593
# mean_test_score                                                         0.770901
# std_test_score                                                          0.095069
# rank_test_score                                                                5
# split0_train_score                                                           1.0
# split1_train_score                                                           1.0
# split2_train_score                                                           1.0
# split3_train_score                                                           1.0
# split4_train_score                                                           1.0
# split5_train_score                                                           1.0
# split6_train_score                                                           1.0
# split7_train_score                                                           1.0
# split8_train_score                                                           1.0
# split9_train_score                                                           1.0
# mean_train_score                                                             1.0
# std_train_score                                                              0.0
#
#                                                                              170  \
# mean_fit_time                                                           0.002546
# std_fit_time                                                            0.001587
# mean_score_time                                                         0.000992
# std_score_time                                                          0.000586
# param_classifier                                           KNeighborsRegressor()
# param_classifier__n_neighbors                                                  4
# param_classifier__p                                                            1
# param_classifier__weights                                                uniform
# param_preprocessing                                               RobustScaler()
# params                         {'classifier': KNeighborsRegressor(), 'classif...
# split0_test_score                                                       0.695927
# split1_test_score                                                       0.695504
# split2_test_score                                                       0.722844
# split3_test_score                                                       0.834903
# split4_test_score                                                       0.865256
# split5_test_score                                                       0.610421
# split6_test_score                                                       0.830988
# split7_test_score                                                       0.784948
# split8_test_score                                                       0.868688
# split9_test_score                                                       0.774883
# mean_test_score                                                         0.768436
# std_test_score                                                          0.081051
# rank_test_score                                                                6
# split0_train_score                                                      0.878703
# split1_train_score                                                      0.861926
# split2_train_score                                                      0.861165
# split3_train_score                                                      0.837701
# split4_train_score                                                       0.88421
# split5_train_score                                                      0.872021
# split6_train_score                                                      0.869241
# split7_train_score                                                      0.883335
# split8_train_score                                                       0.86602
# split9_train_score                                                      0.872852
# mean_train_score                                                        0.868717
# std_train_score                                                         0.012861
#
#                                                                              125  \
# mean_fit_time                                                            0.00123
# std_fit_time                                                            0.000695
# mean_score_time                                                         0.001184
# std_score_time                                                          0.001322
# param_classifier                                           KNeighborsRegressor()
# param_classifier__n_neighbors                                                  3
# param_classifier__p                                                            2
# param_classifier__weights                                               distance
# param_preprocessing                                             StandardScaler()
# params                         {'classifier': KNeighborsRegressor(), 'classif...
# split0_test_score                                                       0.593817
# split1_test_score                                                       0.679686
# split2_test_score                                                       0.726262
# split3_test_score                                                       0.844048
# split4_test_score                                                       0.882491
# split5_test_score                                                       0.680818
# split6_test_score                                                       0.825354
# split7_test_score                                                       0.777351
# split8_test_score                                                       0.864779
# split9_test_score                                                       0.797497
# mean_test_score                                                          0.76721
# std_test_score                                                          0.089432
# rank_test_score                                                                7
# split0_train_score                                                           1.0
# split1_train_score                                                           1.0
# split2_train_score                                                           1.0
# split3_train_score                                                           1.0
# split4_train_score                                                           1.0
# split5_train_score                                                           1.0
# split6_train_score                                                           1.0
# split7_train_score                                                           1.0
# split8_train_score                                                           1.0
# split9_train_score                                                           1.0
# mean_train_score                                                             1.0
# std_train_score                                                              0.0
#
#                                                                              245  \
# mean_fit_time                                                           0.001392
# std_fit_time                                                            0.000621
# mean_score_time                                                         0.001717
# std_score_time                                                          0.000957
# param_classifier                                           KNeighborsRegressor()
# param_classifier__n_neighbors                                                  5
# param_classifier__p                                                            3
# param_classifier__weights                                               distance
# param_preprocessing                                             StandardScaler()
# params                         {'classifier': KNeighborsRegressor(), 'classif...
# split0_test_score                                                       0.599554
# split1_test_score                                                        0.74877
# split2_test_score                                                       0.709671
# split3_test_score                                                       0.822536
# split4_test_score                                                       0.850752
# split5_test_score                                                       0.661076
# split6_test_score                                                       0.836931
# split7_test_score                                                       0.713312
# split8_test_score                                                       0.836487
# split9_test_score                                                        0.81755
# mean_test_score                                                         0.759664
# std_test_score                                                          0.082216
# rank_test_score                                                                8
# split0_train_score                                                           1.0
# split1_train_score                                                           1.0
# split2_train_score                                                           1.0
# split3_train_score                                                           1.0
# split4_train_score                                                           1.0
# split5_train_score                                                           1.0
# split6_train_score                                                           1.0
# split7_train_score                                                           1.0
# split8_train_score                                                           1.0
# split9_train_score                                                           1.0
# mean_train_score                                                             1.0
# std_train_score                                                              0.0
#
#                                                                              113  \
# mean_fit_time                                                           0.001325
# std_fit_time                                                            0.000556
# mean_score_time                                                         0.000817
# std_score_time                                                          0.000369
# param_classifier                                           KNeighborsRegressor()
# param_classifier__n_neighbors                                                  3
# param_classifier__p                                                            1
# param_classifier__weights                                                uniform
# param_preprocessing                                             StandardScaler()
# params                         {'classifier': KNeighborsRegressor(), 'classif...
# split0_test_score                                                       0.652117
# split1_test_score                                                       0.737166
# split2_test_score                                                       0.747766
# split3_test_score                                                       0.786788
# split4_test_score                                                        0.90048
# split5_test_score                                                       0.640463
# split6_test_score                                                        0.79213
# split7_test_score                                                       0.773517
# split8_test_score                                                       0.898895
# split9_test_score                                                       0.656221
# mean_test_score                                                         0.758554
# std_test_score                                                          0.088492
# rank_test_score                                                                9
# split0_train_score                                                      0.902097
# split1_train_score                                                      0.885584
# split2_train_score                                                      0.879364
# split3_train_score                                                      0.870939
# split4_train_score                                                      0.884403
# split5_train_score                                                      0.897317
# split6_train_score                                                      0.884486
# split7_train_score                                                       0.89091
# split8_train_score                                                      0.891289
# split9_train_score                                                      0.904129
# mean_train_score                                                        0.889052
# std_train_score                                                          0.00975
#
#                                                                              118  \
# mean_fit_time                                                           0.001598
# std_fit_time                                                            0.000079
# mean_score_time                                                         0.000636
# std_score_time                                                          0.000025
# param_classifier                                           KNeighborsRegressor()
# param_classifier__n_neighbors                                                  3
# param_classifier__p                                                            1
# param_classifier__weights                                               distance
# param_preprocessing                                               RobustScaler()
# params                         {'classifier': KNeighborsRegressor(), 'classif...
# split0_test_score                                                       0.703209
# split1_test_score                                                       0.686472
# split2_test_score                                                       0.627679
# split3_test_score                                                        0.87075
# split4_test_score                                                       0.839514
# split5_test_score                                                       0.676324
# split6_test_score                                                        0.77281
# split7_test_score                                                        0.76448
# split8_test_score                                                       0.883768
# split9_test_score                                                       0.757852
# mean_test_score                                                         0.758286
# std_test_score                                                          0.081981
# rank_test_score                                                               10
# split0_train_score                                                           1.0
# split1_train_score                                                           1.0
# split2_train_score                                                           1.0
# split3_train_score                                                           1.0
# split4_train_score                                                           1.0
# split5_train_score                                                           1.0
# split6_train_score                                                           1.0
# split7_train_score                                                           1.0
# split8_train_score                                                           1.0
# split9_train_score                                                           1.0
# mean_train_score                                                             1.0
# std_train_score                                                              0.0
#
#                                ...  \
# mean_fit_time                  ...
# std_fit_time                   ...
# mean_score_time                ...
# std_score_time                 ...
# param_classifier               ...
# param_classifier__n_neighbors  ...
# param_classifier__p            ...
# param_classifier__weights      ...
# param_preprocessing            ...
# params                         ...
# split0_test_score              ...
# split1_test_score              ...
# split2_test_score              ...
# split3_test_score              ...
# split4_test_score              ...
# split5_test_score              ...
# split6_test_score              ...
# split7_test_score              ...
# split8_test_score              ...
# split9_test_score              ...
# mean_test_score                ...
# std_test_score                 ...
# rank_test_score                ...
# split0_train_score             ...
# split1_train_score             ...
# split2_train_score             ...
# split3_train_score             ...
# split4_train_score             ...
# split5_train_score             ...
# split6_train_score             ...
# split7_train_score             ...
# split8_train_score             ...
# split9_train_score             ...
# mean_train_score               ...
# std_train_score                ...
#
#                                                                              15   \
# mean_fit_time                                                           0.000556
# std_fit_time                                                            0.000072
# mean_score_time                                                         0.000559
# std_score_time                                                          0.000043
# param_classifier                                           KNeighborsRegressor()
# param_classifier__n_neighbors                                                  1
# param_classifier__p                                                            2
# param_classifier__weights                                               distance
# param_preprocessing                                                         None
# params                         {'classifier': KNeighborsRegressor(), 'classif...
# split0_test_score                                                       0.301531
# split1_test_score                                                       0.203464
# split2_test_score                                                        0.54796
# split3_test_score                                                       0.390113
# split4_test_score                                                       0.408192
# split5_test_score                                                      -0.000741
# split6_test_score                                                       0.399585
# split7_test_score                                                       0.615872
# split8_test_score                                                       0.564096
# split9_test_score                                                       0.000577
# mean_test_score                                                         0.343065
# std_test_score                                                          0.207756
# rank_test_score                                                              271
# split0_train_score                                                           1.0
# split1_train_score                                                           1.0
# split2_train_score                                                           1.0
# split3_train_score                                                           1.0
# split4_train_score                                                           1.0
# split5_train_score                                                           1.0
# split6_train_score                                                           1.0
# split7_train_score                                                           1.0
# split8_train_score                                                           1.0
# split9_train_score                                                           1.0
# mean_train_score                                                             1.0
# std_train_score                                                              0.0
#
#                                                                              11   \
# mean_fit_time                                                           0.000669
# std_fit_time                                                            0.000302
# mean_score_time                                                         0.000627
# std_score_time                                                          0.000233
# param_classifier                                           KNeighborsRegressor()
# param_classifier__n_neighbors                                                  1
# param_classifier__p                                                            2
# param_classifier__weights                                                uniform
# param_preprocessing                                                         None
# params                         {'classifier': KNeighborsRegressor(), 'classif...
# split0_test_score                                                       0.301531
# split1_test_score                                                       0.203464
# split2_test_score                                                        0.54796
# split3_test_score                                                       0.390113
# split4_test_score                                                       0.408192
# split5_test_score                                                      -0.000741
# split6_test_score                                                       0.399585
# split7_test_score                                                       0.615872
# split8_test_score                                                       0.564096
# split9_test_score                                                       0.000577
# mean_test_score                                                         0.343065
# std_test_score                                                          0.207756
# rank_test_score                                                              271
# split0_train_score                                                           1.0
# split1_train_score                                                           1.0
# split2_train_score                                                           1.0
# split3_train_score                                                           1.0
# split4_train_score                                                           1.0
# split5_train_score                                                           1.0
# split6_train_score                                                           1.0
# split7_train_score                                                           1.0
# split8_train_score                                                           1.0
# split9_train_score                                                           1.0
# mean_train_score                                                             1.0
# std_train_score                                                              0.0
#
#                                                                              23   \
# mean_fit_time                                                           0.000874
# std_fit_time                                                            0.000443
# mean_score_time                                                          0.00151
# std_score_time                                                          0.000916
# param_classifier                                           KNeighborsRegressor()
# param_classifier__n_neighbors                                                  1
# param_classifier__p                                                            3
# param_classifier__weights                                               distance
# param_preprocessing                                                         None
# params                         {'classifier': KNeighborsRegressor(), 'classif...
# split0_test_score                                                       0.266652
# split1_test_score                                                       0.210002
# split2_test_score                                                       0.549817
# split3_test_score                                                       0.397123
# split4_test_score                                                       0.330076
# split5_test_score                                                      -0.008119
# split6_test_score                                                       0.319641
# split7_test_score                                                       0.561959
# split8_test_score                                                         0.5409
# split9_test_score                                                       0.230135
# mean_test_score                                                         0.339819
# std_test_score                                                          0.171162
# rank_test_score                                                              273
# split0_train_score                                                           1.0
# split1_train_score                                                           1.0
# split2_train_score                                                           1.0
# split3_train_score                                                           1.0
# split4_train_score                                                           1.0
# split5_train_score                                                           1.0
# split6_train_score                                                           1.0
# split7_train_score                                                           1.0
# split8_train_score                                                           1.0
# split9_train_score                                                           1.0
# mean_train_score                                                             1.0
# std_train_score                                                              0.0
#
#                                                                              19   \
# mean_fit_time                                                           0.000602
# std_fit_time                                                             0.00008
# mean_score_time                                                         0.000852
# std_score_time                                                          0.000065
# param_classifier                                           KNeighborsRegressor()
# param_classifier__n_neighbors                                                  1
# param_classifier__p                                                            3
# param_classifier__weights                                                uniform
# param_preprocessing                                                         None
# params                         {'classifier': KNeighborsRegressor(), 'classif...
# split0_test_score                                                       0.266652
# split1_test_score                                                       0.210002
# split2_test_score                                                       0.549817
# split3_test_score                                                       0.397123
# split4_test_score                                                       0.330076
# split5_test_score                                                      -0.008119
# split6_test_score                                                       0.319641
# split7_test_score                                                       0.561959
# split8_test_score                                                         0.5409
# split9_test_score                                                       0.230135
# mean_test_score                                                         0.339819
# std_test_score                                                          0.171162
# rank_test_score                                                              273
# split0_train_score                                                           1.0
# split1_train_score                                                           1.0
# split2_train_score                                                           1.0
# split3_train_score                                                           1.0
# split4_train_score                                                           1.0
# split5_train_score                                                           1.0
# split6_train_score                                                           1.0
# split7_train_score                                                           1.0
# split8_train_score                                                           1.0
# split9_train_score                                                           1.0
# mean_train_score                                                             1.0
# std_train_score                                                              0.0
#
#                                                                              39   \
# mean_fit_time                                                           0.000988
# std_fit_time                                                            0.000474
# mean_score_time                                                         0.001531
# std_score_time                                                          0.000851
# param_classifier                                           KNeighborsRegressor()
# param_classifier__n_neighbors                                                  1
# param_classifier__p                                                            6
# param_classifier__weights                                               distance
# param_preprocessing                                                         None
# params                         {'classifier': KNeighborsRegressor(), 'classif...
# split0_test_score                                                       0.318254
# split1_test_score                                                       0.188997
# split2_test_score                                                       0.552547
# split3_test_score                                                       0.413432
# split4_test_score                                                       0.443144
# split5_test_score                                                      -0.005599
# split6_test_score                                                       0.300615
# split7_test_score                                                       0.559957
# split8_test_score                                                       0.268204
# split9_test_score                                                       0.239443
# mean_test_score                                                         0.327899
# std_test_score                                                          0.163602
# rank_test_score                                                              275
# split0_train_score                                                           1.0
# split1_train_score                                                           1.0
# split2_train_score                                                           1.0
# split3_train_score                                                           1.0
# split4_train_score                                                           1.0
# split5_train_score                                                           1.0
# split6_train_score                                                           1.0
# split7_train_score                                                           1.0
# split8_train_score                                                           1.0
# split9_train_score                                                           1.0
# mean_train_score                                                             1.0
# std_train_score                                                              0.0
#
#                                                                              35   \
# mean_fit_time                                                           0.001157
# std_fit_time                                                            0.000406
# mean_score_time                                                         0.001729
# std_score_time                                                          0.001249
# param_classifier                                           KNeighborsRegressor()
# param_classifier__n_neighbors                                                  1
# param_classifier__p                                                            6
# param_classifier__weights                                                uniform
# param_preprocessing                                                         None
# params                         {'classifier': KNeighborsRegressor(), 'classif...
# split0_test_score                                                       0.318254
# split1_test_score                                                       0.188997
# split2_test_score                                                       0.552547
# split3_test_score                                                       0.413432
# split4_test_score                                                       0.443144
# split5_test_score                                                      -0.005599
# split6_test_score                                                       0.300615
# split7_test_score                                                       0.559957
# split8_test_score                                                       0.268204
# split9_test_score                                                       0.239443
# mean_test_score                                                         0.327899
# std_test_score                                                          0.163602
# rank_test_score                                                              275
# split0_train_score                                                           1.0
# split1_train_score                                                           1.0
# split2_train_score                                                           1.0
# split3_train_score                                                           1.0
# split4_train_score                                                           1.0
# split5_train_score                                                           1.0
# split6_train_score                                                           1.0
# split7_train_score                                                           1.0
# split8_train_score                                                           1.0
# split9_train_score                                                           1.0
# mean_train_score                                                             1.0
# std_train_score                                                              0.0
#
#                                                                              51   \
# mean_fit_time                                                           0.000782
# std_fit_time                                                             0.00035
# mean_score_time                                                         0.001243
# std_score_time                                                           0.00067
# param_classifier                                           KNeighborsRegressor()
# param_classifier__n_neighbors                                                  1
# param_classifier__p                                                           10
# param_classifier__weights                                                uniform
# param_preprocessing                                                         None
# params                         {'classifier': KNeighborsRegressor(), 'classif...
# split0_test_score                                                        0.33446
# split1_test_score                                                       0.188997
# split2_test_score                                                       0.500959
# split3_test_score                                                       0.413432
# split4_test_score                                                       0.382026
# split5_test_score                                                      -0.014185
# split6_test_score                                                       0.300154
# split7_test_score                                                       0.555172
# split8_test_score                                                       0.525762
# split9_test_score                                                      -0.193726
# mean_test_score                                                         0.299305
# std_test_score                                                           0.23066
# rank_test_score                                                              277
# split0_train_score                                                           1.0
# split1_train_score                                                           1.0
# split2_train_score                                                           1.0
# split3_train_score                                                           1.0
# split4_train_score                                                           1.0
# split5_train_score                                                           1.0
# split6_train_score                                                           1.0
# split7_train_score                                                           1.0
# split8_train_score                                                           1.0
# split9_train_score                                                           1.0
# mean_train_score                                                             1.0
# std_train_score                                                              0.0
#
#                                                                              55   \
# mean_fit_time                                                           0.000758
# std_fit_time                                                             0.00033
# mean_score_time                                                         0.001139
# std_score_time                                                          0.000614
# param_classifier                                           KNeighborsRegressor()
# param_classifier__n_neighbors                                                  1
# param_classifier__p                                                           10
# param_classifier__weights                                               distance
# param_preprocessing                                                         None
# params                         {'classifier': KNeighborsRegressor(), 'classif...
# split0_test_score                                                        0.33446
# split1_test_score                                                       0.188997
# split2_test_score                                                       0.500959
# split3_test_score                                                       0.413432
# split4_test_score                                                       0.382026
# split5_test_score                                                      -0.014185
# split6_test_score                                                       0.300154
# split7_test_score                                                       0.555172
# split8_test_score                                                       0.525762
# split9_test_score                                                      -0.193726
# mean_test_score                                                         0.299305
# std_test_score                                                           0.23066
# rank_test_score                                                              277
# split0_train_score                                                           1.0
# split1_train_score                                                           1.0
# split2_train_score                                                           1.0
# split3_train_score                                                           1.0
# split4_train_score                                                           1.0
# split5_train_score                                                           1.0
# split6_train_score                                                           1.0
# split7_train_score                                                           1.0
# split8_train_score                                                           1.0
# split9_train_score                                                           1.0
# mean_train_score                                                             1.0
# std_train_score                                                              0.0
#
#                                                                              43   \
# mean_fit_time                                                           0.000833
# std_fit_time                                                            0.000408
# mean_score_time                                                         0.001259
# std_score_time                                                          0.000674
# param_classifier                                           KNeighborsRegressor()
# param_classifier__n_neighbors                                                  1
# param_classifier__p                                                            8
# param_classifier__weights                                                uniform
# param_preprocessing                                                         None
# params                         {'classifier': KNeighborsRegressor(), 'classif...
# split0_test_score                                                        0.33446
# split1_test_score                                                       0.188997
# split2_test_score                                                       0.552547
# split3_test_score                                                       0.413432
# split4_test_score                                                       0.382026
# split5_test_score                                                      -0.014185
# split6_test_score                                                       0.300154
# split7_test_score                                                       0.555172
# split8_test_score                                                       0.268204
# split9_test_score                                                      -0.193726
# mean_test_score                                                         0.278708
# std_test_score                                                           0.22382
# rank_test_score                                                              279
# split0_train_score                                                           1.0
# split1_train_score                                                           1.0
# split2_train_score                                                           1.0
# split3_train_score                                                           1.0
# split4_train_score                                                           1.0
# split5_train_score                                                           1.0
# split6_train_score                                                           1.0
# split7_train_score                                                           1.0
# split8_train_score                                                           1.0
# split9_train_score                                                           1.0
# mean_train_score                                                             1.0
# std_train_score                                                              0.0
#
#                                                                              47
# mean_fit_time                                                           0.000858
# std_fit_time                                                             0.00045
# mean_score_time                                                         0.001318
# std_score_time                                                          0.000795
# param_classifier                                           KNeighborsRegressor()
# param_classifier__n_neighbors                                                  1
# param_classifier__p                                                            8
# param_classifier__weights                                               distance
# param_preprocessing                                                         None
# params                         {'classifier': KNeighborsRegressor(), 'classif...
# split0_test_score                                                        0.33446
# split1_test_score                                                       0.188997
# split2_test_score                                                       0.552547
# split3_test_score                                                       0.413432
# split4_test_score                                                       0.382026
# split5_test_score                                                      -0.014185
# split6_test_score                                                       0.300154
# split7_test_score                                                       0.555172
# split8_test_score                                                       0.268204
# split9_test_score                                                      -0.193726
# mean_test_score                                                         0.278708
# std_test_score                                                           0.22382
# rank_test_score                                                              279
# split0_train_score                                                           1.0
# split1_train_score                                                           1.0
# split2_train_score                                                           1.0
# split3_train_score                                                           1.0
# split4_train_score                                                           1.0
# split5_train_score                                                           1.0
# split6_train_score                                                           1.0
# split7_train_score                                                           1.0
# split8_train_score                                                           1.0
# split9_train_score                                                           1.0
# mean_train_score                                                             1.0
# std_train_score                                                              0.0
#
# [35 rows x 280 columns]

# %%
grid.best_params_
# Out:
# {'classifier': KNeighborsRegressor(),
#  'classifier__n_neighbors': 4,
#  'classifier__p': 1,
#  'classifier__weights': 'distance',
#  'preprocessing': RobustScaler()}

# %%
pipe = Pipeline([('preprocessing', RobustScaler()), 
                 ('classifier', KNeighborsRegressor(n_neighbors=4, p=1, weights='distance'))])
pipe.fit(X_train, y_train)
y_pred = pipe.predict(X_test)
y_pred
# Out:
# array([22.02 , 15.085,  6.87 , 28.858, 29.038, 21.633, 16.651, 37.69 ,
#        29.612, 21.756, 21.056, 24.614, 21.59 , 20.695, 35.216, 46.431,
#        14.896, 22.237, 20.223, 24.561, 27.431, 19.669, 21.896, 12.145,
#        25.993, 20.24 , 20.411, 13.583, 21.448, 45.71 , 24.535, 24.854,
#        16.671, 31.077, 43.587, 11.746, 20.793, 44.613, 17.023, 23.037,
#        18.549, 24.842, 23.161, 31.21 , 19.122, 19.652, 20.702, 28.177,
#        47.867, 24.636, 33.604, 19.638, 13.446, 23.518, 15.247, 18.305,
#        21.496, 20.258, 13.291, 14.989, 16.823, 31.834, 19.117, 18.41 ,
#        17.094, 26.27 , 23.304, 13.557, 21.052, 42.657, 15.959, 12.884,
#        20.846, 19.693, 16.585, 17.037, 22.52 ,  9.292, 21.83 , 35.919,
#        11.707, 19.72 , 33.348, 17.751, 11.744, 19.2  , 25.518, 16.911,
#        20.476, 16.943, 21.001, 18.082, 26.76 , 18.103, 32.771, 20.752,
#        24.481, 14.667, 36.905, 13.941, 31.551, 21.119])

# %%
pipe.score(X_train, y_train)
# Out:
# 1.0

# %%
pipe.score(X_test, y_test)
# Out:
# 0.8488665505328123
