# %%
# Внимание!!! Важно, что бы файлы с данными и исполняемый файл находились в одной папке, 
# тогда пути к тестовым и тренировочным наборам будут содержать только имена файлов.
# 
# В пути к тренировочным и тестовым данным запрежается использовать абсалютную адресацию, 
# то есть адресацию, в которой присутствуют имена папок. Путь должен содержать только имя файла.
#
# Напоминание: под моделью машинного обучения понимаются все действия с исходными данными, 
# которые необходимо произвести, что бы сопоставить признаки целевому значению.

# %% [markdown]
# ### Область работы 1 (библиотеки)

# %%
# Данный блок в области 1 НЕ выполняется преподавателем
# 
# данный блок предназначен только для подключения необходимых библиотек
# запрещается подключать библиотеки в других блоках
# запрещается скрывать предупреждения системы
# установка дополнительных библиотек размещается прямо здесь (обязательно закоментированы)
# pip install

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from IPython.display import display
from sklearn.pipeline import make_pipeline, Pipeline
from sklearn.preprocessing import MinMaxScaler, StandardScaler
from sklearn.preprocessing import RobustScaler, Normalizer

from sklearn.model_selection import train_test_split, cross_val_score  
from sklearn.model_selection import GridSearchCV, KFold, StratifiedShuffleSplit
from sklearn.model_selection import ShuffleSplit

from sklearn.naive_bayes import GaussianNB, BernoulliNB
from sklearn.linear_model import LogisticRegression
from sklearn.neighbors import KNeighborsClassifier 

from sklearn.metrics import RocCurveDisplay
from sklearn.metrics import PrecisionRecallDisplay
from sklearn.metrics import ConfusionMatrixDisplay

from sklearn.metrics import confusion_matrix

from sklearn.metrics import classification_report

import sklearn
print(sklearn.__version__)
# Out:
# 1.3.1

# %% [markdown]
# ### Область работы 2 (поиск  модели .... )

# %%
# Данный блок(и) НЕ выполняются преподавателем в области 2
# блок(и) предназначены для поиска лучшей модели 
# должен быть понятен и очевиден отбор параметров модели
# оставляйте свои комментарии и разъяснения
# 
# Запрещается размещать данные блоки за пределами обасти 2
# Все блоки данной области должны быть выполнены
#
# ЗАПРЕЩАЕТСЯ ИСПОЛЬЗОВАТЬ ТЕСТОВЫЙ НАБОР
#
# Путь к тренировочному набору
# 

path_train = ... # содержит только имя файла, без имен папок !!!

# %% [markdown]
# ### Заведем данные, посмотрим на наличие пропущенных заначений и уберем дубликаты

# %%
path_train = 'train.csv'

df = pd.read_csv(path_train)
df.head()
df.info()                 #проверяем есть ли пропущенные данные (в нашем случае их нет)
df.describe()
df = df.drop_duplicates() #убираем строки-дубликаты
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1725 entries, 0 to 1724
# Data columns (total 12 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   fixed acidity         1725 non-null   float64
#  1   volatile acidity      1725 non-null   float64
#  2   citric acid           1725 non-null   float64
#  3   residual sugar        1725 non-null   float64
#  4   chlorides             1725 non-null   float64
#  5   free sulfur dioxide   1725 non-null   float64
#  6   total sulfur dioxide  1725 non-null   float64
#  7   density               1725 non-null   float64
#  8   pH                    1725 non-null   float64
#  9   sulphates             1725 non-null   float64
#  10  alcohol               1725 non-null   float64
#  11  quality               1725 non-null   int64
# dtypes: float64(11), int64(1)
# memory usage: 161.8 KB

# %% [markdown]
# ### Так как мы решаем задачу классификации, то разделим все вина на два класса: вина с качеством меньше 7 мы обозначим за 0, так как у них отсутсвует признак "хорошего качества", а вина с качеством больше 7 мы обозначим за 1, так как у них "хорошее качество" присутсвует.

# %%
df["Q"] = np.where(df['quality'] < 7, 0, 1) #т.к. мы решаем задачу классификации
df = df.drop(columns = ["quality"])
y = df.Q
X = df.iloc[:,:-1].values

# %% [markdown]
# ### Сплитуем наши данные и вводим стратификацию по y, чтобы данные делились равносильно их соотношению в всем наборе данных.

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.5, stratify=y)

# %% [markdown]
# Проверяем, что все данные у нас находятся в формате массива

# %%
X
# Out:
# array([[ 6.4 ,  0.17,  0.34, ...,  3.25,  0.49,  9.6 ],
#        [ 8.  ,  0.42,  0.36, ...,  3.13,  0.57, 12.3 ],
#        [ 6.7 ,  0.27,  0.25, ...,  3.22,  0.43,  9.3 ],
#        ...,
#        [ 7.  ,  0.53,  0.43, ...,  3.08,  0.5 , 12.5 ],
#        [ 5.9 ,  0.17,  0.29, ...,  3.41,  0.33, 13.7 ],
#        [ 5.5 ,  0.34,  0.26, ...,  3.55,  0.49, 13.  ]])

# %%
X_test.shape
# Out:
# (863, 11)

# %% [markdown]
# # Строим модели с помощью 3 мотодов: метода ближайших соседей, наивного байесовского метода и метода логистической регрессии

# %% [markdown]
# ## Строим модель методом ближайших соседей

# %%
pipe_1 = Pipeline([('preprocessing', RobustScaler()), 
                 ('classifier', KNeighborsClassifier())])

shuffle_split = ShuffleSplit(test_size = .3, train_size = .6, n_splits = 5, random_state = 42)

n_neighbors = [10, 25, 50, 70, 90]
p = [1,4,8,20,40,50,70]
weights=['uniform', 'distance']
scaling = [ MinMaxScaler(), StandardScaler(),RobustScaler(), Normalizer()]

param_grid =[
    {'preprocessing': scaling, 
     'classifier': [KNeighborsClassifier()],
     'classifier__n_neighbors': n_neighbors,
     'classifier__p': p,
     'classifier__weights': weights,
     'classifier__n_jobs' : [-1]
     }
]

grid = GridSearchCV(pipe_1, param_grid, cv = shuffle_split, return_train_score=True, scoring = 'precision')
grid.fit(X_train, y_train)
grid
# Out:
# GridSearchCV(cv=ShuffleSplit(n_splits=5, random_state=42, test_size=0.3, train_size=0.6),
#              estimator=Pipeline(steps=[('preprocessing', RobustScaler()),
#                                        ('classifier', KNeighborsClassifier())]),
#              param_grid=[{'classifier': [KNeighborsClassifier()],
#                           'classifier__n_jobs': [-1],
#                           'classifier__n_neighbors': [10, 25, 50, 70, 90],
#                           'classifier__p': [1, 4, 8, 20, 40, 50, 70],
#                           'classifier__weights': ['uniform', 'distance'],
#                           'preprocessing': [MinMaxScaler(), StandardScaler(),
#                                             RobustScaler(), Normalizer()]}],
#              return_train_score=True, scoring='precision')

# %%
grid_result = pd.DataFrame(grid.cv_results_).sort_values(["rank_test_score",'std_test_score']).T
grid_result
# Out:
#                                                                              249  \
# mean_fit_time                                                            0.00104
# std_fit_time                                                            0.000008
# mean_score_time                                                         0.018493
# std_score_time                                                          0.000772
# param_classifier                                          KNeighborsClassifier()
# param_classifier__n_jobs                                                      -1
# param_classifier__n_neighbors                                                 90
# param_classifier__p                                                           20
# param_classifier__weights                                                uniform
# param_preprocessing                                             StandardScaler()
# params                         {'classifier': KNeighborsClassifier(), 'classi...
# split0_test_score                                                       0.621951
# split1_test_score                                                       0.706667
# split2_test_score                                                       0.658824
# split3_test_score                                                       0.617978
# split4_test_score                                                       0.736842
# mean_test_score                                                         0.668452
# std_test_score                                                          0.046777
# rank_test_score                                                                1
# split0_train_score                                                      0.685083
# split1_train_score                                                      0.669173
# split2_train_score                                                      0.678363
# split3_train_score                                                      0.661017
# split4_train_score                                                      0.645503
# mean_train_score                                                        0.667828
# std_train_score                                                         0.013823
#
#                                                                              257  \
# mean_fit_time                                                           0.001083
# std_fit_time                                                            0.000015
# mean_score_time                                                          0.01905
# std_score_time                                                          0.000934
# param_classifier                                          KNeighborsClassifier()
# param_classifier__n_jobs                                                      -1
# param_classifier__n_neighbors                                                 90
# param_classifier__p                                                           40
# param_classifier__weights                                                uniform
# param_preprocessing                                             StandardScaler()
# params                         {'classifier': KNeighborsClassifier(), 'classi...
# split0_test_score                                                       0.621951
# split1_test_score                                                       0.702703
# split2_test_score                                                       0.651163
# split3_test_score                                                       0.617978
# split4_test_score                                                       0.736842
# mean_test_score                                                         0.666127
# std_test_score                                                          0.046545
# rank_test_score                                                                2
# split0_train_score                                                      0.677596
# split1_train_score                                                      0.674419
# split2_train_score                                                      0.687861
# split3_train_score                                                      0.672316
# split4_train_score                                                      0.647368
# mean_train_score                                                        0.671912
# std_train_score                                                         0.013383
#
#                                                                              233  \
# mean_fit_time                                                           0.001164
# std_fit_time                                                            0.000027
# mean_score_time                                                         0.019185
# std_score_time                                                          0.000918
# param_classifier                                          KNeighborsClassifier()
# param_classifier__n_jobs                                                      -1
# param_classifier__n_neighbors                                                 90
# param_classifier__p                                                            4
# param_classifier__weights                                                uniform
# param_preprocessing                                             StandardScaler()
# params                         {'classifier': KNeighborsClassifier(), 'classi...
# split0_test_score                                                       0.658824
# split1_test_score                                                       0.717647
# split2_test_score                                                       0.615385
# split3_test_score                                                       0.626263
# split4_test_score                                                       0.708861
# mean_test_score                                                         0.665396
# std_test_score                                                          0.041702
# rank_test_score                                                                3
# split0_train_score                                                      0.680628
# split1_train_score                                                          0.68
# split2_train_score                                                      0.684783
# split3_train_score                                                          0.67
# split4_train_score                                                      0.642512
# mean_train_score                                                        0.671585
# std_train_score                                                         0.015327
#
#                                                                              253  \
# mean_fit_time                                                           0.001086
# std_fit_time                                                            0.000007
# mean_score_time                                                         0.015824
# std_score_time                                                           0.00074
# param_classifier                                          KNeighborsClassifier()
# param_classifier__n_jobs                                                      -1
# param_classifier__n_neighbors                                                 90
# param_classifier__p                                                           20
# param_classifier__weights                                               distance
# param_preprocessing                                             StandardScaler()
# params                         {'classifier': KNeighborsClassifier(), 'classi...
# split0_test_score                                                          0.625
# split1_test_score                                                       0.709302
# split2_test_score                                                       0.643678
# split3_test_score                                                       0.614583
# split4_test_score                                                       0.734177
# mean_test_score                                                         0.665348
# std_test_score                                                          0.047632
# rank_test_score                                                                4
# split0_train_score                                                           1.0
# split1_train_score                                                           1.0
# split2_train_score                                                           1.0
# split3_train_score                                                           1.0
# split4_train_score                                                           1.0
# mean_train_score                                                             1.0
# std_train_score                                                              0.0
#
#                                                                              33   \
# mean_fit_time                                                           0.001031
# std_fit_time                                                            0.000011
# mean_score_time                                                         0.019562
# std_score_time                                                           0.00036
# param_classifier                                          KNeighborsClassifier()
# param_classifier__n_jobs                                                      -1
# param_classifier__n_neighbors                                                 10
# param_classifier__p                                                           40
# param_classifier__weights                                                uniform
# param_preprocessing                                             StandardScaler()
# params                         {'classifier': KNeighborsClassifier(), 'classi...
# split0_test_score                                                       0.607595
# split1_test_score                                                        0.72619
# split2_test_score                                                          0.675
# split3_test_score                                                       0.651163
# split4_test_score                                                       0.666667
# mean_test_score                                                         0.665323
# std_test_score                                                          0.038297
# rank_test_score                                                                5
# split0_train_score                                                      0.724868
# split1_train_score                                                      0.654676
# split2_train_score                                                      0.723757
# split3_train_score                                                      0.724324
# split4_train_score                                                      0.693989
# mean_train_score                                                        0.704323
# std_train_score                                                         0.027464
#
#                                                                              241  \
# mean_fit_time                                                            0.00108
# std_fit_time                                                            0.000012
# mean_score_time                                                         0.019072
# std_score_time                                                          0.000834
# param_classifier                                          KNeighborsClassifier()
# param_classifier__n_jobs                                                      -1
# param_classifier__n_neighbors                                                 90
# param_classifier__p                                                            8
# param_classifier__weights                                                uniform
# param_preprocessing                                             StandardScaler()
# params                         {'classifier': KNeighborsClassifier(), 'classi...
# split0_test_score                                                       0.635294
# split1_test_score                                                       0.707317
# split2_test_score                                                       0.643678
# split3_test_score                                                       0.622222
# split4_test_score                                                       0.717949
# mean_test_score                                                         0.665292
# std_test_score                                                          0.039398
# rank_test_score                                                                6
# split0_train_score                                                      0.682796
# split1_train_score                                                      0.671533
# split2_train_score                                                      0.685393
# split3_train_score                                                      0.645833
# split4_train_score                                                      0.642487
# mean_train_score                                                        0.665608
# std_train_score                                                         0.018153
#
#                                                                              265  \
# mean_fit_time                                                           0.001043
# std_fit_time                                                            0.000014
# mean_score_time                                                         0.019196
# std_score_time                                                           0.00068
# param_classifier                                          KNeighborsClassifier()
# param_classifier__n_jobs                                                      -1
# param_classifier__n_neighbors                                                 90
# param_classifier__p                                                           50
# param_classifier__weights                                                uniform
# param_preprocessing                                             StandardScaler()
# params                         {'classifier': KNeighborsClassifier(), 'classi...
# split0_test_score                                                       0.621951
# split1_test_score                                                       0.702703
# split2_test_score                                                       0.651163
# split3_test_score                                                       0.622222
# split4_test_score                                                       0.727273
# mean_test_score                                                         0.665062
# std_test_score                                                          0.042834
# rank_test_score                                                                7
# split0_train_score                                                      0.679348
# split1_train_score                                                      0.671875
# split2_train_score                                                      0.689655
# split3_train_score                                                      0.672316
# split4_train_score                                                      0.647368
# mean_train_score                                                        0.672113
# std_train_score                                                         0.013946
#
#                                                                              153  \
# mean_fit_time                                                           0.001069
# std_fit_time                                                            0.000009
# mean_score_time                                                         0.019644
# std_score_time                                                          0.000228
# param_classifier                                          KNeighborsClassifier()
# param_classifier__n_jobs                                                      -1
# param_classifier__n_neighbors                                                 50
# param_classifier__p                                                           50
# param_classifier__weights                                                uniform
# param_preprocessing                                             StandardScaler()
# params                         {'classifier': KNeighborsClassifier(), 'classi...
# split0_test_score                                                       0.629213
# split1_test_score                                                       0.732558
# split2_test_score                                                       0.619565
# split3_test_score                                                       0.638298
# split4_test_score                                                       0.698795
# mean_test_score                                                         0.663686
# std_test_score                                                          0.044171
# rank_test_score                                                                8
# split0_train_score                                                      0.666667
# split1_train_score                                                      0.666667
# split2_train_score                                                      0.695402
# split3_train_score                                                      0.664948
# split4_train_score                                                      0.652632
# mean_train_score                                                        0.669263
# std_train_score                                                         0.014085
#
#                                                                              161  \
# mean_fit_time                                                           0.001069
# std_fit_time                                                            0.000011
# mean_score_time                                                         0.019394
# std_score_time                                                          0.000073
# param_classifier                                          KNeighborsClassifier()
# param_classifier__n_jobs                                                      -1
# param_classifier__n_neighbors                                                 50
# param_classifier__p                                                           70
# param_classifier__weights                                                uniform
# param_preprocessing                                             StandardScaler()
# params                         {'classifier': KNeighborsClassifier(), 'classi...
# split0_test_score                                                       0.629213
# split1_test_score                                                       0.732558
# split2_test_score                                                       0.619565
# split3_test_score                                                       0.638298
# split4_test_score                                                       0.698795
# mean_test_score                                                         0.663686
# std_test_score                                                          0.044171
# rank_test_score                                                                8
# split0_train_score                                                      0.666667
# split1_train_score                                                      0.660131
# split2_train_score                                                      0.691429
# split3_train_score                                                      0.663212
# split4_train_score                                                      0.652632
# mean_train_score                                                        0.666814
# std_train_score                                                          0.01315
#
#                                                                              245  \
# mean_fit_time                                                           0.001069
# std_fit_time                                                            0.000009
# mean_score_time                                                         0.015178
# std_score_time                                                          0.000746
# param_classifier                                          KNeighborsClassifier()
# param_classifier__n_jobs                                                      -1
# param_classifier__n_neighbors                                                 90
# param_classifier__p                                                            8
# param_classifier__weights                                               distance
# param_preprocessing                                             StandardScaler()
# params                         {'classifier': KNeighborsClassifier(), 'classi...
# split0_test_score                                                       0.640449
# split1_test_score                                                       0.701149
# split2_test_score                                                       0.633333
# split3_test_score                                                          0.625
# split4_test_score                                                       0.714286
# mean_test_score                                                         0.662844
# std_test_score                                                          0.037197
# rank_test_score                                                               10
# split0_train_score                                                           1.0
# split1_train_score                                                           1.0
# split2_train_score                                                           1.0
# split3_train_score                                                           1.0
# split4_train_score                                                           1.0
# mean_train_score                                                             1.0
# std_train_score                                                              0.0
#
#                                ...  \
# mean_fit_time                  ...
# std_fit_time                   ...
# mean_score_time                ...
# std_score_time                 ...
# param_classifier               ...
# param_classifier__n_jobs       ...
# param_classifier__n_neighbors  ...
# param_classifier__p            ...
# param_classifier__weights      ...
# param_preprocessing            ...
# params                         ...
# split0_test_score              ...
# split1_test_score              ...
# split2_test_score              ...
# split3_test_score              ...
# split4_test_score              ...
# mean_test_score                ...
# std_test_score                 ...
# rank_test_score                ...
# split0_train_score             ...
# split1_train_score             ...
# split2_train_score             ...
# split3_train_score             ...
# split4_train_score             ...
# mean_train_score               ...
# std_train_score                ...
#
#                                                                              259  \
# mean_fit_time                                                           0.001018
# std_fit_time                                                            0.000043
# mean_score_time                                                         0.019976
# std_score_time                                                          0.000403
# param_classifier                                          KNeighborsClassifier()
# param_classifier__n_jobs                                                      -1
# param_classifier__n_neighbors                                                 90
# param_classifier__p                                                           40
# param_classifier__weights                                                uniform
# param_preprocessing                                                 Normalizer()
# params                         {'classifier': KNeighborsClassifier(), 'classi...
# split0_test_score                                                       0.574074
# split1_test_score                                                       0.586957
# split2_test_score                                                       0.603448
# split3_test_score                                                       0.515152
# split4_test_score                                                       0.660377
# mean_test_score                                                         0.588002
# std_test_score                                                          0.046859
# rank_test_score                                                              271
# split0_train_score                                                       0.63964
# split1_train_score                                                      0.609756
# split2_train_score                                                      0.630769
# split3_train_score                                                      0.590909
# split4_train_score                                                      0.628571
# mean_train_score                                                        0.619929
# std_train_score                                                         0.017472
#
#                                                                              171  \
# mean_fit_time                                                           0.000998
# std_fit_time                                                            0.000013
# mean_score_time                                                         0.019769
# std_score_time                                                          0.000189
# param_classifier                                          KNeighborsClassifier()
# param_classifier__n_jobs                                                      -1
# param_classifier__n_neighbors                                                 70
# param_classifier__p                                                            1
# param_classifier__weights                                                uniform
# param_preprocessing                                                 Normalizer()
# params                         {'classifier': KNeighborsClassifier(), 'classi...
# split0_test_score                                                       0.597015
# split1_test_score                                                           0.58
# split2_test_score                                                       0.623188
# split3_test_score                                                       0.557143
# split4_test_score                                                       0.576923
# mean_test_score                                                         0.586854
# std_test_score                                                          0.022144
# rank_test_score                                                              272
# split0_train_score                                                      0.602484
# split1_train_score                                                      0.622642
# split2_train_score                                                      0.585227
# split3_train_score                                                       0.60241
# split4_train_score                                                      0.614865
# mean_train_score                                                        0.605526
# std_train_score                                                         0.012737
#
#                                                                              250  \
# mean_fit_time                                                           0.002127
# std_fit_time                                                            0.000019
# mean_score_time                                                         0.018216
# std_score_time                                                          0.000953
# param_classifier                                          KNeighborsClassifier()
# param_classifier__n_jobs                                                      -1
# param_classifier__n_neighbors                                                 90
# param_classifier__p                                                           20
# param_classifier__weights                                                uniform
# param_preprocessing                                               RobustScaler()
# params                         {'classifier': KNeighborsClassifier(), 'classi...
# split0_test_score                                                       0.588235
# split1_test_score                                                       0.635135
# split2_test_score                                                       0.602273
# split3_test_score                                                       0.539216
# split4_test_score                                                       0.565217
# mean_test_score                                                         0.586015
# std_test_score                                                          0.032572
# rank_test_score                                                              273
# split0_train_score                                                      0.642857
# split1_train_score                                                      0.642857
# split2_train_score                                                      0.616216
# split3_train_score                                                      0.654054
# split4_train_score                                                      0.610526
# mean_train_score                                                        0.633302
# std_train_score                                                         0.016875
#
#                                                                              175  \
# mean_fit_time                                                           0.001095
# std_fit_time                                                            0.000033
# mean_score_time                                                         0.016399
# std_score_time                                                          0.000113
# param_classifier                                          KNeighborsClassifier()
# param_classifier__n_jobs                                                      -1
# param_classifier__n_neighbors                                                 70
# param_classifier__p                                                            1
# param_classifier__weights                                               distance
# param_preprocessing                                                 Normalizer()
# params                         {'classifier': KNeighborsClassifier(), 'classi...
# split0_test_score                                                       0.591549
# split1_test_score                                                            0.6
# split2_test_score                                                       0.602941
# split3_test_score                                                       0.554054
# split4_test_score                                                          0.575
# mean_test_score                                                         0.584709
# std_test_score                                                          0.018149
# rank_test_score                                                              274
# split0_train_score                                                           1.0
# split1_train_score                                                           1.0
# split2_train_score                                                           1.0
# split3_train_score                                                           1.0
# split4_train_score                                                           1.0
# mean_train_score                                                             1.0
# std_train_score                                                              0.0
#
#                                                                              235  \
# mean_fit_time                                                           0.001102
# std_fit_time                                                            0.000017
# mean_score_time                                                         0.019867
# std_score_time                                                          0.000538
# param_classifier                                          KNeighborsClassifier()
# param_classifier__n_jobs                                                      -1
# param_classifier__n_neighbors                                                 90
# param_classifier__p                                                            4
# param_classifier__weights                                                uniform
# param_preprocessing                                                 Normalizer()
# params                         {'classifier': KNeighborsClassifier(), 'classi...
# split0_test_score                                                       0.596154
# split1_test_score                                                       0.605263
# split2_test_score                                                       0.596491
# split3_test_score                                                       0.492958
# split4_test_score                                                       0.631579
# mean_test_score                                                         0.584489
# std_test_score                                                          0.047554
# rank_test_score                                                              275
# split0_train_score                                                      0.646018
# split1_train_score                                                      0.585366
# split2_train_score                                                      0.607143
# split3_train_score                                                      0.601449
# split4_train_score                                                      0.623853
# mean_train_score                                                        0.612766
# std_train_score                                                         0.020684
#
#                                                                              115  \
# mean_fit_time                                                           0.001001
# std_fit_time                                                            0.000019
# mean_score_time                                                         0.019694
# std_score_time                                                          0.000212
# param_classifier                                          KNeighborsClassifier()
# param_classifier__n_jobs                                                      -1
# param_classifier__n_neighbors                                                 50
# param_classifier__p                                                            1
# param_classifier__weights                                                uniform
# param_preprocessing                                                 Normalizer()
# params                         {'classifier': KNeighborsClassifier(), 'classi...
# split0_test_score                                                       0.549296
# split1_test_score                                                       0.636364
# split2_test_score                                                            0.6
# split3_test_score                                                       0.561644
# split4_test_score                                                       0.564103
# mean_test_score                                                         0.582281
# std_test_score                                                          0.031885
# rank_test_score                                                              276
# split0_train_score                                                      0.604938
# split1_train_score                                                      0.598131
# split2_train_score                                                      0.587912
# split3_train_score                                                      0.612121
# split4_train_score                                                      0.612676
# mean_train_score                                                        0.603156
# std_train_score                                                         0.009293
#
#                                                                              7    \
# mean_fit_time                                                           0.001334
# std_fit_time                                                            0.000039
# mean_score_time                                                          0.01652
# std_score_time                                                          0.000161
# param_classifier                                          KNeighborsClassifier()
# param_classifier__n_jobs                                                      -1
# param_classifier__n_neighbors                                                 10
# param_classifier__p                                                            1
# param_classifier__weights                                               distance
# param_preprocessing                                                 Normalizer()
# params                         {'classifier': KNeighborsClassifier(), 'classi...
# split0_test_score                                                       0.607595
# split1_test_score                                                       0.632911
# split2_test_score                                                         0.5375
# split3_test_score                                                       0.561798
# split4_test_score                                                       0.554348
# mean_test_score                                                          0.57883
# std_test_score                                                          0.035637
# rank_test_score                                                              277
# split0_train_score                                                           1.0
# split1_train_score                                                           1.0
# split2_train_score                                                           1.0
# split3_train_score                                                           1.0
# split4_train_score                                                           1.0
# mean_train_score                                                             1.0
# std_train_score                                                              0.0
#
#                                                                              59   \
# mean_fit_time                                                           0.001068
# std_fit_time                                                            0.000059
# mean_score_time                                                         0.019729
# std_score_time                                                          0.001275
# param_classifier                                          KNeighborsClassifier()
# param_classifier__n_jobs                                                      -1
# param_classifier__n_neighbors                                                 25
# param_classifier__p                                                            1
# param_classifier__weights                                                uniform
# param_preprocessing                                                 Normalizer()
# params                         {'classifier': KNeighborsClassifier(), 'classi...
# split0_test_score                                                       0.533333
# split1_test_score                                                       0.683333
# split2_test_score                                                        0.56338
# split3_test_score                                                       0.545455
# split4_test_score                                                        0.54321
# mean_test_score                                                         0.573742
# std_test_score                                                          0.055647
# rank_test_score                                                              278
# split0_train_score                                                      0.632768
# split1_train_score                                                      0.652893
# split2_train_score                                                      0.672131
# split3_train_score                                                      0.636364
# split4_train_score                                                      0.652695
# mean_train_score                                                         0.64937
# std_train_score                                                         0.014045
#
#                                                                              227  \
# mean_fit_time                                                           0.001009
# std_fit_time                                                            0.000007
# mean_score_time                                                         0.019817
# std_score_time                                                           0.00009
# param_classifier                                          KNeighborsClassifier()
# param_classifier__n_jobs                                                      -1
# param_classifier__n_neighbors                                                 90
# param_classifier__p                                                            1
# param_classifier__weights                                                uniform
# param_preprocessing                                                 Normalizer()
# params                         {'classifier': KNeighborsClassifier(), 'classi...
# split0_test_score                                                       0.558824
# split1_test_score                                                       0.595745
# split2_test_score                                                       0.550725
# split3_test_score                                                        0.58209
# split4_test_score                                                       0.567568
# mean_test_score                                                          0.57099
# std_test_score                                                          0.016164
# rank_test_score                                                              279
# split0_train_score                                                      0.592105
# split1_train_score                                                      0.605769
# split2_train_score                                                      0.571429
# split3_train_score                                                      0.616352
# split4_train_score                                                      0.613793
# mean_train_score                                                         0.59989
# std_train_score                                                          0.01655
#
#                                                                              231
# mean_fit_time                                                           0.001044
# std_fit_time                                                            0.000014
# mean_score_time                                                         0.016482
# std_score_time                                                          0.000099
# param_classifier                                          KNeighborsClassifier()
# param_classifier__n_jobs                                                      -1
# param_classifier__n_neighbors                                                 90
# param_classifier__p                                                            1
# param_classifier__weights                                               distance
# param_preprocessing                                                 Normalizer()
# params                         {'classifier': KNeighborsClassifier(), 'classi...
# split0_test_score                                                       0.573529
# split1_test_score                                                       0.592593
# split2_test_score                                                       0.557143
# split3_test_score                                                       0.575342
# split4_test_score                                                           0.55
# mean_test_score                                                         0.569721
# std_test_score                                                          0.014942
# rank_test_score                                                              280
# split0_train_score                                                           1.0
# split1_train_score                                                           1.0
# split2_train_score                                                           1.0
# split3_train_score                                                           1.0
# split4_train_score                                                           1.0
# mean_train_score                                                             1.0
# std_train_score                                                              0.0
#
# [26 rows x 280 columns]

# %% [markdown]
# ### Выводим параметры модели с наилучшими результатами

# %%
print(grid.best_estimator_)
# Out:
# Pipeline(steps=[('preprocessing', StandardScaler()),
#                 ('classifier',
#                  KNeighborsClassifier(n_jobs=-1, n_neighbors=90, p=20))])

# %% [markdown]
# ### Записываем нашу модель с полученными лучшими результатами

# %%
pipe_1 = Pipeline([('preprocessing', StandardScaler()),
                ('classifier',
                 KNeighborsClassifier(n_jobs=-1, n_neighbors=70, p=4,
                                      weights='uniform'))])
pipe_1.fit(X_train, y_train)
# Out:
# Pipeline(steps=[('preprocessing', StandardScaler()),
#                 ('classifier',
#                  KNeighborsClassifier(n_jobs=-1, n_neighbors=70, p=4))])

# %%
pipe_1.fit(X_train,y_train)
y_pred_1 = pipe_1.predict(X_test)

# %% [markdown]
# ## Строим модель наивным байесовским методом

# %%
pipe_2 = Pipeline([('preprocessing', MinMaxScaler()), 
                 ('clf',           GaussianNB())])

cv = StratifiedShuffleSplit(test_size = .3, train_size = .6, n_splits = 5, random_state = 42)
scaling = [ MinMaxScaler(), StandardScaler(),RobustScaler(), Normalizer()]
wh = [GaussianNB(), BernoulliNB()]
param_grid =[
    {'preprocessing': scaling, 
     'clf': wh}
    ]

grid = GridSearchCV(pipe_2, param_grid, cv = shuffle_split, return_train_score=True, scoring = 'precision')
grid.fit(X_train, y_train)
grid
# Out:
# /Users/daria_otradnova/opt/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1469: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/daria_otradnova/opt/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1469: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/daria_otradnova/opt/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1469: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/daria_otradnova/opt/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1469: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/daria_otradnova/opt/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1469: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/daria_otradnova/opt/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1469: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/daria_otradnova/opt/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1469: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/daria_otradnova/opt/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1469: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/daria_otradnova/opt/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1469: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/daria_otradnova/opt/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1469: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/daria_otradnova/opt/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1469: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/daria_otradnova/opt/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1469: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# GridSearchCV(cv=ShuffleSplit(n_splits=5, random_state=42, test_size=0.3, train_size=0.6),
#              estimator=Pipeline(steps=[('preprocessing', MinMaxScaler()),
#                                        ('clf', GaussianNB())]),
#              param_grid=[{'clf': [GaussianNB(), BernoulliNB()],
#                           'preprocessing': [MinMaxScaler(), StandardScaler(),
#                                             RobustScaler(), Normalizer()]}],
#              return_train_score=True, scoring='precision')

# %%
grid_result = pd.DataFrame(grid.cv_results_).sort_values(["rank_test_score",'std_test_score']).T
grid_result
# Out:
#                                                                      6  \
# mean_fit_time                                                 0.002239
# std_fit_time                                                  0.000043
# mean_score_time                                               0.001243
# std_score_time                                                0.000009
# param_clf                                                BernoulliNB()
# param_preprocessing                                     RobustScaler()
# params               {'clf': BernoulliNB(), 'preprocessing': Robust...
# split0_test_score                                             0.560748
# split1_test_score                                             0.580645
# split2_test_score                                             0.616822
# split3_test_score                                             0.565217
# split4_test_score                                             0.635417
# mean_test_score                                                0.59177
# std_test_score                                                0.029407
# rank_test_score                                                      1
# split0_train_score                                            0.608696
# split1_train_score                                            0.566667
# split2_train_score                                            0.571429
# split3_train_score                                            0.607143
# split4_train_score                                            0.591928
# mean_train_score                                              0.589172
# std_train_score                                                0.01751
#
#                                                                      5  \
# mean_fit_time                                                 0.001139
# std_fit_time                                                   0.00001
# mean_score_time                                               0.001225
# std_score_time                                                0.000006
# param_clf                                                BernoulliNB()
# param_preprocessing                                   StandardScaler()
# params               {'clf': BernoulliNB(), 'preprocessing': Standa...
# split0_test_score                                             0.566038
# split1_test_score                                              0.59375
# split2_test_score                                             0.610619
# split3_test_score                                             0.566929
# split4_test_score                                             0.608247
# mean_test_score                                               0.589117
# std_test_score                                                0.019364
# rank_test_score                                                      2
# split0_train_score                                            0.607595
# split1_train_score                                            0.591549
# split2_train_score                                            0.585253
# split3_train_score                                            0.581897
# split4_train_score                                            0.570796
# mean_train_score                                              0.587418
# std_train_score                                               0.012129
#
#                                                                      0  \
# mean_fit_time                                                 0.001113
# std_fit_time                                                  0.000466
# mean_score_time                                               0.001238
# std_score_time                                                0.000129
# param_clf                                                 GaussianNB()
# param_preprocessing                                     MinMaxScaler()
# params               {'clf': GaussianNB(), 'preprocessing': MinMaxS...
# split0_test_score                                             0.579365
# split1_test_score                                             0.622378
# split2_test_score                                             0.591304
# split3_test_score                                             0.535211
# split4_test_score                                             0.598361
# mean_test_score                                               0.585324
# std_test_score                                                0.028725
# rank_test_score                                                      3
# split0_train_score                                            0.601562
# split1_train_score                                            0.565737
# split2_train_score                                             0.59387
# split3_train_score                                            0.608365
# split4_train_score                                            0.586716
# mean_train_score                                               0.59125
# std_train_score                                               0.014681
#
#                                                                      1  \
# mean_fit_time                                                 0.000938
# std_fit_time                                                  0.000014
# mean_score_time                                               0.001186
# std_score_time                                                0.000047
# param_clf                                                 GaussianNB()
# param_preprocessing                                   StandardScaler()
# params               {'clf': GaussianNB(), 'preprocessing': Standar...
# split0_test_score                                             0.579365
# split1_test_score                                             0.622378
# split2_test_score                                             0.591304
# split3_test_score                                             0.535211
# split4_test_score                                             0.598361
# mean_test_score                                               0.585324
# std_test_score                                                0.028725
# rank_test_score                                                      3
# split0_train_score                                            0.601562
# split1_train_score                                            0.565737
# split2_train_score                                             0.59387
# split3_train_score                                            0.608365
# split4_train_score                                            0.586716
# mean_train_score                                               0.59125
# std_train_score                                               0.014681
#
#                                                                      2  \
# mean_fit_time                                                 0.001991
# std_fit_time                                                  0.000045
# mean_score_time                                               0.001168
# std_score_time                                                0.000002
# param_clf                                                 GaussianNB()
# param_preprocessing                                     RobustScaler()
# params               {'clf': GaussianNB(), 'preprocessing': RobustS...
# split0_test_score                                             0.579365
# split1_test_score                                             0.622378
# split2_test_score                                             0.591304
# split3_test_score                                             0.535211
# split4_test_score                                             0.598361
# mean_test_score                                               0.585324
# std_test_score                                                0.028725
# rank_test_score                                                      3
# split0_train_score                                            0.601562
# split1_train_score                                            0.565737
# split2_train_score                                             0.59387
# split3_train_score                                            0.608365
# split4_train_score                                            0.586716
# mean_train_score                                               0.59125
# std_train_score                                               0.014681
#
#                                                                      4  \
# mean_fit_time                                                 0.001128
# std_fit_time                                                  0.000208
# mean_score_time                                               0.001334
# std_score_time                                                0.000204
# param_clf                                                BernoulliNB()
# param_preprocessing                                     MinMaxScaler()
# params               {'clf': BernoulliNB(), 'preprocessing': MinMax...
# split0_test_score                                                  0.0
# split1_test_score                                             0.857143
# split2_test_score                                                  0.8
# split3_test_score                                                  0.0
# split4_test_score                                                  1.0
# mean_test_score                                               0.531429
# std_test_score                                                0.438774
# rank_test_score                                                      6
# split0_train_score                                                 1.0
# split1_train_score                                                 1.0
# split2_train_score                                                 1.0
# split3_train_score                                                 1.0
# split4_train_score                                                 1.0
# mean_train_score                                                   1.0
# std_train_score                                                    0.0
#
#                                                                      3  \
# mean_fit_time                                                 0.000856
# std_fit_time                                                  0.000014
# mean_score_time                                                0.00124
# std_score_time                                                0.000004
# param_clf                                                 GaussianNB()
# param_preprocessing                                       Normalizer()
# params               {'clf': GaussianNB(), 'preprocessing': Normali...
# split0_test_score                                             0.473333
# split1_test_score                                             0.557823
# split2_test_score                                             0.396341
# split3_test_score                                             0.533333
# split4_test_score                                             0.408163
# mean_test_score                                               0.473799
# std_test_score                                                0.064672
# rank_test_score                                                      7
# split0_train_score                                            0.503067
# split1_train_score                                            0.494465
# split2_train_score                                            0.495495
# split3_train_score                                            0.543554
# split4_train_score                                            0.462366
# mean_train_score                                               0.49979
# std_train_score                                               0.025975
#
#                                                                      7
# mean_fit_time                                                 0.001035
# std_fit_time                                                  0.000011
# mean_score_time                                               0.001299
# std_score_time                                                0.000007
# param_clf                                                BernoulliNB()
# param_preprocessing                                       Normalizer()
# params               {'clf': BernoulliNB(), 'preprocessing': Normal...
# split0_test_score                                                  0.0
# split1_test_score                                                  0.0
# split2_test_score                                                  0.0
# split3_test_score                                                  0.0
# split4_test_score                                                  0.0
# mean_test_score                                                    0.0
# std_test_score                                                     0.0
# rank_test_score                                                      8
# split0_train_score                                                 0.0
# split1_train_score                                                 0.0
# split2_train_score                                                 0.0
# split3_train_score                                                 0.0
# split4_train_score                                                 0.0
# mean_train_score                                                   0.0
# std_train_score                                                    0.0

# %% [markdown]
# ### Выводим параметры модели с наилучшими результатами

# %%
print(grid.best_estimator_)
# Out:
# Pipeline(steps=[('preprocessing', RobustScaler()), ('clf', BernoulliNB())])

# %% [markdown]
# ### Записываем нашу модель с полученными лучшими результатами

# %%
pipe_2 = Pipeline([('preprocessing', RobustScaler()),
                ('clf',BernoulliNB())])
pipe_2.fit(X_train, y_train)
y_pred_2 = pipe_2.predict(X_test)

# %% [markdown]
# ## Строим модель методом логистической регрессии

# %%
pipe_3 = Pipeline([('preprocessing', MinMaxScaler()), 
                 ('clf',           LogisticRegression())])

# n_splits = 5, random_state = 42 дают не улачную комбинацию и это хорошо для разбора ошибок решетки
cv = StratifiedShuffleSplit(test_size = .3, train_size = .6, n_splits = 5, random_state = 42)
scaling = [ MinMaxScaler(), StandardScaler(),RobustScaler(), Normalizer()]

param_grid =[
    {'preprocessing': scaling,'clf__penalty': ['l2'], 
         'clf__solver': ['newton-cg' ,'lbfgs', 'liblinear', 'sag', 'saga']},
    {'preprocessing': scaling,'clf__penalty': ['l1'], 
         'clf__solver': ['liblinear']},
    {'preprocessing': scaling,'clf__penalty': ['none'], 
         'clf__solver': ['lbfgs','newton-cg']}
    ]

grid = GridSearchCV(pipe_3, param_grid, cv = shuffle_split, return_train_score=True, scoring = 'precision')
grid.fit(X_train, y_train)
grid
# Out:
# /Users/daria_otradnova/opt/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1469: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/daria_otradnova/opt/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1469: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/daria_otradnova/opt/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1469: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/daria_otradnova/opt/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1469: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/daria_otradnova/opt/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1469: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/daria_otradnova/opt/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1469: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/daria_otradnova/opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /Users/daria_otradnova/opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /Users/daria_otradnova/opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /Users/daria_otradnova/opt/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1469: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/daria_otradnova/opt/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1469: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/daria_otradnova/opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /Users/daria_otradnova/opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /Users/daria_otradnova/opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /Users/daria_otradnova/opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /Users/daria_otradnova/opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /Users/daria_otradnova/opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /Users/daria_otradnova/opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /Users/daria_otradnova/opt/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1469: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/daria_otradnova/opt/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1469: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/daria_otradnova/opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_logistic.py:1183: FutureWarning: `penalty='none'`has been deprecated in 1.2 and will be removed in 1.4. To keep the past behaviour, set `penalty=None`.
#   warnings.warn(
# /Users/daria_otradnova/opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_logistic.py:1183: FutureWarning: `penalty='none'`has been deprecated in 1.2 and will be removed in 1.4. To keep the past behaviour, set `penalty=None`.
#   warnings.warn(
# /Users/daria_otradnova/opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_logistic.py:1183: FutureWarning: `penalty='none'`has been deprecated in 1.2 and will be removed in 1.4. To keep the past behaviour, set `penalty=None`.
#   warnings.warn(
# /Users/daria_otradnova/opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_logistic.py:1183: FutureWarning: `penalty='none'`has been deprecated in 1.2 and will be removed in 1.4. To keep the past behaviour, set `penalty=None`.
#   warnings.warn(
# /Users/daria_otradnova/opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_logistic.py:1183: FutureWarning: `penalty='none'`has been deprecated in 1.2 and will be removed in 1.4. To keep the past behaviour, set `penalty=None`.
#   warnings.warn(
# /Users/daria_otradnova/opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_logistic.py:1183: FutureWarning: `penalty='none'`has been deprecated in 1.2 and will be removed in 1.4. To keep the past behaviour, set `penalty=None`.
#   warnings.warn(
# /Users/daria_otradnova/opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_logistic.py:1183: FutureWarning: `penalty='none'`has been deprecated in 1.2 and will be removed in 1.4. To keep the past behaviour, set `penalty=None`.
#   warnings.warn(
# /Users/daria_otradnova/opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_logistic.py:1183: FutureWarning: `penalty='none'`has been deprecated in 1.2 and will be removed in 1.4. To keep the past behaviour, set `penalty=None`.
#   warnings.warn(
# /Users/daria_otradnova/opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_logistic.py:1183: FutureWarning: `penalty='none'`has been deprecated in 1.2 and will be removed in 1.4. To keep the past behaviour, set `penalty=None`.
#   warnings.warn(
# /Users/daria_otradnova/opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_logistic.py:1183: FutureWarning: `penalty='none'`has been deprecated in 1.2 and will be removed in 1.4. To keep the past behaviour, set `penalty=None`.
#   warnings.warn(
# /Users/daria_otradnova/opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_logistic.py:1183: FutureWarning: `penalty='none'`has been deprecated in 1.2 and will be removed in 1.4. To keep the past behaviour, set `penalty=None`.
#   warnings.warn(
# /Users/daria_otradnova/opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_logistic.py:1183: FutureWarning: `penalty='none'`has been deprecated in 1.2 and will be removed in 1.4. To keep the past behaviour, set `penalty=None`.
#   warnings.warn(
# /Users/daria_otradnova/opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_logistic.py:1183: FutureWarning: `penalty='none'`has been deprecated in 1.2 and will be removed in 1.4. To keep the past behaviour, set `penalty=None`.
#   warnings.warn(
# /Users/daria_otradnova/opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_logistic.py:1183: FutureWarning: `penalty='none'`has been deprecated in 1.2 and will be removed in 1.4. To keep the past behaviour, set `penalty=None`.
#   warnings.warn(
# /Users/daria_otradnova/opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_logistic.py:1183: FutureWarning: `penalty='none'`has been deprecated in 1.2 and will be removed in 1.4. To keep the past behaviour, set `penalty=None`.
#   warnings.warn(
# /Users/daria_otradnova/opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_logistic.py:1183: FutureWarning: `penalty='none'`has been deprecated in 1.2 and will be removed in 1.4. To keep the past behaviour, set `penalty=None`.
#   warnings.warn(
# /Users/daria_otradnova/opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_logistic.py:460: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /Users/daria_otradnova/opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_logistic.py:1183: FutureWarning: `penalty='none'`has been deprecated in 1.2 and will be removed in 1.4. To keep the past behaviour, set `penalty=None`.
#   warnings.warn(
# /Users/daria_otradnova/opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_logistic.py:460: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /Users/daria_otradnova/opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_logistic.py:1183: FutureWarning: `penalty='none'`has been deprecated in 1.2 and will be removed in 1.4. To keep the past behaviour, set `penalty=None`.
#   warnings.warn(
# /Users/daria_otradnova/opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_logistic.py:460: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /Users/daria_otradnova/opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_logistic.py:1183: FutureWarning: `penalty='none'`has been deprecated in 1.2 and will be removed in 1.4. To keep the past behaviour, set `penalty=None`.
#   warnings.warn(
# /Users/daria_otradnova/opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_logistic.py:460: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /Users/daria_otradnova/opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_logistic.py:1183: FutureWarning: `penalty='none'`has been deprecated in 1.2 and will be removed in 1.4. To keep the past behaviour, set `penalty=None`.
#   warnings.warn(
# /Users/daria_otradnova/opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_logistic.py:460: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /Users/daria_otradnova/opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_logistic.py:1183: FutureWarning: `penalty='none'`has been deprecated in 1.2 and will be removed in 1.4. To keep the past behaviour, set `penalty=None`.
#   warnings.warn(
# /Users/daria_otradnova/opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_logistic.py:1183: FutureWarning: `penalty='none'`has been deprecated in 1.2 and will be removed in 1.4. To keep the past behaviour, set `penalty=None`.
#   warnings.warn(
# /Users/daria_otradnova/opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_logistic.py:1183: FutureWarning: `penalty='none'`has been deprecated in 1.2 and will be removed in 1.4. To keep the past behaviour, set `penalty=None`.
#   warnings.warn(
# /Users/daria_otradnova/opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_logistic.py:1183: FutureWarning: `penalty='none'`has been deprecated in 1.2 and will be removed in 1.4. To keep the past behaviour, set `penalty=None`.
#   warnings.warn(
# /Users/daria_otradnova/opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_logistic.py:1183: FutureWarning: `penalty='none'`has been deprecated in 1.2 and will be removed in 1.4. To keep the past behaviour, set `penalty=None`.
#   warnings.warn(
# /Users/daria_otradnova/opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_logistic.py:1183: FutureWarning: `penalty='none'`has been deprecated in 1.2 and will be removed in 1.4. To keep the past behaviour, set `penalty=None`.
#   warnings.warn(
# /Users/daria_otradnova/opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_logistic.py:1183: FutureWarning: `penalty='none'`has been deprecated in 1.2 and will be removed in 1.4. To keep the past behaviour, set `penalty=None`.
#   warnings.warn(
# /Users/daria_otradnova/opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_logistic.py:1183: FutureWarning: `penalty='none'`has been deprecated in 1.2 and will be removed in 1.4. To keep the past behaviour, set `penalty=None`.
#   warnings.warn(
# /Users/daria_otradnova/opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_logistic.py:1183: FutureWarning: `penalty='none'`has been deprecated in 1.2 and will be removed in 1.4. To keep the past behaviour, set `penalty=None`.
#   warnings.warn(
# /Users/daria_otradnova/opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_logistic.py:1183: FutureWarning: `penalty='none'`has been deprecated in 1.2 and will be removed in 1.4. To keep the past behaviour, set `penalty=None`.
#   warnings.warn(
# /Users/daria_otradnova/opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_logistic.py:1183: FutureWarning: `penalty='none'`has been deprecated in 1.2 and will be removed in 1.4. To keep the past behaviour, set `penalty=None`.
#   warnings.warn(
# /Users/daria_otradnova/opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_logistic.py:1183: FutureWarning: `penalty='none'`has been deprecated in 1.2 and will be removed in 1.4. To keep the past behaviour, set `penalty=None`.
#   warnings.warn(
# /Users/daria_otradnova/opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_logistic.py:1183: FutureWarning: `penalty='none'`has been deprecated in 1.2 and will be removed in 1.4. To keep the past behaviour, set `penalty=None`.
#   warnings.warn(
# /Users/daria_otradnova/opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_logistic.py:1183: FutureWarning: `penalty='none'`has been deprecated in 1.2 and will be removed in 1.4. To keep the past behaviour, set `penalty=None`.
#   warnings.warn(
# /Users/daria_otradnova/opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_logistic.py:1183: FutureWarning: `penalty='none'`has been deprecated in 1.2 and will be removed in 1.4. To keep the past behaviour, set `penalty=None`.
#   warnings.warn(
# /Users/daria_otradnova/opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_logistic.py:1183: FutureWarning: `penalty='none'`has been deprecated in 1.2 and will be removed in 1.4. To keep the past behaviour, set `penalty=None`.
#   warnings.warn(
# /Users/daria_otradnova/opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_logistic.py:1183: FutureWarning: `penalty='none'`has been deprecated in 1.2 and will be removed in 1.4. To keep the past behaviour, set `penalty=None`.
#   warnings.warn(
# /Users/daria_otradnova/opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_logistic.py:1183: FutureWarning: `penalty='none'`has been deprecated in 1.2 and will be removed in 1.4. To keep the past behaviour, set `penalty=None`.
#   warnings.warn(
# /Users/daria_otradnova/opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_logistic.py:1183: FutureWarning: `penalty='none'`has been deprecated in 1.2 and will be removed in 1.4. To keep the past behaviour, set `penalty=None`.
#   warnings.warn(
# /Users/daria_otradnova/opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_logistic.py:1183: FutureWarning: `penalty='none'`has been deprecated in 1.2 and will be removed in 1.4. To keep the past behaviour, set `penalty=None`.
#   warnings.warn(
# /Users/daria_otradnova/opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_logistic.py:1183: FutureWarning: `penalty='none'`has been deprecated in 1.2 and will be removed in 1.4. To keep the past behaviour, set `penalty=None`.
#   warnings.warn(
# /Users/daria_otradnova/opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_logistic.py:460: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# GridSearchCV(cv=ShuffleSplit(n_splits=5, random_state=42, test_size=0.3, train_size=0.6),
#              estimator=Pipeline(steps=[('preprocessing', MinMaxScaler()),
#                                        ('clf', LogisticRegression())]),
#              param_grid=[{'clf__penalty': ['l2'],
#                           'clf__solver': ['newton-cg', 'lbfgs', 'liblinear',
#                                           'sag', 'saga'],
#                           'preprocessing': [MinMaxScaler(), StandardScaler(),
#                                             RobustScaler(), Normalizer()]},
#                          {'clf__penalty': ['l1'], 'clf__solver': ['liblinear'],
#                           'preprocessing': [MinMaxScaler(), StandardScaler(),
#                                             RobustScaler(), Normalizer()]},
#                          {'clf__penalty': ['none'],
#                           'clf__solver': ['lbfgs', 'newton-cg'],
#                           'preprocessing': [MinMaxScaler(), StandardScaler(),
#                                             RobustScaler(), Normalizer()]}],
#              return_train_score=True, scoring='precision')

# %%
grid_result = pd.DataFrame(grid.cv_results_).sort_values(["rank_test_score",'std_test_score']).T
grid_result
# Out:
#                                                                     27  \
# mean_fit_time                                                 0.014517
# std_fit_time                                                  0.003822
# mean_score_time                                               0.001287
# std_score_time                                                 0.00001
# param_clf__penalty                                                none
# param_clf__solver                                                lbfgs
# param_preprocessing                                       Normalizer()
# params               {'clf__penalty': 'none', 'clf__solver': 'lbfgs...
# split0_test_score                                             0.714286
# split1_test_score                                             0.697368
# split2_test_score                                             0.676056
# split3_test_score                                             0.662338
# split4_test_score                                             0.772727
# mean_test_score                                               0.704555
# std_test_score                                                 0.03844
# rank_test_score                                                      1
# split0_train_score                                             0.68323
# split1_train_score                                            0.689394
# split2_train_score                                            0.691781
# split3_train_score                                            0.684564
# split4_train_score                                            0.679012
# mean_train_score                                              0.685596
# std_train_score                                               0.004532
#
#                                                                     24  \
# mean_fit_time                                                 0.006065
# std_fit_time                                                  0.000502
# mean_score_time                                               0.001198
# std_score_time                                                0.000019
# param_clf__penalty                                                none
# param_clf__solver                                                lbfgs
# param_preprocessing                                     MinMaxScaler()
# params               {'clf__penalty': 'none', 'clf__solver': 'lbfgs...
# split0_test_score                                             0.666667
# split1_test_score                                             0.695122
# split2_test_score                                             0.702703
# split3_test_score                                             0.678571
# split4_test_score                                             0.753846
# mean_test_score                                               0.699382
# std_test_score                                                0.029996
# rank_test_score                                                      2
# split0_train_score                                            0.689655
# split1_train_score                                            0.650685
# split2_train_score                                            0.666667
# split3_train_score                                            0.673913
# split4_train_score                                            0.639535
# mean_train_score                                              0.664091
# std_train_score                                               0.017546
#
#                                                                     25  \
# mean_fit_time                                                 0.003232
# std_fit_time                                                  0.000602
# mean_score_time                                                0.00119
# std_score_time                                                0.000015
# param_clf__penalty                                                none
# param_clf__solver                                                lbfgs
# param_preprocessing                                   StandardScaler()
# params               {'clf__penalty': 'none', 'clf__solver': 'lbfgs...
# split0_test_score                                             0.666667
# split1_test_score                                             0.695122
# split2_test_score                                             0.702703
# split3_test_score                                             0.678571
# split4_test_score                                             0.753846
# mean_test_score                                               0.699382
# std_test_score                                                0.029996
# rank_test_score                                                      2
# split0_train_score                                            0.689655
# split1_train_score                                            0.650685
# split2_train_score                                            0.666667
# split3_train_score                                            0.673913
# split4_train_score                                            0.639535
# mean_train_score                                              0.664091
# std_train_score                                               0.017546
#
#                                                                     26  \
# mean_fit_time                                                 0.004296
# std_fit_time                                                  0.000134
# mean_score_time                                               0.001206
# std_score_time                                                0.000011
# param_clf__penalty                                                none
# param_clf__solver                                                lbfgs
# param_preprocessing                                     RobustScaler()
# params               {'clf__penalty': 'none', 'clf__solver': 'lbfgs...
# split0_test_score                                             0.666667
# split1_test_score                                             0.695122
# split2_test_score                                             0.702703
# split3_test_score                                             0.678571
# split4_test_score                                             0.753846
# mean_test_score                                               0.699382
# std_test_score                                                0.029996
# rank_test_score                                                      2
# split0_train_score                                            0.689655
# split1_train_score                                            0.650685
# split2_train_score                                            0.666667
# split3_train_score                                            0.673913
# split4_train_score                                            0.639535
# mean_train_score                                              0.664091
# std_train_score                                               0.017546
#
#                                                                     28  \
# mean_fit_time                                                 0.011591
# std_fit_time                                                  0.002346
# mean_score_time                                               0.001332
# std_score_time                                                0.000095
# param_clf__penalty                                                none
# param_clf__solver                                            newton-cg
# param_preprocessing                                     MinMaxScaler()
# params               {'clf__penalty': 'none', 'clf__solver': 'newto...
# split0_test_score                                             0.666667
# split1_test_score                                             0.695122
# split2_test_score                                             0.702703
# split3_test_score                                             0.678571
# split4_test_score                                             0.753846
# mean_test_score                                               0.699382
# std_test_score                                                0.029996
# rank_test_score                                                      2
# split0_train_score                                            0.689655
# split1_train_score                                            0.650685
# split2_train_score                                            0.666667
# split3_train_score                                            0.673913
# split4_train_score                                            0.639535
# mean_train_score                                              0.664091
# std_train_score                                               0.017546
#
#                                                                     29  \
# mean_fit_time                                                 0.007217
# std_fit_time                                                   0.00224
# mean_score_time                                               0.001278
# std_score_time                                                0.000088
# param_clf__penalty                                                none
# param_clf__solver                                            newton-cg
# param_preprocessing                                   StandardScaler()
# params               {'clf__penalty': 'none', 'clf__solver': 'newto...
# split0_test_score                                             0.666667
# split1_test_score                                             0.695122
# split2_test_score                                             0.702703
# split3_test_score                                             0.678571
# split4_test_score                                             0.753846
# mean_test_score                                               0.699382
# std_test_score                                                0.029996
# rank_test_score                                                      2
# split0_train_score                                            0.689655
# split1_train_score                                            0.650685
# split2_train_score                                            0.666667
# split3_train_score                                            0.673913
# split4_train_score                                            0.639535
# mean_train_score                                              0.664091
# std_train_score                                               0.017546
#
#                                                                     30  \
# mean_fit_time                                                 0.008861
# std_fit_time                                                  0.001358
# mean_score_time                                               0.001237
# std_score_time                                                0.000058
# param_clf__penalty                                                none
# param_clf__solver                                            newton-cg
# param_preprocessing                                     RobustScaler()
# params               {'clf__penalty': 'none', 'clf__solver': 'newto...
# split0_test_score                                             0.666667
# split1_test_score                                             0.695122
# split2_test_score                                             0.702703
# split3_test_score                                             0.678571
# split4_test_score                                             0.753846
# mean_test_score                                               0.699382
# std_test_score                                                0.029996
# rank_test_score                                                      2
# split0_train_score                                            0.689655
# split1_train_score                                            0.650685
# split2_train_score                                            0.666667
# split3_train_score                                            0.673913
# split4_train_score                                            0.639535
# mean_train_score                                              0.664091
# std_train_score                                               0.017546
#
#                                                                     2   \
# mean_fit_time                                                 0.011557
# std_fit_time                                                  0.001944
# mean_score_time                                               0.001498
# std_score_time                                                0.000308
# param_clf__penalty                                                  l2
# param_clf__solver                                            newton-cg
# param_preprocessing                                     RobustScaler()
# params               {'clf__penalty': 'l2', 'clf__solver': 'newton-...
# split0_test_score                                             0.657895
# split1_test_score                                             0.698795
# split2_test_score                                             0.684211
# split3_test_score                                             0.686747
# split4_test_score                                             0.746269
# mean_test_score                                               0.694783
# std_test_score                                                0.028996
# rank_test_score                                                      8
# split0_train_score                                            0.680723
# split1_train_score                                            0.646259
# split2_train_score                                            0.654321
# split3_train_score                                            0.672222
# split4_train_score                                            0.639053
# mean_train_score                                              0.658516
# std_train_score                                               0.015669
#
#                                                                     6   \
# mean_fit_time                                                 0.004117
# std_fit_time                                                  0.000166
# mean_score_time                                               0.001202
# std_score_time                                                0.000002
# param_clf__penalty                                                  l2
# param_clf__solver                                                lbfgs
# param_preprocessing                                     RobustScaler()
# params               {'clf__penalty': 'l2', 'clf__solver': 'lbfgs',...
# split0_test_score                                             0.657895
# split1_test_score                                             0.698795
# split2_test_score                                             0.684211
# split3_test_score                                             0.686747
# split4_test_score                                             0.746269
# mean_test_score                                               0.694783
# std_test_score                                                0.028996
# rank_test_score                                                      8
# split0_train_score                                            0.680723
# split1_train_score                                            0.646259
# split2_train_score                                            0.654321
# split3_train_score                                            0.672222
# split4_train_score                                            0.639053
# mean_train_score                                              0.658516
# std_train_score                                               0.015669
#
#                                                                     10  ...  \
# mean_fit_time                                                 0.002671  ...
# std_fit_time                                                  0.000293  ...
# mean_score_time                                               0.001204  ...
# std_score_time                                                0.000027  ...
# param_clf__penalty                                                  l2  ...
# param_clf__solver                                            liblinear  ...
# param_preprocessing                                     RobustScaler()  ...
# params               {'clf__penalty': 'l2', 'clf__solver': 'libline...  ...
# split0_test_score                                             0.657895  ...
# split1_test_score                                             0.698795  ...
# split2_test_score                                             0.684211  ...
# split3_test_score                                             0.686747  ...
# split4_test_score                                             0.746269  ...
# mean_test_score                                               0.694783  ...
# std_test_score                                                0.028996  ...
# rank_test_score                                                      8  ...
# split0_train_score                                            0.676647  ...
# split1_train_score                                            0.651007  ...
# split2_train_score                                            0.658537  ...
# split3_train_score                                            0.672222  ...
# split4_train_score                                            0.639053  ...
# mean_train_score                                              0.659493  ...
# std_train_score                                               0.013762  ...
#
#                                                                     17  \
# mean_fit_time                                                 0.004937
# std_fit_time                                                  0.001591
# mean_score_time                                               0.001098
# std_score_time                                                0.000009
# param_clf__penalty                                                  l2
# param_clf__solver                                                 saga
# param_preprocessing                                   StandardScaler()
# params               {'clf__penalty': 'l2', 'clf__solver': 'saga', ...
# split0_test_score                                             0.653846
# split1_test_score                                             0.698795
# split2_test_score                                             0.684211
# split3_test_score                                             0.678571
# split4_test_score                                             0.738462
# mean_test_score                                               0.690777
# std_test_score                                                0.027907
# rank_test_score                                                     19
# split0_train_score                                            0.674556
# split1_train_score                                            0.650685
# split2_train_score                                            0.654321
# split3_train_score                                            0.675978
# split4_train_score                                            0.641176
# mean_train_score                                              0.659343
# std_train_score                                               0.013699
#
#                                                                     20  \
# mean_fit_time                                                 0.005639
# std_fit_time                                                  0.001935
# mean_score_time                                               0.001093
# std_score_time                                                0.000004
# param_clf__penalty                                                  l1
# param_clf__solver                                            liblinear
# param_preprocessing                                     MinMaxScaler()
# params               {'clf__penalty': 'l1', 'clf__solver': 'libline...
# split0_test_score                                                 0.64
# split1_test_score                                               0.7125
# split2_test_score                                             0.671053
# split3_test_score                                             0.686747
# split4_test_score                                             0.723077
# mean_test_score                                               0.686675
# std_test_score                                                0.029714
# rank_test_score                                                     24
# split0_train_score                                            0.685185
# split1_train_score                                             0.65035
# split2_train_score                                            0.645161
# split3_train_score                                            0.684211
# split4_train_score                                            0.651163
# mean_train_score                                              0.663214
# std_train_score                                               0.017665
#
#                                                                     22  \
# mean_fit_time                                                  0.00294
# std_fit_time                                                  0.000708
# mean_score_time                                               0.001105
# std_score_time                                                0.000003
# param_clf__penalty                                                  l1
# param_clf__solver                                            liblinear
# param_preprocessing                                     RobustScaler()
# params               {'clf__penalty': 'l1', 'clf__solver': 'libline...
# split0_test_score                                             0.649351
# split1_test_score                                             0.696203
# split2_test_score                                             0.679487
# split3_test_score                                             0.655556
# split4_test_score                                             0.746269
# mean_test_score                                               0.685373
# std_test_score                                                0.034776
# rank_test_score                                                     25
# split0_train_score                                            0.682635
# split1_train_score                                            0.641892
# split2_train_score                                            0.654321
# split3_train_score                                            0.672222
# split4_train_score                                            0.633721
# mean_train_score                                              0.656958
# std_train_score                                               0.018255
#
#                                                                     21  \
# mean_fit_time                                                 0.002284
# std_fit_time                                                  0.000694
# mean_score_time                                               0.001096
# std_score_time                                                0.000002
# param_clf__penalty                                                  l1
# param_clf__solver                                            liblinear
# param_preprocessing                                   StandardScaler()
# params               {'clf__penalty': 'l1', 'clf__solver': 'libline...
# split0_test_score                                              0.64557
# split1_test_score                                             0.696203
# split2_test_score                                             0.675325
# split3_test_score                                             0.659091
# split4_test_score                                             0.738462
# mean_test_score                                                0.68293
# std_test_score                                                0.032502
# rank_test_score                                                     26
# split0_train_score                                            0.682353
# split1_train_score                                            0.646259
# split2_train_score                                            0.652174
# split3_train_score                                            0.672131
# split4_train_score                                            0.639535
# mean_train_score                                               0.65849
# std_train_score                                               0.016151
#
#                                                                     3   \
# mean_fit_time                                                 0.005928
# std_fit_time                                                  0.001174
# mean_score_time                                               0.001383
# std_score_time                                                0.000076
# param_clf__penalty                                                  l2
# param_clf__solver                                            newton-cg
# param_preprocessing                                       Normalizer()
# params               {'clf__penalty': 'l2', 'clf__solver': 'newton-...
# split0_test_score                                                  0.5
# split1_test_score                                                  0.0
# split2_test_score                                                  0.0
# split3_test_score                                             0.333333
# split4_test_score                                                  1.0
# mean_test_score                                               0.366667
# std_test_score                                                0.371184
# rank_test_score                                                     27
# split0_train_score                                            0.714286
# split1_train_score                                                 0.0
# split2_train_score                                            0.636364
# split3_train_score                                                 0.5
# split4_train_score                                            0.333333
# mean_train_score                                              0.436797
# std_train_score                                               0.253897
#
#                                                                     7   \
# mean_fit_time                                                 0.004249
# std_fit_time                                                  0.000712
# mean_score_time                                                 0.0013
# std_score_time                                                0.000029
# param_clf__penalty                                                  l2
# param_clf__solver                                                lbfgs
# param_preprocessing                                       Normalizer()
# params               {'clf__penalty': 'l2', 'clf__solver': 'lbfgs',...
# split0_test_score                                                  0.5
# split1_test_score                                                  0.0
# split2_test_score                                                  0.0
# split3_test_score                                             0.333333
# split4_test_score                                                  1.0
# mean_test_score                                               0.366667
# std_test_score                                                0.371184
# rank_test_score                                                     27
# split0_train_score                                            0.714286
# split1_train_score                                                 0.0
# split2_train_score                                            0.636364
# split3_train_score                                                 0.5
# split4_train_score                                            0.333333
# mean_train_score                                              0.436797
# std_train_score                                               0.253897
#
#                                                                     15  \
# mean_fit_time                                                 0.002012
# std_fit_time                                                  0.000039
# mean_score_time                                               0.001187
# std_score_time                                                0.000013
# param_clf__penalty                                                  l2
# param_clf__solver                                                  sag
# param_preprocessing                                       Normalizer()
# params               {'clf__penalty': 'l2', 'clf__solver': 'sag', '...
# split0_test_score                                                  0.5
# split1_test_score                                                  0.0
# split2_test_score                                                  0.0
# split3_test_score                                             0.333333
# split4_test_score                                                  1.0
# mean_test_score                                               0.366667
# std_test_score                                                0.371184
# rank_test_score                                                     27
# split0_train_score                                            0.714286
# split1_train_score                                                 0.0
# split2_train_score                                            0.636364
# split3_train_score                                                 0.5
# split4_train_score                                            0.333333
# mean_train_score                                              0.436797
# std_train_score                                               0.253897
#
#                                                                     19  \
# mean_fit_time                                                 0.001889
# std_fit_time                                                  0.000081
# mean_score_time                                               0.001193
# std_score_time                                                0.000012
# param_clf__penalty                                                  l2
# param_clf__solver                                                 saga
# param_preprocessing                                       Normalizer()
# params               {'clf__penalty': 'l2', 'clf__solver': 'saga', ...
# split0_test_score                                                  0.5
# split1_test_score                                                  0.0
# split2_test_score                                                  0.0
# split3_test_score                                             0.333333
# split4_test_score                                                  1.0
# mean_test_score                                               0.366667
# std_test_score                                                0.371184
# rank_test_score                                                     27
# split0_train_score                                            0.714286
# split1_train_score                                                 0.0
# split2_train_score                                            0.636364
# split3_train_score                                                 0.5
# split4_train_score                                            0.333333
# mean_train_score                                              0.436797
# std_train_score                                               0.253897
#
#                                                                     23  \
# mean_fit_time                                                 0.026317
# std_fit_time                                                  0.016244
# mean_score_time                                               0.001257
# std_score_time                                                0.000092
# param_clf__penalty                                                  l1
# param_clf__solver                                            liblinear
# param_preprocessing                                       Normalizer()
# params               {'clf__penalty': 'l1', 'clf__solver': 'libline...
# split0_test_score                                             0.466667
# split1_test_score                                             0.230769
# split2_test_score                                             0.473684
# split3_test_score                                                 0.25
# split4_test_score                                             0.285714
# mean_test_score                                               0.341367
# std_test_score                                                0.106663
# rank_test_score                                                     31
# split0_train_score                                                 0.5
# split1_train_score                                            0.266667
# split2_train_score                                            0.444444
# split3_train_score                                            0.538462
# split4_train_score                                            0.428571
# mean_train_score                                              0.435629
# std_train_score                                                0.09316
#
#                                                                     11
# mean_fit_time                                                 0.001188
# std_fit_time                                                  0.000025
# mean_score_time                                                0.00128
# std_score_time                                                0.000044
# param_clf__penalty                                                  l2
# param_clf__solver                                            liblinear
# param_preprocessing                                       Normalizer()
# params               {'clf__penalty': 'l2', 'clf__solver': 'libline...
# split0_test_score                                             0.333333
# split1_test_score                                                  0.0
# split2_test_score                                                  0.0
# split3_test_score                                             0.333333
# split4_test_score                                                  1.0
# mean_test_score                                               0.333333
# std_test_score                                                0.365148
# rank_test_score                                                     32
# split0_train_score                                            0.555556
# split1_train_score                                                 0.0
# split2_train_score                                            0.666667
# split3_train_score                                                 0.6
# split4_train_score                                            0.333333
# mean_train_score                                              0.431111
# std_train_score                                               0.242864
#
# [23 rows x 32 columns]

# %% [markdown]
# ### Выводим параметры модели с наилучшими результатами

# %%
print(grid.best_estimator_)
# Out:
# Pipeline(steps=[('preprocessing', Normalizer()),
#                 ('clf', LogisticRegression(penalty='none'))])

# %% [markdown]
# ### Записываем нашу модель с полученными лучшими результатами

# %%
pipe_3 = Pipeline([('preprocessing', MinMaxScaler()),
                ('clf',LogisticRegression(penalty=None, solver='newton-cg'))])
pipe_3.fit(X_train, y_train)
y_pred_3 = pipe_3.predict(X_test)

# %% [markdown]
# ### Построим кривую ROC AUC (чем больше площадь под нашей кривой, тем лучше)

# %%
fig, ax_roc = plt.subplots(1,1, figsize=(10, 5))

RocCurveDisplay.from_estimator(pipe_1, X_test, y_test, ax = ax_roc, name = 'pipe_1');
RocCurveDisplay.from_estimator(pipe_2, X_test, y_test, ax = ax_roc, name = 'pipe_2');
RocCurveDisplay.from_estimator(pipe_3, X_test, y_test, ax = ax_roc, name = 'pipe_3');

# %% [markdown]
# ### Построим матрицы ошибок и сравним все три, полученные разными методами, модели.

# %% [markdown]
# Нам важно, чтобы наименьшее количество вин "плохого" качества определялись, как "хорошие" (т.е. чтобы вина 0 класса не определялись как вина 1 класса), чтобы мы не смогли их "случайно купить", однако сколько "хороших" вин определяются как "плохие" нам не сильно важно.

# %%
matrix_1 = confusion_matrix(y_test,y_pred_1)
matrix_2 = confusion_matrix(y_test,y_pred_2)
matrix_3 = confusion_matrix(y_test,y_pred_3)


fig,ax = plt.subplots(1, 3, sharex=True, sharey=True, figsize=(15,5))
ax = plt.subplot(1, 3, 1)
sns.heatmap(matrix_1,annot=True, fmt='g', cbar=None,cmap="Blues");
ax = plt.subplot(1, 3, 2)
sns.heatmap(matrix_2,annot=True, fmt='g', cbar=None,cmap="Blues");
ax = plt.subplot(1, 3, 3)
sns.heatmap(matrix_3,annot=True, fmt='g', cbar=None,cmap="Blues");

# %% [markdown]
# ### Для наглядного сравнения выведем результаты моделей

# %%
print("Тренировка:", pipe_1.score(X_train, y_train), "Тест:", pipe_1.score(X_test, y_test) )
print("Тренировка:", pipe_2.score(X_train, y_train), "Тест:", pipe_2.score(X_test, y_test) )
print("Тренировка:", pipe_3.score(X_train, y_train), "Тест:", pipe_3.score(X_test, y_test) )
# Out:
# Тренировка: 0.7703016241299304 Тест: 0.7636152954808807
# Тренировка: 0.7122969837587007 Тест: 0.7161066048667439
# Тренировка: 0.7529002320185615 Тест: 0.7740440324449595

# %% [markdown]
# ### Вывод: проанализировав полученные данные мы можем сделать вывод, что наилучшей моделью является модель логистической регрессии, так как:
# ### 1. имеет наибольшую площадь под кривой ROC AUC
# ### 2. делает наименьшее количество ошибок (смотрим на матрицах ошибок)
# ### 3. результат на тестовых значений самый высокий
