# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.datasets import load_boston
from sklearn.preprocessing import MinMaxScaler, PolynomialFeatures
from sklearn.model_selection import train_test_split 

boston=load_boston()
boston.target
# Out:
# array([24. , 21.6, 34.7, 33.4, 36.2, 28.7, 22.9, 27.1, 16.5, 18.9, 15. ,
#        18.9, 21.7, 20.4, 18.2, 19.9, 23.1, 17.5, 20.2, 18.2, 13.6, 19.6,
#        15.2, 14.5, 15.6, 13.9, 16.6, 14.8, 18.4, 21. , 12.7, 14.5, 13.2,
#        13.1, 13.5, 18.9, 20. , 21. , 24.7, 30.8, 34.9, 26.6, 25.3, 24.7,
#        21.2, 19.3, 20. , 16.6, 14.4, 19.4, 19.7, 20.5, 25. , 23.4, 18.9,
#        35.4, 24.7, 31.6, 23.3, 19.6, 18.7, 16. , 22.2, 25. , 33. , 23.5,
#        19.4, 22. , 17.4, 20.9, 24.2, 21.7, 22.8, 23.4, 24.1, 21.4, 20. ,
#        20.8, 21.2, 20.3, 28. , 23.9, 24.8, 22.9, 23.9, 26.6, 22.5, 22.2,
#        23.6, 28.7, 22.6, 22. , 22.9, 25. , 20.6, 28.4, 21.4, 38.7, 43.8,
#        33.2, 27.5, 26.5, 18.6, 19.3, 20.1, 19.5, 19.5, 20.4, 19.8, 19.4,
#        21.7, 22.8, 18.8, 18.7, 18.5, 18.3, 21.2, 19.2, 20.4, 19.3, 22. ,
#        20.3, 20.5, 17.3, 18.8, 21.4, 15.7, 16.2, 18. , 14.3, 19.2, 19.6,
#        23. , 18.4, 15.6, 18.1, 17.4, 17.1, 13.3, 17.8, 14. , 14.4, 13.4,
#        15.6, 11.8, 13.8, 15.6, 14.6, 17.8, 15.4, 21.5, 19.6, 15.3, 19.4,
#        17. , 15.6, 13.1, 41.3, 24.3, 23.3, 27. , 50. , 50. , 50. , 22.7,
#        25. , 50. , 23.8, 23.8, 22.3, 17.4, 19.1, 23.1, 23.6, 22.6, 29.4,
#        23.2, 24.6, 29.9, 37.2, 39.8, 36.2, 37.9, 32.5, 26.4, 29.6, 50. ,
#        32. , 29.8, 34.9, 37. , 30.5, 36.4, 31.1, 29.1, 50. , 33.3, 30.3,
#        34.6, 34.9, 32.9, 24.1, 42.3, 48.5, 50. , 22.6, 24.4, 22.5, 24.4,
#        20. , 21.7, 19.3, 22.4, 28.1, 23.7, 25. , 23.3, 28.7, 21.5, 23. ,
#        26.7, 21.7, 27.5, 30.1, 44.8, 50. , 37.6, 31.6, 46.7, 31.5, 24.3,
#        31.7, 41.7, 48.3, 29. , 24. , 25.1, 31.5, 23.7, 23.3, 22. , 20.1,
#        22.2, 23.7, 17.6, 18.5, 24.3, 20.5, 24.5, 26.2, 24.4, 24.8, 29.6,
#        42.8, 21.9, 20.9, 44. , 50. , 36. , 30.1, 33.8, 43.1, 48.8, 31. ,
#        36.5, 22.8, 30.7, 50. , 43.5, 20.7, 21.1, 25.2, 24.4, 35.2, 32.4,
#        32. , 33.2, 33.1, 29.1, 35.1, 45.4, 35.4, 46. , 50. , 32.2, 22. ,
#        20.1, 23.2, 22.3, 24.8, 28.5, 37.3, 27.9, 23.9, 21.7, 28.6, 27.1,
#        20.3, 22.5, 29. , 24.8, 22. , 26.4, 33.1, 36.1, 28.4, 33.4, 28.2,
#        22.8, 20.3, 16.1, 22.1, 19.4, 21.6, 23.8, 16.2, 17.8, 19.8, 23.1,
#        21. , 23.8, 23.1, 20.4, 18.5, 25. , 24.6, 23. , 22.2, 19.3, 22.6,
#        19.8, 17.1, 19.4, 22.2, 20.7, 21.1, 19.5, 18.5, 20.6, 19. , 18.7,
#        32.7, 16.5, 23.9, 31.2, 17.5, 17.2, 23.1, 24.5, 26.6, 22.9, 24.1,
#        18.6, 30.1, 18.2, 20.6, 17.8, 21.7, 22.7, 22.6, 25. , 19.9, 20.8,
#        16.8, 21.9, 27.5, 21.9, 23.1, 50. , 50. , 50. , 50. , 50. , 13.8,
#        13.8, 15. , 13.9, 13.3, 13.1, 10.2, 10.4, 10.9, 11.3, 12.3,  8.8,
#         7.2, 10.5,  7.4, 10.2, 11.5, 15.1, 23.2,  9.7, 13.8, 12.7, 13.1,
#        12.5,  8.5,  5. ,  6.3,  5.6,  7.2, 12.1,  8.3,  8.5,  5. , 11.9,
#        27.9, 17.2, 27.5, 15. , 17.2, 17.9, 16.3,  7. ,  7.2,  7.5, 10.4,
#         8.8,  8.4, 16.7, 14.2, 20.8, 13.4, 11.7,  8.3, 10.2, 10.9, 11. ,
#         9.5, 14.5, 14.1, 16.1, 14.3, 11.7, 13.4,  9.6,  8.7,  8.4, 12.8,
#        10.5, 17.1, 18.4, 15.4, 10.8, 11.8, 14.9, 12.6, 14.1, 13. , 13.4,
#        15.2, 16.1, 17.8, 14.9, 14.1, 12.7, 13.5, 14.9, 20. , 16.4, 17.7,
#        19.5, 20.2, 21.4, 19.9, 19. , 19.1, 19.1, 20.1, 19.9, 19.6, 23.2,
#        29.8, 13.8, 13.3, 16.7, 12. , 14.6, 21.4, 23. , 23.7, 25. , 21.8,
#        20.6, 21.2, 19.1, 20.6, 15.2,  7. ,  8.1, 13.6, 20.1, 21.8, 24.5,
#        23.1, 19.7, 18.3, 21.2, 17.5, 16.8, 22.4, 20.6, 23.9, 22. , 11.9])

# %% [markdown]
# ### Пример 1. LinearRegression

# %%
from sklearn.linear_model import LinearRegression
X_train, X_test, y_train, y_test = train_test_split(boston.data, boston.target, random_state=0) 

boston_st_non = LinearRegression()
boston_st_non.fit(X_train, y_train)
print("R-квадрат обучение: {:.2f}".format(boston_st_non.score(X_train, y_train))) 
print("R-квадрат тест: {:.2f}".format(boston_st_non.score(X_test, y_test)))
print("-------------------------------")
print("boston_st.coef_: {}".format( boston_st_non.coef_ )) 
print("boston_st.intercept_: {}".format( boston_st_non.intercept_  ))
# Out:
# R-квадрат обучение: 0.77
# R-квадрат тест: 0.64
# -------------------------------
# boston_st.coef_: [-1.17735289e-01  4.40174969e-02 -5.76814314e-03  2.39341594e+00
#  -1.55894211e+01  3.76896770e+00 -7.03517828e-03 -1.43495641e+00
#   2.40081086e-01 -1.12972810e-02 -9.85546732e-01  8.44443453e-03
#  -4.99116797e-01]
# boston_st.intercept_: 36.933255457118975

# %%
# А нужно ли перемасштабирование Scaler? Проверим!

from sklearn.pipeline import make_pipeline


boston_st = make_pipeline( MinMaxScaler(), LinearRegression() )
boston_st.fit(X_train, y_train)

print("R-квадрат обучение: {:.2f}".format(boston_st.score(X_train, y_train))) 
print("R-квадрат тест: {:.2f}".format(boston_st.score(X_test, y_test)))
print("-------------------------------")
# ВНИМАНИЕ! СИЛЬНОЕ ОТЛИЧИЕ из-за Pipline
print("boston_st.coef_: {}".format( boston_st.named_steps['linearregression'].coef_ )) 
print("boston_st.intercept_: {}".format( boston_st.named_steps['linearregression'].intercept_  ))
# Out:
# R-квадрат обучение: 0.77
# R-квадрат тест: 0.64
# -------------------------------
# boston_st.coef_: [-10.47489456   4.40174969  -0.15735494   2.39341594  -7.57645867
#   19.67024242  -0.68311581 -15.71607313   5.52186497  -5.91977522
#   -9.26413928   3.34889385 -17.59386711]
# boston_st.intercept_: 27.49272790795228

# %% [markdown]
# ### О наборе расширенный Бостон

# %%
def load_extended_boston():
    boston = load_boston()
    X = boston.data
    X = MinMaxScaler().fit_transform(boston.data)
    X = PolynomialFeatures(degree=2, include_bias=False).fit_transform(X)
    return X, boston.target

# %%
boston.data.shape
# Out:
# (506, 13)

# %%
X,y = load_extended_boston()
X.shape
# Out:
# (506, 104)

# %%
boston.target
# Out:
# array([24. , 21.6, 34.7, 33.4, 36.2, 28.7, 22.9, 27.1, 16.5, 18.9, 15. ,
#        18.9, 21.7, 20.4, 18.2, 19.9, 23.1, 17.5, 20.2, 18.2, 13.6, 19.6,
#        15.2, 14.5, 15.6, 13.9, 16.6, 14.8, 18.4, 21. , 12.7, 14.5, 13.2,
#        13.1, 13.5, 18.9, 20. , 21. , 24.7, 30.8, 34.9, 26.6, 25.3, 24.7,
#        21.2, 19.3, 20. , 16.6, 14.4, 19.4, 19.7, 20.5, 25. , 23.4, 18.9,
#        35.4, 24.7, 31.6, 23.3, 19.6, 18.7, 16. , 22.2, 25. , 33. , 23.5,
#        19.4, 22. , 17.4, 20.9, 24.2, 21.7, 22.8, 23.4, 24.1, 21.4, 20. ,
#        20.8, 21.2, 20.3, 28. , 23.9, 24.8, 22.9, 23.9, 26.6, 22.5, 22.2,
#        23.6, 28.7, 22.6, 22. , 22.9, 25. , 20.6, 28.4, 21.4, 38.7, 43.8,
#        33.2, 27.5, 26.5, 18.6, 19.3, 20.1, 19.5, 19.5, 20.4, 19.8, 19.4,
#        21.7, 22.8, 18.8, 18.7, 18.5, 18.3, 21.2, 19.2, 20.4, 19.3, 22. ,
#        20.3, 20.5, 17.3, 18.8, 21.4, 15.7, 16.2, 18. , 14.3, 19.2, 19.6,
#        23. , 18.4, 15.6, 18.1, 17.4, 17.1, 13.3, 17.8, 14. , 14.4, 13.4,
#        15.6, 11.8, 13.8, 15.6, 14.6, 17.8, 15.4, 21.5, 19.6, 15.3, 19.4,
#        17. , 15.6, 13.1, 41.3, 24.3, 23.3, 27. , 50. , 50. , 50. , 22.7,
#        25. , 50. , 23.8, 23.8, 22.3, 17.4, 19.1, 23.1, 23.6, 22.6, 29.4,
#        23.2, 24.6, 29.9, 37.2, 39.8, 36.2, 37.9, 32.5, 26.4, 29.6, 50. ,
#        32. , 29.8, 34.9, 37. , 30.5, 36.4, 31.1, 29.1, 50. , 33.3, 30.3,
#        34.6, 34.9, 32.9, 24.1, 42.3, 48.5, 50. , 22.6, 24.4, 22.5, 24.4,
#        20. , 21.7, 19.3, 22.4, 28.1, 23.7, 25. , 23.3, 28.7, 21.5, 23. ,
#        26.7, 21.7, 27.5, 30.1, 44.8, 50. , 37.6, 31.6, 46.7, 31.5, 24.3,
#        31.7, 41.7, 48.3, 29. , 24. , 25.1, 31.5, 23.7, 23.3, 22. , 20.1,
#        22.2, 23.7, 17.6, 18.5, 24.3, 20.5, 24.5, 26.2, 24.4, 24.8, 29.6,
#        42.8, 21.9, 20.9, 44. , 50. , 36. , 30.1, 33.8, 43.1, 48.8, 31. ,
#        36.5, 22.8, 30.7, 50. , 43.5, 20.7, 21.1, 25.2, 24.4, 35.2, 32.4,
#        32. , 33.2, 33.1, 29.1, 35.1, 45.4, 35.4, 46. , 50. , 32.2, 22. ,
#        20.1, 23.2, 22.3, 24.8, 28.5, 37.3, 27.9, 23.9, 21.7, 28.6, 27.1,
#        20.3, 22.5, 29. , 24.8, 22. , 26.4, 33.1, 36.1, 28.4, 33.4, 28.2,
#        22.8, 20.3, 16.1, 22.1, 19.4, 21.6, 23.8, 16.2, 17.8, 19.8, 23.1,
#        21. , 23.8, 23.1, 20.4, 18.5, 25. , 24.6, 23. , 22.2, 19.3, 22.6,
#        19.8, 17.1, 19.4, 22.2, 20.7, 21.1, 19.5, 18.5, 20.6, 19. , 18.7,
#        32.7, 16.5, 23.9, 31.2, 17.5, 17.2, 23.1, 24.5, 26.6, 22.9, 24.1,
#        18.6, 30.1, 18.2, 20.6, 17.8, 21.7, 22.7, 22.6, 25. , 19.9, 20.8,
#        16.8, 21.9, 27.5, 21.9, 23.1, 50. , 50. , 50. , 50. , 50. , 13.8,
#        13.8, 15. , 13.9, 13.3, 13.1, 10.2, 10.4, 10.9, 11.3, 12.3,  8.8,
#         7.2, 10.5,  7.4, 10.2, 11.5, 15.1, 23.2,  9.7, 13.8, 12.7, 13.1,
#        12.5,  8.5,  5. ,  6.3,  5.6,  7.2, 12.1,  8.3,  8.5,  5. , 11.9,
#        27.9, 17.2, 27.5, 15. , 17.2, 17.9, 16.3,  7. ,  7.2,  7.5, 10.4,
#         8.8,  8.4, 16.7, 14.2, 20.8, 13.4, 11.7,  8.3, 10.2, 10.9, 11. ,
#         9.5, 14.5, 14.1, 16.1, 14.3, 11.7, 13.4,  9.6,  8.7,  8.4, 12.8,
#        10.5, 17.1, 18.4, 15.4, 10.8, 11.8, 14.9, 12.6, 14.1, 13. , 13.4,
#        15.2, 16.1, 17.8, 14.9, 14.1, 12.7, 13.5, 14.9, 20. , 16.4, 17.7,
#        19.5, 20.2, 21.4, 19.9, 19. , 19.1, 19.1, 20.1, 19.9, 19.6, 23.2,
#        29.8, 13.8, 13.3, 16.7, 12. , 14.6, 21.4, 23. , 23.7, 25. , 21.8,
#        20.6, 21.2, 19.1, 20.6, 15.2,  7. ,  8.1, 13.6, 20.1, 21.8, 24.5,
#        23.1, 19.7, 18.3, 21.2, 17.5, 16.8, 22.4, 20.6, 23.9, 22. , 11.9])

# %% [markdown]
# ### Пример 2. Ridge

# %%
boston_ex = make_pipeline(MinMaxScaler(),
                          PolynomialFeatures(degree=2, include_bias=False), 
                          LinearRegression() 
                         )
boston_ex.fit(X_train, y_train)
print("R-квадрат обучение: {:.2f}".format(boston_ex.score(X_train, y_train))) 
print("R-квадрат тест: {:.2f}".format(boston_ex.score(X_test, y_test)))
# Out:
# R-квадрат обучение: 0.95
# R-квадрат тест: 0.61

# %%
from sklearn.linear_model import Ridge
boston_ridge = make_pipeline(MinMaxScaler(),
                          PolynomialFeatures(degree=2, include_bias=False), 
                          Ridge() 
                         )
boston_ridge.fit(X_train, y_train)
print("R-квадрат обучение: {:.2f}".format(boston_ridge.score(X_train, y_train))) 
print("R-квадрат тест: {:.2f}".format(boston_ridge.score(X_test, y_test)))
# Out:
# R-квадрат обучение: 0.89
# R-квадрат тест: 0.75

# %%
# уберите Scaler, что получится?
# причина штафы за евклидово расстояние
# совпадение случайно с LR
boston_ridge_non = make_pipeline(
                             PolynomialFeatures(degree=2, include_bias=False), 
                             Ridge() 
                            )
boston_ridge_non.fit(X_train, y_train)
print("R-квадрат обучение: {:.2f}".format(boston_ridge_non.score(X_train, y_train))) 
print("R-квадрат тест: {:.2f}".format(boston_ridge_non.score(X_test, y_test)))
# Out:
# R-квадрат обучение: 0.95
# R-квадрат тест: 0.61

# %%
from sklearn.model_selection import cross_val_score, GridSearchCV, KFold 

kfold = KFold(n_splits=10, shuffle=True, random_state=0)
param_grid =[
    {'ridge__alpha':[0.04,0.05,0.06,0.07,0.08,0.09]}
     ]
grid = GridSearchCV(boston_ridge, param_grid, cv=kfold, return_train_score=True, iid=True)
grid.fit(X_train,y_train)
print("R^2 наилучшей модели кроссвалидации на валидационных тестовых наборах: {:.6f}\n".format(grid.best_score_)) 
print("R^2 для наилучшей модели на тестовом наборе: {:.6f}\n".format(grid.score(X_test, y_test)))
print("Наилучшие параметры:\n{}\n".format(grid.best_params_))
# Out:
# R^2 наилучшей модели кроссвалидации на валидационных тестовых наборах: 0.870852
#
# R^2 для наилучшей модели на тестовом наборе: 0.767736
#
# Наилучшие параметры:
# {'ridge__alpha': 0.07}

# %%
grid.best_estimator_
# Out:
# Pipeline(memory=None,
#          steps=[('minmaxscaler', MinMaxScaler(copy=True, feature_range=(0, 1))),
#                 ('polynomialfeatures',
#                  PolynomialFeatures(degree=2, include_bias=False,
#                                     interaction_only=False, order='C')),
#                 ('ridge',
#                  Ridge(alpha=0.07, copy_X=True, fit_intercept=True,
#                        max_iter=None, normalize=False, random_state=None,
#                        solver='auto', tol=0.001))],
#          verbose=False)

# %%
from sklearn.model_selection import ShuffleSplit
from sklearn.model_selection import validation_curve

pipe = grid.best_estimator_

n_range = np.logspace(-6, 1, num=8, endpoint=True, base=10.0)
train_scores, test_scores = validation_curve(
    pipe, X_train, y_train,
    param_name ="ridge__alpha", 
    param_range = n_range,
    cv=KFold(n_splits=10, shuffle=True, random_state=0), 
    n_jobs=-1)

train_scores_mean = np.mean(train_scores, axis=1)
train_scores_std = np.std(train_scores, axis=1)
test_scores_mean = np.mean(test_scores, axis=1)
test_scores_std = np.std(test_scores, axis=1)


plt.title("Validation Curve")
plt.xlabel("$alpha$")
plt.ylabel("Score")
plt.ylim(0, 1.05)

plt.semilogx(n_range, train_scores_mean, label="Training score", color="darkorange")
plt.fill_between(n_range, train_scores_mean - train_scores_std,
                 train_scores_mean + train_scores_std, alpha=0.2,
                 color="darkorange")
plt.semilogx(n_range, test_scores_mean, label="Cross-validation score",
             color="navy")
plt.fill_between(n_range, test_scores_mean - test_scores_std,
                 test_scores_mean + test_scores_std, alpha=0.2,
                 color="navy")
plt.legend(loc="best")
plt.show()

# %%
from sklearn.model_selection import validation_curve
from sklearn.model_selection import ShuffleSplit

pipe = grid.best_estimator_

n_range = np.logspace(-6, 1, num=8, endpoint=True, base=10.0)
train_scores, test_scores = validation_curve(
    pipe, X_train, y_train,
    param_name ="ridge__alpha", 
    param_range = n_range,
    cv=ShuffleSplit(n_splits=10,  test_size=0.3, train_size=0.7, random_state=0), 
    n_jobs=-1)

train_scores_mean = np.mean(train_scores, axis=1)
train_scores_std = np.std(train_scores, axis=1)
test_scores_mean = np.mean(test_scores, axis=1)
test_scores_std = np.std(test_scores, axis=1)


plt.title("Validation Curve")
plt.xlabel("$alpha$")
plt.ylabel("Score")
plt.ylim(0, 1.05)

plt.semilogx(n_range, train_scores_mean, label="Training score", color="darkorange")
plt.fill_between(n_range, train_scores_mean - train_scores_std,
                 train_scores_mean + train_scores_std, alpha=0.2,
                 color="darkorange")
plt.semilogx(n_range, test_scores_mean, label="Cross-validation score",
             color="navy")
plt.fill_between(n_range, test_scores_mean - test_scores_std,
                 test_scores_mean + test_scores_std, alpha=0.2,
                 color="navy")
plt.legend(loc="best")
plt.show()

# %%
from sklearn.model_selection import learning_curve
from sklearn.model_selection import ShuffleSplit

# код исходный тут https://scikit-learn.org/stable/auto_examples/model_selection/plot_learning_curve.html#sphx-glr-auto-examples-model-selection-plot-learning-curve-py
def plot_learning_curve(estimator, title, X, y, ylim=None, cv=None,
                        n_jobs=None, train_sizes=np.linspace(.1, 1.0, 10)):
    plt.figure()
    plt.title(title)
    if ylim is not None:
        plt.ylim(*ylim)
    plt.xlabel("Training examples")
    plt.ylabel("Score")
    train_sizes, train_scores, test_scores = learning_curve(
        estimator, X, y, cv=cv, n_jobs=n_jobs, train_sizes=train_sizes)
    train_scores_mean = np.mean(train_scores, axis=1)
    train_scores_std = np.std(train_scores, axis=1)
    test_scores_mean = np.mean(test_scores, axis=1)
    test_scores_std = np.std(test_scores, axis=1)
    plt.grid()

    plt.fill_between(train_sizes, train_scores_mean - train_scores_std,
                     train_scores_mean + train_scores_std, alpha=0.1,
                     color="r")
    plt.fill_between(train_sizes, test_scores_mean - test_scores_std,
                     test_scores_mean + test_scores_std, alpha=0.1, color="g")
    plt.plot(train_sizes, train_scores_mean, 'o-', color="r",
             label="Training score")
    plt.plot(train_sizes, test_scores_mean, 'o-', color="g",
             label="Cross-validation score")

    plt.legend(loc="best")
    return plt

X, y = boston.data, boston.target


cv = ShuffleSplit(n_splits=10, test_size=0.2, random_state=0)

title = "LR"
boston_ex = make_pipeline(MinMaxScaler(),
                          PolynomialFeatures(degree=2, include_bias=False), 
                          LinearRegression() 
                         )
boston_ex.fit(X, y)
estimator = boston_ex
plot_learning_curve(estimator, title, X, y, ylim=(0.6, 1.01), cv=cv, n_jobs=-1)


title = "Ridge"
boston_ridge = make_pipeline(MinMaxScaler(),
                          PolynomialFeatures(degree=2, include_bias=False), 
                          Ridge() 
                         )
boston_ridge.fit(X, y)

estimator = boston_ridge
plot_learning_curve(estimator, title, X, y, ylim=(0.6, 1.01), cv=cv, n_jobs=-1)

plt.show()

# %% [markdown]
# ### Пример 3. Lasso

# %%
from sklearn.linear_model import Lasso

X_train, X_test, y_train, y_test = train_test_split(boston.data, boston.target, random_state=42) 
boston_lasso=make_pipeline(MinMaxScaler(),
                          PolynomialFeatures(degree=2, include_bias=False), 
                          Lasso() 
                         )
boston_lasso = boston_lasso.fit(X_train, y_train)

print("R-квадрат на обучающем наборе: {:.2f}".format(boston_lasso.score(X_train, y_train))) 
print("R-квадрат на контрольном наборе: {:.2f}".format(boston_lasso.score(X_test, y_test))) 
print("Количество использованных признаков: {}".format(np.sum(boston_lasso.named_steps['lasso'].coef_ != 0)))
# Out:
# R-квадрат на обучающем наборе: 0.28
# R-квадрат на контрольном наборе: 0.27
# Количество использованных признаков: 4

# %%
boston_lasso=make_pipeline(MinMaxScaler(),
                          PolynomialFeatures(degree=2, include_bias=False), 
                          Lasso(alpha=0.0001, tol = 0.1, max_iter=100000) 
                         )
boston_lasso = boston_lasso.fit(X_train, y_train)

print("R-квадрат на обучающем наборе: {:.2f}".format(boston_lasso.score(X_train, y_train))) 
print("R-квадрат на тестовом наборе: {:.2f}".format(boston_lasso.score(X_test, y_test))) 
print("Количество использованных признаков: {}".format(np.sum(boston_lasso.named_steps['lasso'].coef_ != 0)))
# Out:
# R-квадрат на обучающем наборе: 0.87
# R-квадрат на тестовом наборе: 0.81
# Количество использованных признаков: 102

# %%
boston_lasso=make_pipeline(MinMaxScaler(),
                          PolynomialFeatures(degree=2, include_bias=False), 
                          Lasso(alpha=0.001, max_iter=100000) 
                         )
boston_lasso = boston_lasso.fit(X_train, y_train)

print("R-квадрат на обучающем наборе: {:.2f}".format(boston_lasso.score(X_train, y_train))) 
print("R-квадрат на тестовом наборе: {:.2f}".format(boston_lasso.score(X_test, y_test))) 
print("Количество использованных признаков: {}".format(np.sum(boston_lasso.named_steps['lasso'].coef_ != 0)))
# Out:
# R-квадрат на обучающем наборе: 0.93
# R-квадрат на тестовом наборе: 0.82
# Количество использованных признаков: 71

# %%
boston_lasso=make_pipeline(MinMaxScaler(),
                          PolynomialFeatures(degree=2, include_bias=False), 
                          Lasso(alpha=0.01) 
                         )
boston_lasso = boston_lasso.fit(X_train, y_train)

print("R-квадрат на обучающем наборе: {:.2f}".format(boston_lasso.score(X_train, y_train))) 
print("R-квадрат на тестовом наборе: {:.2f}".format(boston_lasso.score(X_test, y_test))) 
print("Количество использованных признаков: {}".format(np.sum(boston_lasso.named_steps['lasso'].coef_ != 0)))
# Out:
# R-квадрат на обучающем наборе: 0.89
# R-квадрат на тестовом наборе: 0.80
# Количество использованных признаков: 36
# /Users/macbook2019/opt/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:475: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 5.97446610983161, tolerance: 3.361037625329815
#   positive)

# %%
boston_lasso
# Out:
# Pipeline(memory=None,
#          steps=[('minmaxscaler', MinMaxScaler(copy=True, feature_range=(0, 1))),
#                 ('polynomialfeatures',
#                  PolynomialFeatures(degree=2, include_bias=False,
#                                     interaction_only=False, order='C')),
#                 ('lasso',
#                  Lasso(alpha=0.01, copy_X=True, fit_intercept=True,
#                        max_iter=1000, normalize=False, positive=False,
#                        precompute=False, random_state=None, selection='cyclic',
#                        tol=0.0001, warm_start=False))],
#          verbose=False)

# %%
from sklearn.model_selection import validation_curve
from sklearn.model_selection import ShuffleSplit

pipe = boston_lasso

n_range = np.logspace(-6, 0, num=7, endpoint=True, base=10.0)
train_scores, test_scores = validation_curve(
    pipe, X_train, y_train,
    param_name ="lasso__alpha", 
    param_range = n_range,
    cv=ShuffleSplit(n_splits=10,  test_size=0.3, train_size=0.7, random_state=42), 
    n_jobs=-1)

train_scores_mean = np.mean(train_scores, axis=1)
train_scores_std = np.std(train_scores, axis=1)
test_scores_mean = np.mean(test_scores, axis=1)
test_scores_std = np.std(test_scores, axis=1)


plt.title("Validation Curve")
plt.xlabel("$alpha$")
plt.ylabel("Score")
plt.ylim(0, 1.05)

plt.semilogx(n_range, train_scores_mean, label="Training score", color="darkorange")
plt.fill_between(n_range, train_scores_mean - train_scores_std,
                 train_scores_mean + train_scores_std, alpha=0.2,
                 color="darkorange")
plt.semilogx(n_range, test_scores_mean, label="Cross-validation score",
             color="navy")
plt.fill_between(n_range, test_scores_mean - test_scores_std,
                 test_scores_mean + test_scores_std, alpha=0.2,
                 color="navy")
plt.legend(loc="best")
plt.show()

# %% [markdown]
# ### Пример 4. ElasticNet

# %%
from sklearn.linear_model import ElasticNet
from sklearn.pipeline import Pipeline

X_train, X_test, y_train, y_test = train_test_split(boston.data, boston.target, random_state=42) 
boston_net=make_pipeline(MinMaxScaler(),
                          PolynomialFeatures(degree=2, include_bias=False), 
                          ElasticNet() 
                         )
pipe = Pipeline([('preprocessing', MinMaxScaler()),
                 ('features', PolynomialFeatures(degree=2, include_bias=False)),
                 ('regresion', ElasticNet(tol=0.1))])

cv=ShuffleSplit(n_splits=10,  test_size=0.3, train_size=0.7, random_state=42)
param_grid =[
    {'regresion__l1_ratio': [.1, .5, .7, .9, .95, 0.99, 1],
     'regresion__alpha': [10**(-6),10**(-5),10**(-4),10**(-3),10**(-2)]
     }
]

grid = GridSearchCV(pipe, param_grid, cv=cv, return_train_score=True, iid=True)
grid.fit(X_train,y_train)

print("Словарь с параметрами для лучшего решения:\n{}\n".format(grid.best_params_))
print("Осредненный R-квадрат для наилучшей модели кроссвалидации на проверочных тренировочных наборах: {:.6f}\n".format(grid.best_score_))
print("R-квадрат на тестовом наборе: {:.2f}".format(grid.score(X_test, y_test)))
gridresults = pd.DataFrame(grid.cv_results_)
display(gridresults.sort_values(["rank_test_score"]).T)
# Out:
# Словарь с параметрами для лучшего решения:
# {'regresion__alpha': 1e-05, 'regresion__l1_ratio': 0.99}
#
# Осредненный R-квадрат для наилучшей модели кроссвалидации на проверочных тренировочных наборах: 0.804041
#
# R-квадрат на тестовом наборе: 0.80
#                                                                           12  \
# mean_fit_time                                                     0.00177014
# std_fit_time                                                     5.19654e-05
# mean_score_time                                                   0.00121918
# std_score_time                                                    9.1797e-06
# param_regresion__alpha                                                 1e-05
# param_regresion__l1_ratio                                               0.99
# params                     {'regresion__alpha': 1e-05, 'regresion__l1_rat...
# split0_test_score                                                   0.751531
# split1_test_score                                                   0.827344
# split2_test_score                                                   0.768541
# split3_test_score                                                    0.81594
# split4_test_score                                                   0.839392
# split5_test_score                                                   0.756636
# split6_test_score                                                   0.809918
# split7_test_score                                                    0.84574
# split8_test_score                                                   0.734579
# split9_test_score                                                    0.89079
# mean_test_score                                                     0.804041
# std_test_score                                                      0.047247
# rank_test_score                                                            1
# split0_train_score                                                  0.912943
# split1_train_score                                                  0.900828
# split2_train_score                                                  0.844354
# split3_train_score                                                  0.887827
# split4_train_score                                                  0.882856
# split5_train_score                                                  0.892271
# split6_train_score                                                  0.893618
# split7_train_score                                                  0.873724
# split8_train_score                                                  0.909858
# split9_train_score                                                   0.88816
# mean_train_score                                                    0.888644
# std_train_score                                                    0.0185621
#
#                                                                           27  \
# mean_fit_time                                                     0.00172389
# std_fit_time                                                     1.91176e-05
# mean_score_time                                                   0.00119934
# std_score_time                                                   6.58761e-06
# param_regresion__alpha                                                 0.001
# param_regresion__l1_ratio                                                  1
# params                     {'regresion__alpha': 0.001, 'regresion__l1_rat...
# split0_test_score                                                   0.749378
# split1_test_score                                                   0.792994
# split2_test_score                                                   0.809977
# split3_test_score                                                   0.802125
# split4_test_score                                                   0.837564
# split5_test_score                                                   0.776033
# split6_test_score                                                   0.816649
# split7_test_score                                                   0.847328
# split8_test_score                                                   0.728645
# split9_test_score                                                   0.875872
# mean_test_score                                                     0.803656
# std_test_score                                                     0.0423469
# rank_test_score                                                            2
# split0_train_score                                                  0.893709
# split1_train_score                                                  0.885953
# split2_train_score                                                  0.887681
# split3_train_score                                                  0.881904
# split4_train_score                                                  0.881745
# split5_train_score                                                  0.889156
# split6_train_score                                                  0.892181
# split7_train_score                                                  0.872058
# split8_train_score                                                  0.856402
# split9_train_score                                                  0.861975
# mean_train_score                                                    0.880276
# std_train_score                                                     0.012105
#
#                                                                           10  \
# mean_fit_time                                                     0.00175099
# std_fit_time                                                     2.28777e-05
# mean_score_time                                                   0.00122149
# std_score_time                                                   9.00708e-06
# param_regresion__alpha                                                 1e-05
# param_regresion__l1_ratio                                                0.9
# params                     {'regresion__alpha': 1e-05, 'regresion__l1_rat...
# split0_test_score                                                   0.746242
# split1_test_score                                                   0.798474
# split2_test_score                                                   0.806605
# split3_test_score                                                   0.815428
# split4_test_score                                                   0.839225
# split5_test_score                                                   0.758489
# split6_test_score                                                   0.811174
# split7_test_score                                                   0.845789
# split8_test_score                                                   0.730318
# split9_test_score                                                   0.875444
# mean_test_score                                                     0.802719
# std_test_score                                                     0.0437386
# rank_test_score                                                            3
# split0_train_score                                                  0.895396
# split1_train_score                                                  0.887303
# split2_train_score                                                  0.889489
# split3_train_score                                                  0.887778
# split4_train_score                                                  0.882744
# split5_train_score                                                  0.891789
# split6_train_score                                                  0.893415
# split7_train_score                                                  0.873686
# split8_train_score                                                   0.88348
# split9_train_score                                                  0.863812
# mean_train_score                                                    0.884889
# std_train_score                                                     0.009178
#
#                                                                           19  \
# mean_fit_time                                                     0.00174117
# std_fit_time                                                     1.28856e-05
# mean_score_time                                                   0.00121744
# std_score_time                                                   2.25771e-05
# param_regresion__alpha                                                0.0001
# param_regresion__l1_ratio                                               0.99
# params                     {'regresion__alpha': 0.0001, 'regresion__l1_ra...
# split0_test_score                                                   0.746618
# split1_test_score                                                   0.798086
# split2_test_score                                                   0.806997
# split3_test_score                                                    0.81466
# split4_test_score                                                   0.839123
# split5_test_score                                                   0.759714
# split6_test_score                                                   0.811871
# split7_test_score                                                   0.845976
# split8_test_score                                                   0.728256
# split9_test_score                                                   0.875626
# mean_test_score                                                     0.802693
# std_test_score                                                      0.043954
# rank_test_score                                                            4
# split0_train_score                                                   0.89531
# split1_train_score                                                  0.887248
# split2_train_score                                                  0.889372
# split3_train_score                                                   0.88767
# split4_train_score                                                  0.882697
# split5_train_score                                                  0.891547
# split6_train_score                                                  0.893342
# split7_train_score                                                  0.873603
# split8_train_score                                                  0.873151
# split9_train_score                                                  0.863687
# mean_train_score                                                    0.883763
# std_train_score                                                   0.00982124
#
#                                                                           0   \
# mean_fit_time                                                     0.00202398
# std_fit_time                                                     0.000214703
# mean_score_time                                                   0.00132222
# std_score_time                                                   0.000134275
# param_regresion__alpha                                                 1e-06
# param_regresion__l1_ratio                                                0.1
# params                     {'regresion__alpha': 1e-06, 'regresion__l1_rat...
# split0_test_score                                                   0.746183
# split1_test_score                                                   0.798547
# split2_test_score                                                   0.806489
# split3_test_score                                                   0.815566
# split4_test_score                                                   0.839271
# split5_test_score                                                   0.758183
# split6_test_score                                                   0.810976
# split7_test_score                                                    0.84576
# split8_test_score                                                    0.73024
# split9_test_score                                                   0.875413
# mean_test_score                                                     0.802663
# std_test_score                                                     0.0437844
# rank_test_score                                                            5
# split0_train_score                                                  0.895416
# split1_train_score                                                  0.887313
# split2_train_score                                                  0.889521
# split3_train_score                                                  0.887793
# split4_train_score                                                   0.88276
# split5_train_score                                                  0.891854
# split6_train_score                                                  0.893447
# split7_train_score                                                  0.873701
# split8_train_score                                                   0.88347
# split9_train_score                                                  0.863843
# mean_train_score                                                    0.884912
# std_train_score                                                    0.0091813
#
#                                                                           3   \
# mean_fit_time                                                     0.00185044
# std_fit_time                                                     0.000144187
# mean_score_time                                                   0.00130708
# std_score_time                                                   0.000149982
# param_regresion__alpha                                                 1e-06
# param_regresion__l1_ratio                                                0.9
# params                     {'regresion__alpha': 1e-06, 'regresion__l1_rat...
# split0_test_score                                                   0.754969
# split1_test_score                                                   0.834989
# split2_test_score                                                   0.768404
# split3_test_score                                                    0.81612
# split4_test_score                                                   0.839599
# split5_test_score                                                   0.756333
# split6_test_score                                                    0.80994
# split7_test_score                                                   0.839781
# split8_test_score                                                   0.736849
# split9_test_score                                                    0.86956
# mean_test_score                                                     0.802654
# std_test_score                                                     0.0429216
# rank_test_score                                                            6
# split0_train_score                                                  0.917236
# split1_train_score                                                   0.90464
# split2_train_score                                                   0.84438
# split3_train_score                                                  0.887845
# split4_train_score                                                  0.882852
# split5_train_score                                                  0.892339
# split6_train_score                                                  0.893625
# split7_train_score                                                  0.864746
# split8_train_score                                                  0.912471
# split9_train_score                                                  0.857625
# mean_train_score                                                    0.885776
# std_train_score                                                    0.0226365
#
#                                                                           9   \
# mean_fit_time                                                     0.00179691
# std_fit_time                                                     0.000138491
# mean_score_time                                                   0.00126114
# std_score_time                                                   0.000107022
# param_regresion__alpha                                                 1e-05
# param_regresion__l1_ratio                                                0.7
# params                     {'regresion__alpha': 1e-05, 'regresion__l1_rat...
# split0_test_score                                                   0.746976
# split1_test_score                                                   0.797861
# split2_test_score                                                   0.808101
# split3_test_score                                                   0.814517
# split4_test_score                                                   0.838891
# split5_test_score                                                   0.761428
# split6_test_score                                                   0.808521
# split7_test_score                                                   0.846084
# split8_test_score                                                    0.72838
# split9_test_score                                                   0.875429
# mean_test_score                                                     0.802619
# std_test_score                                                     0.0436343
# rank_test_score                                                            7
# split0_train_score                                                  0.895102
# split1_train_score                                                  0.887185
# split2_train_score                                                  0.889118
# split3_train_score                                                  0.887683
# split4_train_score                                                  0.882488
# split5_train_score                                                  0.891072
# split6_train_score                                                  0.887612
# split7_train_score                                                  0.873512
# split8_train_score                                                  0.873196
# split9_train_score                                                   0.86347
# mean_train_score                                                    0.883044
# std_train_score                                                   0.00936778
#
#                                                                           11  \
# mean_fit_time                                                     0.00175064
# std_fit_time                                                     3.13826e-05
# mean_score_time                                                   0.00121231
# std_score_time                                                    1.4736e-05
# param_regresion__alpha                                                 1e-05
# param_regresion__l1_ratio                                               0.95
# params                     {'regresion__alpha': 1e-05, 'regresion__l1_rat...
# split0_test_score                                                   0.746059
# split1_test_score                                                   0.798638
# split2_test_score                                                   0.806226
# split3_test_score                                                   0.815679
# split4_test_score                                                   0.839299
# split5_test_score                                                   0.757644
# split6_test_score                                                   0.810486
# split7_test_score                                                   0.845714
# split8_test_score                                                   0.730144
# split9_test_score                                                   0.875419
# mean_test_score                                                     0.802531
# std_test_score                                                     0.0438611
# rank_test_score                                                            8
# split0_train_score                                                  0.895467
# split1_train_score                                                  0.887325
# split2_train_score                                                  0.889595
# split3_train_score                                                  0.887802
# split4_train_score                                                  0.882809
# split5_train_score                                                  0.891989
# split6_train_score                                                  0.893541
# split7_train_score                                                  0.873725
# split8_train_score                                                  0.883449
# split9_train_score                                                  0.863901
# mean_train_score                                                     0.88496
# std_train_score                                                   0.00919346
#
#                                                                           1   \
# mean_fit_time                                                     0.00181792
# std_fit_time                                                     0.000129139
# mean_score_time                                                   0.00131466
# std_score_time                                                   0.000147018
# param_regresion__alpha                                                 1e-06
# param_regresion__l1_ratio                                                0.5
# params                     {'regresion__alpha': 1e-06, 'regresion__l1_rat...
# split0_test_score                                                   0.746051
# split1_test_score                                                   0.798684
# split2_test_score                                                   0.806188
# split3_test_score                                                    0.81578
# split4_test_score                                                   0.839349
# split5_test_score                                                   0.757484
# split6_test_score                                                    0.81043
# split7_test_score                                                   0.845706
# split8_test_score                                                     0.7301
# split9_test_score                                                   0.875381
# mean_test_score                                                     0.802515
# std_test_score                                                     0.0438843
# rank_test_score                                                            9
# split0_train_score                                                   0.89547
# split1_train_score                                                  0.887331
# split2_train_score                                                   0.88961
# split3_train_score                                                  0.887814
# split4_train_score                                                  0.882811
# split5_train_score                                                   0.89202
# split6_train_score                                                  0.893547
# split7_train_score                                                  0.873731
# split8_train_score                                                  0.883445
# split9_train_score                                                  0.863917
# mean_train_score                                                     0.88497
# std_train_score                                                   0.00919382
#
#                                                                           14  \
# mean_fit_time                                                     0.00173514
# std_fit_time                                                     7.47285e-06
# mean_score_time                                                   0.00121896
# std_score_time                                                   6.97394e-06
# param_regresion__alpha                                                0.0001
# param_regresion__l1_ratio                                                0.1
# params                     {'regresion__alpha': 0.0001, 'regresion__l1_ra...
# split0_test_score                                                    0.75612
# split1_test_score                                                   0.786644
# split2_test_score                                                    0.81698
# split3_test_score                                                   0.790059
# split4_test_score                                                   0.830368
# split5_test_score                                                   0.783048
# split6_test_score                                                   0.823983
# split7_test_score                                                   0.852547
# split8_test_score                                                   0.711872
# split9_test_score                                                   0.872638
# mean_test_score                                                     0.802426
# std_test_score                                                     0.0447446
# rank_test_score                                                           10
# split0_train_score                                                  0.894234
# split1_train_score                                                  0.884943
# split2_train_score                                                  0.874734
# split3_train_score                                                  0.875252
# split4_train_score                                                  0.878493
# split5_train_score                                                  0.873369
# split6_train_score                                                  0.878234
# split7_train_score                                                  0.874433
# split8_train_score                                                  0.895202
# split9_train_score                                                  0.856343
# mean_train_score                                                    0.878524
# std_train_score                                                    0.0106143
#
#                            ...  \
# mean_fit_time              ...
# std_fit_time               ...
# mean_score_time            ...
# std_score_time             ...
# param_regresion__alpha     ...
# param_regresion__l1_ratio  ...
# params                     ...
# split0_test_score          ...
# split1_test_score          ...
# split2_test_score          ...
# split3_test_score          ...
# split4_test_score          ...
# split5_test_score          ...
# split6_test_score          ...
# split7_test_score          ...
# split8_test_score          ...
# split9_test_score          ...
# mean_test_score            ...
# std_test_score             ...
# rank_test_score            ...
# split0_train_score         ...
# split1_train_score         ...
# split2_train_score         ...
# split3_train_score         ...
# split4_train_score         ...
# split5_train_score         ...
# split6_train_score         ...
# split7_train_score         ...
# split8_train_score         ...
# split9_train_score         ...
# mean_train_score           ...
# std_train_score            ...
#
#                                                                           32  \
# mean_fit_time                                                     0.00174119
# std_fit_time                                                     2.40256e-05
# mean_score_time                                                   0.00121849
# std_score_time                                                   6.21267e-06
# param_regresion__alpha                                                  0.01
# param_regresion__l1_ratio                                               0.95
# params                     {'regresion__alpha': 0.01, 'regresion__l1_rati...
# split0_test_score                                                   0.744374
# split1_test_score                                                   0.757724
# split2_test_score                                                   0.794017
# split3_test_score                                                   0.772038
# split4_test_score                                                   0.805358
# split5_test_score                                                   0.812267
# split6_test_score                                                   0.818574
# split7_test_score                                                    0.84536
# split8_test_score                                                   0.712794
# split9_test_score                                                   0.858796
# mean_test_score                                                      0.79213
# std_test_score                                                     0.0432705
# rank_test_score                                                           26
# split0_train_score                                                  0.881892
# split1_train_score                                                  0.871601
# split2_train_score                                                  0.856515
# split3_train_score                                                  0.859262
# split4_train_score                                                   0.85521
# split5_train_score                                                  0.860742
# split6_train_score                                                  0.864501
# split7_train_score                                                  0.859502
# split8_train_score                                                  0.874515
# split9_train_score                                                  0.829145
# mean_train_score                                                    0.861288
# std_train_score                                                    0.0134782
#
#                                                                           13  \
# mean_fit_time                                                     0.00173764
# std_fit_time                                                     3.74918e-05
# mean_score_time                                                   0.00123434
# std_score_time                                                   3.33912e-05
# param_regresion__alpha                                                 1e-05
# param_regresion__l1_ratio                                                  1
# params                     {'regresion__alpha': 1e-05, 'regresion__l1_rat...
# split0_test_score                                                   0.756389
# split1_test_score                                                   0.778997
# split2_test_score                                                   0.787788
# split3_test_score                                                   0.821654
# split4_test_score                                                   0.834938
# split5_test_score                                                   0.750579
# split6_test_score                                                    0.80634
# split7_test_score                                                     0.8054
# split8_test_score                                                   0.727915
# split9_test_score                                                   0.848188
# mean_test_score                                                     0.791819
# std_test_score                                                        0.0368
# rank_test_score                                                           27
# split0_train_score                                                   0.91893
# split1_train_score                                                  0.877299
# split2_train_score                                                  0.863262
# split3_train_score                                                  0.891661
# split4_train_score                                                  0.876797
# split5_train_score                                                  0.864412
# split6_train_score                                                   0.88817
# split7_train_score                                                  0.830364
# split8_train_score                                                  0.872955
# split9_train_score                                                  0.837666
# mean_train_score                                                    0.872151
# std_train_score                                                    0.0243896
#
#                                                                           22  \
# mean_fit_time                                                     0.00172114
# std_fit_time                                                     3.06171e-05
# mean_score_time                                                   0.00122364
# std_score_time                                                   3.59124e-05
# param_regresion__alpha                                                 0.001
# param_regresion__l1_ratio                                                0.5
# params                     {'regresion__alpha': 0.001, 'regresion__l1_rat...
# split0_test_score                                                   0.754416
# split1_test_score                                                   0.758541
# split2_test_score                                                   0.801577
# split3_test_score                                                   0.772844
# split4_test_score                                                   0.809755
# split5_test_score                                                   0.787105
# split6_test_score                                                   0.812125
# split7_test_score                                                   0.838399
# split8_test_score                                                   0.721364
# split9_test_score                                                    0.85548
# mean_test_score                                                     0.791161
# std_test_score                                                     0.0386002
# rank_test_score                                                           28
# split0_train_score                                                  0.880212
# split1_train_score                                                  0.869919
# split2_train_score                                                  0.859012
# split3_train_score                                                  0.862176
# split4_train_score                                                  0.859339
# split5_train_score                                                  0.855574
# split6_train_score                                                  0.863539
# split7_train_score                                                  0.851581
# split8_train_score                                                  0.878369
# split9_train_score                                                  0.834991
# mean_train_score                                                    0.861471
# std_train_score                                                     0.012479
#
#                                                                           5   \
# mean_fit_time                                                      0.0017652
# std_fit_time                                                     0.000110062
# mean_score_time                                                   0.00123506
# std_score_time                                                   3.61891e-05
# param_regresion__alpha                                                 1e-06
# param_regresion__l1_ratio                                               0.99
# params                     {'regresion__alpha': 1e-06, 'regresion__l1_rat...
# split0_test_score                                                   0.747208
# split1_test_score                                                   0.779378
# split2_test_score                                                   0.788075
# split3_test_score                                                   0.821953
# split4_test_score                                                   0.827514
# split5_test_score                                                   0.750558
# split6_test_score                                                   0.806224
# split7_test_score                                                   0.805391
# split8_test_score                                                   0.727807
# split9_test_score                                                   0.848518
# mean_test_score                                                     0.790263
# std_test_score                                                      0.037045
# rank_test_score                                                           29
# split0_train_score                                                    0.9018
# split1_train_score                                                  0.877384
# split2_train_score                                                   0.86329
# split3_train_score                                                  0.891667
# split4_train_score                                                  0.868936
# split5_train_score                                                  0.864429
# split6_train_score                                                  0.888197
# split7_train_score                                                  0.830369
# split8_train_score                                                  0.872963
# split9_train_score                                                  0.837718
# mean_train_score                                                    0.869675
# std_train_score                                                    0.0213638
#
#                                                                           30  \
# mean_fit_time                                                     0.00178087
# std_fit_time                                                     1.53225e-05
# mean_score_time                                                   0.00121753
# std_score_time                                                   5.86146e-06
# param_regresion__alpha                                                  0.01
# param_regresion__l1_ratio                                                0.7
# params                     {'regresion__alpha': 0.01, 'regresion__l1_rati...
# split0_test_score                                                   0.731336
# split1_test_score                                                   0.745424
# split2_test_score                                                   0.800153
# split3_test_score                                                   0.771697
# split4_test_score                                                   0.805698
# split5_test_score                                                   0.801277
# split6_test_score                                                   0.805814
# split7_test_score                                                   0.830203
# split8_test_score                                                   0.722984
# split9_test_score                                                   0.862734
# mean_test_score                                                     0.787732
# std_test_score                                                     0.0422332
# rank_test_score                                                           30
# split0_train_score                                                   0.87034
# split1_train_score                                                  0.857723
# split2_train_score                                                  0.852895
# split3_train_score                                                  0.857808
# split4_train_score                                                   0.85722
# split5_train_score                                                  0.849795
# split6_train_score                                                  0.851128
# split7_train_score                                                  0.844237
# split8_train_score                                                  0.874589
# split9_train_score                                                  0.830006
# mean_train_score                                                    0.854574
# std_train_score                                                    0.0119354
#
#                                                                           33  \
# mean_fit_time                                                     0.00170825
# std_fit_time                                                     1.16306e-05
# mean_score_time                                                   0.00121634
# std_score_time                                                   1.05256e-05
# param_regresion__alpha                                                  0.01
# param_regresion__l1_ratio                                               0.99
# params                     {'regresion__alpha': 0.01, 'regresion__l1_rati...
# split0_test_score                                                   0.748591
# split1_test_score                                                   0.753087
# split2_test_score                                                   0.786368
# split3_test_score                                                   0.750515
# split4_test_score                                                   0.781947
# split5_test_score                                                   0.791988
# split6_test_score                                                   0.809636
# split7_test_score                                                    0.83603
# split8_test_score                                                   0.733993
# split9_test_score                                                   0.853864
# mean_test_score                                                     0.784602
# std_test_score                                                      0.037612
# rank_test_score                                                           31
# split0_train_score                                                  0.869904
# split1_train_score                                                  0.867541
# split2_train_score                                                  0.848264
# split3_train_score                                                   0.84644
# split4_train_score                                                  0.841655
# split5_train_score                                                  0.852722
# split6_train_score                                                  0.860063
# split7_train_score                                                  0.847393
# split8_train_score                                                  0.858177
# split9_train_score                                                  0.825148
# mean_train_score                                                    0.851731
# std_train_score                                                    0.0124866
#
#                                                                           6   \
# mean_fit_time                                                     0.00173466
# std_fit_time                                                     4.76429e-05
# mean_score_time                                                   0.00121758
# std_score_time                                                   9.57686e-06
# param_regresion__alpha                                                 1e-06
# param_regresion__l1_ratio                                                  1
# params                     {'regresion__alpha': 1e-06, 'regresion__l1_rat...
# split0_test_score                                                   0.746842
# split1_test_score                                                   0.762402
# split2_test_score                                                   0.787344
# split3_test_score                                                   0.822211
# split4_test_score                                                   0.828218
# split5_test_score                                                    0.74911
# split6_test_score                                                   0.766708
# split7_test_score                                                   0.805319
# split8_test_score                                                   0.727952
# split9_test_score                                                   0.847431
# mean_test_score                                                     0.784354
# std_test_score                                                     0.0379581
# rank_test_score                                                           32
# split0_train_score                                                  0.895313
# split1_train_score                                                  0.868845
# split2_train_score                                                   0.86323
# split3_train_score                                                   0.89165
# split4_train_score                                                  0.868829
# split5_train_score                                                  0.844807
# split6_train_score                                                  0.855654
# split7_train_score                                                  0.830229
# split8_train_score                                                  0.872888
# split9_train_score                                                  0.837572
# mean_train_score                                                    0.862902
# std_train_score                                                    0.0203379
#
#                                                                           34  \
# mean_fit_time                                                     0.00170677
# std_fit_time                                                     9.44935e-06
# mean_score_time                                                   0.00121708
# std_score_time                                                    8.7196e-06
# param_regresion__alpha                                                  0.01
# param_regresion__l1_ratio                                                  1
# params                     {'regresion__alpha': 0.01, 'regresion__l1_rati...
# split0_test_score                                                   0.749462
# split1_test_score                                                   0.747272
# split2_test_score                                                   0.787073
# split3_test_score                                                   0.749661
# split4_test_score                                                   0.794785
# split5_test_score                                                   0.780266
# split6_test_score                                                   0.810665
# split7_test_score                                                   0.830698
# split8_test_score                                                   0.727108
# split9_test_score                                                   0.844131
# mean_test_score                                                     0.782112
# std_test_score                                                     0.0368363
# rank_test_score                                                           33
# split0_train_score                                                  0.870502
# split1_train_score                                                  0.863198
# split2_train_score                                                  0.849115
# split3_train_score                                                  0.847015
# split4_train_score                                                  0.852292
# split5_train_score                                                   0.84718
# split6_train_score                                                  0.861076
# split7_train_score                                                  0.841305
# split8_train_score                                                  0.869884
# split9_train_score                                                  0.816496
# mean_train_score                                                    0.851806
# std_train_score                                                    0.0151691
#
#                                                                           29  \
# mean_fit_time                                                     0.00179985
# std_fit_time                                                     5.14843e-05
# mean_score_time                                                   0.00122392
# std_score_time                                                   2.27167e-05
# param_regresion__alpha                                                  0.01
# param_regresion__l1_ratio                                                0.5
# params                     {'regresion__alpha': 0.01, 'regresion__l1_rati...
# split0_test_score                                                   0.728268
# split1_test_score                                                    0.73414
# split2_test_score                                                   0.791495
# split3_test_score                                                   0.764452
# split4_test_score                                                   0.798025
# split5_test_score                                                   0.792978
# split6_test_score                                                   0.796263
# split7_test_score                                                    0.82509
# split8_test_score                                                   0.724535
# split9_test_score                                                   0.854131
# mean_test_score                                                     0.780938
# std_test_score                                                     0.0406291
# rank_test_score                                                           34
# split0_train_score                                                  0.861678
# split1_train_score                                                   0.85001
# split2_train_score                                                  0.843391
# split3_train_score                                                  0.848054
# split4_train_score                                                  0.848892
# split5_train_score                                                  0.842133
# split6_train_score                                                  0.844009
# split7_train_score                                                   0.83852
# split8_train_score                                                  0.864504
# split9_train_score                                                  0.825056
# mean_train_score                                                    0.846625
# std_train_score                                                    0.0106456
#
#                                                                           28
# mean_fit_time                                                     0.00358391
# std_fit_time                                                     0.000802377
# mean_score_time                                                    0.0012192
# std_score_time                                                   9.46858e-06
# param_regresion__alpha                                                  0.01
# param_regresion__l1_ratio                                                0.1
# params                     {'regresion__alpha': 0.01, 'regresion__l1_rati...
# split0_test_score                                                   0.739781
# split1_test_score                                                   0.720235
# split2_test_score                                                   0.789237
# split3_test_score                                                   0.760546
# split4_test_score                                                    0.78487
# split5_test_score                                                   0.776352
# split6_test_score                                                   0.776621
# split7_test_score                                                   0.809588
# split8_test_score                                                   0.756553
# split9_test_score                                                   0.832842
# mean_test_score                                                     0.774662
# std_test_score                                                     0.0310391
# rank_test_score                                                           35
# split0_train_score                                                  0.853296
# split1_train_score                                                  0.845783
# split2_train_score                                                  0.832506
# split3_train_score                                                  0.835838
# split4_train_score                                                  0.834328
# split5_train_score                                                  0.829119
# split6_train_score                                                  0.837963
# split7_train_score                                                  0.823846
# split8_train_score                                                  0.853477
# split9_train_score                                                     0.808
# mean_train_score                                                    0.835416
# std_train_score                                                    0.0130188
#
# [32 rows x 35 columns]

# %%
gridresults.head(3)
# Out:
#    mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 0       0.002024      0.000215         0.001322        0.000134
# 1       0.001818      0.000129         0.001315        0.000147
# 2       0.001753      0.000024         0.001234        0.000043
#
#   param_regresion__alpha param_regresion__l1_ratio  \
# 0                  1e-06                       0.1
# 1                  1e-06                       0.5
# 2                  1e-06                       0.7
#
#                                               params  split0_test_score  \
# 0  {'regresion__alpha': 1e-06, 'regresion__l1_rat...           0.746183
# 1  {'regresion__alpha': 1e-06, 'regresion__l1_rat...           0.746051
# 2  {'regresion__alpha': 1e-06, 'regresion__l1_rat...           0.746597
#
#    split1_test_score  split2_test_score  ...  split2_train_score  \
# 0           0.798547           0.806489  ...            0.889521
# 1           0.798684           0.806188  ...            0.889610
# 2           0.790404           0.799720  ...            0.874892
#
#    split3_train_score  split4_train_score  split5_train_score  \
# 0            0.887793            0.882760            0.891854
# 1            0.887814            0.882811            0.892020
# 2            0.887826            0.882835            0.897445
#
#    split6_train_score  split7_train_score  split8_train_score  \
# 0            0.893447            0.873701            0.883470
# 1            0.893547            0.873731            0.883445
# 2            0.893593            0.873741            0.890461
#
#    split9_train_score  mean_train_score  std_train_score
# 0            0.863843          0.884912         0.009181
# 1            0.863917          0.884970         0.009194
# 2            0.863958          0.884972         0.011097
#
# [3 rows x 32 columns]

# %%
import seaborn as sns 
sns.set()
fig,ax = plt.subplots(1, 3, figsize=(20,5))

ax = plt.subplot(1, 3, 1)
pvt_rank = gridresults.pivot(index ='param_regresion__alpha', columns = 'param_regresion__l1_ratio',
                             values = 'rank_test_score')
sns.heatmap(pvt_rank,annot=True);
ax = plt.subplot(1, 3, 2)
pvt_mean = gridresults.pivot(index ='param_regresion__alpha', columns = 'param_regresion__l1_ratio',
                             values = 'mean_test_score')
sns.heatmap(pvt_mean,annot=True);
ax = plt.subplot(1, 3, 3)
pvt_std = gridresults.pivot(index = 'param_regresion__alpha', columns ='param_regresion__l1_ratio',
                            values = 'std_test_score')
sns.heatmap(pvt_std,annot=True);

# %%
import matplotlib
matplotlib.__version__
# Out:
# '3.1.1'
